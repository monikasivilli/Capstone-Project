# %% [markdown]
# # New York Borough COVID-19 and Census Data
# ___

# %% [markdown]
# New York is the epicenter of the American coronavirus pandedemic. However, the state of NY has had varying amounts of cases. The true epicenter within NY has been New York City, specificially the five major boroughs, New York, Bronx, Brooklyn (also known as Kings County), Manhattan (New York County), Queens, Staten Island (also known as Richmond County).
#
# This data set is a combination of census data and COVID-19 tracking data. The census data is complied of population, population per square mile, and demogrpahic breakdown. The COVID-19 Tracking informaiton includes confirmed cases, hospitilization, and deaths in total counts and rates. As mentioned earlier this dataset includes the five boroughs individually and in total. This data was last updated on July 1, 2019.

# %% [markdown]
# <b> Import modules </b>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import norm
import numpy as np

# %% [markdown]
# <b> Read csv file to a pandas dataframe </b>

# %%
df = pd.read_csv("borough_COVID_python.csv")
df
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/opt/tljh/user/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3319, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-34-061b66351a2d>", line 1, in <module>
#     df = pd.read_csv("borough_COVID_python.csv")
#   File "/opt/tljh/user/lib/python3.6/site-packages/pandas/io/parsers.py", line 685, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "/opt/tljh/user/lib/python3.6/site-packages/pandas/io/parsers.py", line 457, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/opt/tljh/user/lib/python3.6/site-packages/pandas/io/parsers.py", line 895, in __init__
#     self._make_engine(self.engine)
#   File "/opt/tljh/user/lib/python3.6/site-packages/pandas/io/parsers.py", line 1135, in _make_engine
#     self._engine = CParserWrapper(self.f, **self.options)
#   File "/opt/tljh/user/lib/python3.6/site-packages/pandas/io/parsers.py", line 1917, in __init__
#     self._reader = parsers.TextReader(src, **kwds)
#   File "pandas/_libs/parsers.pyx", line 382, in pandas._libs.parsers.TextReader.__cinit__
#   File "pandas/_libs/parsers.pyx", line 689, in pandas._libs.parsers.TextReader._setup_parser_source
# FileNotFoundError: [Errno 2] File b'borough_COVID_python.csv' does not exist: b'borough_COVID_python.csv'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/tljh/user/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2034, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/tljh/user/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1151, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/opt/tljh/user/lib/python3.6/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/opt/tljh/user/lib/python3.6/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/opt/tljh/user/lib/python3.6/inspect.py", line 1488, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/opt/tljh/user/lib/python3.6/inspect.py", line 1446, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/opt/tljh/user/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/opt/tljh/user/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/opt/tljh/user/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/opt/tljh/user/lib/python3.6/posixpath.py", line 376, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# ---------------------------------------------------------------------------

# %% [markdown]
# <b> Number of rows, number of columns in dataset </b>

# %%
print('There are # number of rows in the dataset    :', df.shape[0])
print('There are # number of columns in the dataset :', df.shape[1])
# Out:
# There are # number of rows in the dataset    : 6
# There are # number of columns in the dataset : 68

# %%
#df.info()

# %%
df.hist(figsize = (15,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa78c312940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa78c12d908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa78c153278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa78c0f8cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa78c1277b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa78c1277f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa78c07bcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa78c02b7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa78c05b278>]],
#       dtype=object)

# %%
# ID descriptions 
    # 0 New York City, New York
    # 1 Bronx County
    # 2 Kings County, Brookyln 
    # 3 Manhattan
    # 4 Queens County
    # 5 Richmond County, State Island

# %%
df['Case Rate']
# Out:
# 0    2387.82
# 1    3167.31
# 2    2141.29
# 3    1538.40
# 4    2690.15
# 5    2817.64
# Name: Case Rate, dtype: float64

# %% [markdown]
# ## 1. Barcharts

# %% [markdown]
# _Bar charts for the Case Rate, Death Rate, and Hospitilization Rate for all of NYC and the 5 boroughs._

# %%
df['Case Rate'].plot(kind='barh')

# %%
df['Hospitilization Rate'].plot(kind='barh')

# %%
df['Death Rate'].plot(kind='barh')
