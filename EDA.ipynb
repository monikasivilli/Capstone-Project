# %% [markdown]
# # <b> Preparing Data for Models </b>
# ___

# %% [markdown]
# <b> Table of Content: </b>
# <br> [0. Loading Modules and Dataset](#11)
# <br> [1. Outlier IQR](#22)
# <br> [2. Normalization](#33)
# <br> [3. Standardization Z-score](#44)
# <br> [4. Correlation Analysis](#55)
# <br> [5. Feature Selection](#66)
# <br> [6. Save Top Features and Target to a CSV File](#77)

# %% [markdown]
# <a id = "11"> <h2> 0. Loading Modules and Dataset </h2> </a>
# ___

# %% [markdown]
# <b> Import modules

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from scipy import stats
from scipy.stats import norm
from scipy.stats import kurtosis, skew
from scipy.stats import boxcox
from scipy.stats import zscore

from sklearn.datasets import make_regression
from sklearn.feature_selection import RFE
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import chi2
from sklearn.linear_model import Ridge

from sklearn.linear_model import LogisticRegression
from sklearn import datasets

import warnings

# %% [markdown]
# <b> Read previously recoded/calculated features from a .csv file to a pandas dataframe

# %%
df = pd.read_csv("census_covid_cat_final.csv")
df.head()
# Out:
#                  Full Name    Country Name    State State Abbr  \
# 0  Autauga County, Alabama  Autauga County  Alabama         AL
# 1  Baldwin County, Alabama  Baldwin County  Alabama         AL
# 2  Barbour County, Alabama  Barbour County  Alabama         AL
# 3     Bibb County, Alabama     Bibb County  Alabama         AL
# 4   Blount County, Alabama   Blount County  Alabama         AL
#
#     Total Population    Households SNAP    Estimated Individuals SNAP   \
# 0               54571               2802                          7509
# 1              182265               6644                         16344
# 2               27457               2468                          6096
# 3               22915                933                          2426
# 4               57322               2244                          5902
#
#     Total Citizen Educated in US    Citizen Less than High School  Education   \
# 0                           36757                                        4521
# 1                          143022                                       13997
# 2                           18434                                        4960
# 3                           15859                                        2833
# 4                           39475                                        7980
#
#     Citizen High School  Graduate   ...  Female Median Age  \
# 0                            12363  ...               37.9
# 1                            39771  ...               42.2
# 2                             6549  ...               41.6
# 3                             6958  ...               39.5
# 4                            12740  ...               40.0
#
#     Total Households    Average Household Size    Total Families   \
# 0               20221                         3             14613
# 1               73180                         2             41898
# 2                9820                         2              6015
# 3                7953                         3              5201
# 4               21578                         3             14106
#
#    Total Confirmed Cases  Total Deaths  Case Rate per 1000  Death Rate 1000  \
# 0                      0             0               7.330            0.147
# 1                    400             8               2.200            0.049
# 2                    401             9               9.579            0.036
# 3                    263             1               5.280            0.044
# 4                    121             1               2.268            0.017
#
#    Case Rate Categories   Death Rate Categories
# 0                      2                      2
# 1                      2                      1
# 2                      3                      1
# 3                      2                      1
# 4                      2                      1
#
# [5 rows x 43 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3139 entries, 0 to 3138
# Data columns (total 43 columns):
# Full Name                                     3139 non-null object
# Country Name                                  3139 non-null object
# State                                         3139 non-null object
# State Abbr                                    3139 non-null object
#  Total Population                             3139 non-null int64
#  Households SNAP                              3139 non-null int64
#  Estimated Individuals SNAP                   3139 non-null int64
#  Total Citizen Educated in US                 3139 non-null int64
#  Citizen Less than High School  Education     3139 non-null int64
#  Citizen High School  Graduate                3139 non-null int64
#  Citizen Some College  Education              3139 non-null int64
#  Citizen College Degree                       3139 non-null int64
#  Citizen Graduate or Professional Degree      3139 non-null int64
#  Total Citizen Income                         3139 non-null int64
#  Citizen No Income                            3139 non-null int64
# Citizen Income 1-9999                         3139 non-null int64
# Citizen Income 10000-14999                    3139 non-null int64
# Citizen Income 15000-24999                    3139 non-null int64
# Citizen Income 25000-34999                    3139 non-null int64
# Citizen Income 35000-49999                    3139 non-null int64
# Citizen Income 50000-64999                    3139 non-null int64
# Citizen Income 65000-74999                    3139 non-null int64
# Citizen Income over 75000                     3139 non-null int64
#  One Race Population                          3139 non-null int64
#  White Race                                   3139 non-null int64
#  Black Race                                   3139 non-null int64
#  Native American Race                         3139 non-null int64
#  Asian Race                                   3139 non-null int64
#  Pacific Islander Race                        3139 non-null int64
#  Other Race Alone                             3139 non-null int64
#  Hispanic or Latino                           3139 non-null int64
# Median Age                                    3139 non-null float64
# Male Median Age                               3139 non-null float64
# Female Median Age                             3139 non-null float64
#  Total Households                             3139 non-null int64
#  Average Household Size                       3139 non-null int64
#  Total Families                               3139 non-null int64
# Total Confirmed Cases                         3139 non-null int64
# Total Deaths                                  3139 non-null int64
# Case Rate per 1000                            3139 non-null float64
# Death Rate 1000                               3139 non-null float64
# Case Rate Categories                          3139 non-null int64
# Death Rate Categories                         3139 non-null int64
# dtypes: float64(5), int64(34), object(4)
# memory usage: 1.0+ MB

# %%
# show the list of features incl. target in dataset
#df.columns.to_series().groupby(df.dtypes).groups

# %%
# trim the spaces of the cells from the csv file
df.columns = df.columns.to_series().apply(lambda x: x.strip())

# %%
# need to change int64 to cat type for target vars
df['Case Rate Categories'] = df['Case Rate Categories'].astype('category')
df['Death Rate Categories'] = df['Death Rate Categories'].astype('category')

# %% [markdown]
# <a id = "22"> <h2> 1. Outlier IQR </h2> </a>
# ___

# %% [markdown]
# <b> Assumption: </b> Every data point for every continuous feature that is 1.5 times below/above the Interquartile Range (Q3-Q1) is considered an outlier
# <br> Whereby zero's are excluded from the calculation of the 25% quantile and 75% quantile

# %% [markdown]
# The features in the table above, should not be included in dealing with outliers with the IQR method, it will result in all zero's

# %% [markdown]
# <b> 1.1 Create a function to deal with outliers </b>

# %%
def remove_cols_outliers_iqr(df, column_list): 
    for my_col in column_list:      
        # only calculate the quantile on non-zero values in the column
        Q1 = df[df[my_col] > 0 ][my_col].quantile(0.25)
        Q3 = df[df[my_col] > 0 ][my_col].quantile(0.75)
        #Q1 = df[my_col].quantile(0.25)
        #Q3 = df[my_col].quantile(0.75)
        IQR = Q3 - Q1

        u_bound_q3 = (Q3 + 1.5 * IQR)
        l_bound_q1 = (Q1 - 1.5 * IQR)
        
        # combine old column name with a suffix for the new name of the column
        suffix = '_iqr'
        my_new_col = ''.join([my_col, suffix])
        
        # create a new column with the name: (column name + suffix)
        df[my_new_col] = df[my_col]
        
        # if a value in the column is larger than the upper bound, set it equal to the upper bound, else keep the original value
        df[my_new_col] = np.where(df[my_new_col] > u_bound_q3, u_bound_q3, df[my_new_col]) 
        # if a value in the column is larger than the lower bound, set it equal to the lower bound, else keep the original value
        df[my_new_col] = np.where(df[my_new_col] < l_bound_q1, l_bound_q1, df[my_new_col])

# %% [markdown]
# <b> 1.2 Apply the function  on continuous features </b>

# %%
# create a list of the continuous features in the pandas dataframe
lst_continuous_cols = ['Total Population','Households SNAP','Estimated Individuals SNAP','Total Citizen Educated in US',
                       'Citizen Less than High School  Education','Citizen High School  Graduate',
                       'Citizen Some College  Education','Citizen College Degree','Citizen Graduate or Professional Degree',
                       'Total Citizen Income','Citizen No Income','Citizen Income 1-9999','Citizen Income 10000-14999',
                       'Citizen Income 15000-24999','Citizen Income 25000-34999','Citizen Income 35000-49999',
                       'Citizen Income 50000-64999','Citizen Income 65000-74999','Citizen Income over 75000',
                       'One Race Population','White Race','Black Race','Native American Race','Asian Race',
                       'Pacific Islander Race','Other Race Alone','Hispanic or Latino','Median Age', 
                        'Male Median Age','Female Median Age','Total Households',
                       'Average Household Size','Total Families', 'Total Confirmed Cases', 'Total Deaths',
                      'Case Rate per 1000', 'Death Rate 1000']


# apply the function to the list of continuous features        
remove_cols_outliers_iqr(df=df, column_list=lst_continuous_cols)

# %% [markdown]
# _test if all iqr columns were created:_

# %%
# source: https://stackoverflow.com/questions/21285380/find-column-whose-name-contains-a-specific-string
iqr_cols = [col for col in df.columns if 'iqr' in col]

# test if the length of the list of columns that has iqr in the name, is the same length as the list provided in the function of column names
len(lst_continuous_cols) == len(iqr_cols)

# show columns where names contains the string 'iqr'
iqr_cols
# Out:
# ['Total Population_iqr',
#  'Households SNAP_iqr',
#  'Estimated Individuals SNAP_iqr',
#  'Total Citizen Educated in US_iqr',
#  'Citizen Less than High School  Education_iqr',
#  'Citizen High School  Graduate_iqr',
#  'Citizen Some College  Education_iqr',
#  'Citizen College Degree_iqr',
#  'Citizen Graduate or Professional Degree_iqr',
#  'Total Citizen Income_iqr',
#  'Citizen No Income_iqr',
#  'Citizen Income 1-9999_iqr',
#  'Citizen Income 10000-14999_iqr',
#  'Citizen Income 15000-24999_iqr',
#  'Citizen Income 25000-34999_iqr',
#  'Citizen Income 35000-49999_iqr',
#  'Citizen Income 50000-64999_iqr',
#  'Citizen Income 65000-74999_iqr',
#  'Citizen Income over 75000_iqr',
#  'One Race Population_iqr',
#  'White Race_iqr',
#  'Black Race_iqr',
#  'Native American Race_iqr',
#  'Asian Race_iqr',
#  'Pacific Islander Race_iqr',
#  'Other Race Alone_iqr',
#  'Hispanic or Latino_iqr',
#  'Median Age_iqr',
#  'Male Median Age_iqr',
#  'Female Median Age_iqr',
#  'Total Households_iqr',
#  'Average Household Size_iqr',
#  'Total Families_iqr',
#  'Total Confirmed Cases_iqr',
#  'Total Deaths_iqr',
#  'Case Rate per 1000_iqr',
#  'Death Rate 1000_iqr']

# %% [markdown]
# <b> 1.3 Test if the function correctly worked, using different examples </b>

# %% [markdown]
# _test if the maximum changed_

# %%
print('maximum value of feature `Total Population`:', df['Total Population'].max())
print('new maximum value after removal of outliers with iqr of feature `Total Population_iqr`:', df['Total Population_iqr'].max())
# Out:
# maximum value of feature `Total Population`: 9818605
# new maximum value after removal of outliers with iqr of feature `Total Population_iqr`: 150073.5

# %%
# show the original feature versus the feature where outliers are dealt with using IQR
df[df['Total Population_iqr']==54571][['Total Population', 'Total Population_iqr']]
# Out:
#    Total Population  Total Population_iqr
# 0             54571               54571.0

# %% [markdown]
# <a id = "33"> <h2> 2. Normalization </h2> </a>
# ___

# %% [markdown]
# Assumption: the dataset follows a Gaussian Distribution

# %% [markdown]
# <b> 2.2 Create a function to normalize continuous features with a PowerTransform: </b>
# <br> using Boxcox _(for Positive Features)_
# <br> <b> Note: </b> A power transformation will change the distribution of the data, for more information see: [link](https://medium.com/@patricklcavins/using-scipys-powertransformer-3e2b792fd712)

# %%
################################################################################################ 
# defined a function to normalize a feature in an additional new column with powertransform, 
# using boxcox (if positive values) 
# and add a suffix to the name of the column _bc for boxcox 
################################################################################################ 
# required modules -> imported at the start but if you copy/paste this function please make sure you install the two below!
#from scipy.stats import boxcox


def powertransform_boxcox_yeojohnson(df, column_list):
    # loop through each column in the column list
    for my_col in column_list:      
        # test if the minimum in the column is positive, if True apply boxcox, if False apply yeojohnson
        if (df[my_col].min() > 0)==True:
            # combine old column name with a suffix for the new name of the column
            suffix = '_bc'
            my_new_col = ''.join([my_col, suffix])
            # create a new column with the name: (column name + suffix)
            df[my_new_col] = df[my_col]
            # if positive, apply boxcox
            df[my_new_col] = boxcox(df[my_new_col])[0]

# %% [markdown]
# <b> 2.3 Apply the function to normalize continuous features
# 1. Applied to continuous features <b> without </b>  applying outlier IQR,
# 2. Applied to continuous features <b> with </b> applying outlier IQR:

# %%
# list continuous features
lst_continuous_cols = ['Total Population_iqr',
                             'Households SNAP_iqr',
                             'Estimated Individuals SNAP_iqr',
                             'Total Citizen Educated in US_iqr',
                             'Citizen Less than High School  Education_iqr',
                             'Citizen High School  Graduate_iqr',
                             'Citizen Some College  Education_iqr',
                             'Citizen College Degree_iqr',
                             'Citizen Graduate or Professional Degree_iqr',
                             'Total Citizen Income_iqr',
                             'Citizen No Income_iqr',
                             'Citizen Income 1-9999_iqr',
                             'Citizen Income 10000-14999_iqr',
                             'Citizen Income 15000-24999_iqr',
                             'Citizen Income 25000-34999_iqr',
                             'Citizen Income 35000-49999_iqr',
                             'Citizen Income 50000-64999_iqr',
                             'Citizen Income 65000-74999_iqr',
                             'Citizen Income over 75000_iqr',
                             'One Race Population_iqr',
                             'White Race_iqr',
                             'Black Race_iqr',
                             'Native American Race_iqr',
                             'Asian Race_iqr',
                             'Pacific Islander Race_iqr',
                             'Other Race Alone_iqr',
                             'Hispanic or Latino_iqr',
                            'Median Age_iqr',
                             'Male Median Age_iqr',
                             'Female Median Age_iqr',
                             'Total Households_iqr',
                             'Average Household Size_iqr',
                             'Total Families_iqr',
                             'Total Confirmed Cases_iqr',
                             'Total Deaths_iqr',
                             'Case Rate per 1000_iqr',
                             'Death Rate 1000_iqr']

powertransform_boxcox_yeojohnson(df=df, column_list=lst_continuous_cols)

# %% [markdown]
# <b> 2.4 Test if there are NaN's after the normalization

# %%
# check if there are NaN's after the normalization
# create a function to create a dataframe with # NaN's and % NaN's
def function_nans(df):
    # Count NaN's
    list_nan = df.isna().sum()

    # Percentage of missing values for each column (To see the amount of usable data for each column and infer the effect replacing NaN's will have by some metric in part 2)
    list_nan_pct = df.isna().mean().round(4) * 100

    # create a dataframe showing the missing and percentage that is missing
    df_combined = pd.concat([list_nan.rename('# NaNs'), list_nan_pct.rename('% NaNs')], axis=1)
    
    #return(df_combined)
    return(df_combined[df_combined['# NaNs']>0])

# show all the rows of the dataframe without truncating
#pd.set_option('display.max_rows', len(df))

# apply function 'function_nans' - show a dataframe for number of NaN's and the % of NaN's for each added feature
function_nans(df=df)
# conclusion, no NaN's, because empty dataframe
# Out:
# Empty DataFrame
# Columns: [# NaNs, % NaNs]
# Index: []

# %% [markdown]
# <b> 2.5 Test if all normalized features are added to the dataframe

# %% [markdown]
# Test if additional columns were created with boxcox, using a suffix _bc

# %%
bc_cols = [col for col in df.columns if '_bc' in col]
# show columns where names contains the string '_bc'
bc_cols
# Out:
# ['Total Population_iqr_bc',
#  'Total Citizen Educated in US_iqr_bc',
#  'Citizen Less than High School  Education_iqr_bc',
#  'Citizen High School  Graduate_iqr_bc',
#  'Citizen Some College  Education_iqr_bc',
#  'Citizen College Degree_iqr_bc',
#  'Total Citizen Income_iqr_bc',
#  'Citizen No Income_iqr_bc',
#  'Citizen Income 1-9999_iqr_bc',
#  'Citizen Income 10000-14999_iqr_bc',
#  'Citizen Income 15000-24999_iqr_bc',
#  'Citizen Income 25000-34999_iqr_bc',
#  'Citizen Income 35000-49999_iqr_bc',
#  'Citizen Income 50000-64999_iqr_bc',
#  'Citizen Income over 75000_iqr_bc',
#  'One Race Population_iqr_bc',
#  'Other Race Alone_iqr_bc',
#  'Hispanic or Latino_iqr_bc',
#  'Median Age_iqr_bc',
#  'Male Median Age_iqr_bc',
#  'Female Median Age_iqr_bc',
#  'Total Households_iqr_bc',
#  'Average Household Size_iqr_bc']

# %% [markdown]
# Test if additional columns were created with a suffix _yj

# %%
# set the option to not truncate the columns when showing a dataframe
pd.set_option('display.max_columns', None)
#pd.reset_option('display.max_columns')
df.head()
# Out:
#                  Full Name    Country Name    State State Abbr  \
# 0  Autauga County, Alabama  Autauga County  Alabama         AL
# 1  Baldwin County, Alabama  Baldwin County  Alabama         AL
# 2  Barbour County, Alabama  Barbour County  Alabama         AL
# 3     Bibb County, Alabama     Bibb County  Alabama         AL
# 4   Blount County, Alabama   Blount County  Alabama         AL
#
#    Total Population  Households SNAP  Estimated Individuals SNAP  \
# 0             54571             2802                        7509
# 1            182265             6644                       16344
# 2             27457             2468                        6096
# 3             22915              933                        2426
# 4             57322             2244                        5902
#
#    Total Citizen Educated in US  Citizen Less than High School  Education  \
# 0                         36757                                      4521
# 1                        143022                                     13997
# 2                         18434                                      4960
# 3                         15859                                      2833
# 4                         39475                                      7980
#
#    Citizen High School  Graduate  Citizen Some College  Education  \
# 0                          12363                            10697
# 1                          39771                            45286
# 2                           6549                             4707
# 3                           6958                             3971
# 4                          12740                            13583
#
#    Citizen College Degree  Citizen Graduate or Professional Degree  \
# 0                    5316                                     3860
# 1                   29237                                    14731
# 2                    1403                                      815
# 3                    1289                                      808
# 4                    3416                                     1756
#
#    Total Citizen Income  Citizen No Income  Citizen Income 1-9999  \
# 0                 44109               6377                   6955
# 1                166364              20201                  25080
# 2                 21627               3968                   5090
# 3                 18743               4170                   3268
# 4                 46501              10165                   6561
#
#    Citizen Income 10000-14999  Citizen Income 15000-24999  \
# 0                        4235                        6000
# 1                       16030                       26852
# 2                        2762                        3419
# 3                        1835                        2926
# 4                        4115                        6956
#
#    Citizen Income 25000-34999  Citizen Income 35000-49999  \
# 0                        4825                        5727
# 1                       20222                       21502
# 2                        1982                        1820
# 3                        2036                        1860
# 4                        5184                        5639
#
#    Citizen Income 50000-64999  Citizen Income 65000-74999  \
# 0                        3352                        1340
# 1                       13466                        5057
# 2                        1150                         417
# 3                        1044                         651
# 4                        3549                        1642
#
#    Citizen Income over 75000  One Race Population  White Race  Black Race  \
# 0                       5298                42855        9643         232
# 1                      17954               156153       17105        1216
# 2                       1019                13180       12875         114
# 3                        953                17381        5047          64
# 4                       2690                53068         761         307
#
#    Native American Race  Asian Race  Pacific Islander Race  Other Race Alone  \
# 0                   474          32                    466               869
# 1                  1348          89                   3631              2723
# 2                   107          29                    894               258
# 3                    22          13                    185               203
# 4                   117          38                   2347               684
#
#    Hispanic or Latino  Median Age  Male Median Age  Female Median Age  \
# 0               53261        37.0             35.9               37.9
# 1              174273        41.1             40.1               42.2
# 2               26070        39.0             37.2               41.6
# 3               22509        37.8             36.5               39.5
# 4               52696        39.0             38.0               40.0
#
#    Total Households  Average Household Size  Total Families  \
# 0             20221                       3           14613
# 1             73180                       2           41898
# 2              9820                       2            6015
# 3              7953                       3            5201
# 4             21578                       3           14106
#
#    Total Confirmed Cases  Total Deaths  Case Rate per 1000  Death Rate 1000  \
# 0                      0             0               7.330            0.147
# 1                    400             8               2.200            0.049
# 2                    401             9               9.579            0.036
# 3                    263             1               5.280            0.044
# 4                    121             1               2.268            0.017
#
#   Case Rate Categories Death Rate Categories  Total Population_iqr  \
# 0                    2                     2               54571.0
# 1                    2                     1              150073.5
# 2                    3                     1               27457.0
# 3                    2                     1               22915.0
# 4                    2                     1               57322.0
#
#    Households SNAP_iqr  Estimated Individuals SNAP_iqr  \
# 0               2802.0                          7509.0
# 1               6644.0                         16344.0
# 2               2468.0                          6096.0
# 3                933.0                          2426.0
# 4               2244.0                          5902.0
#
#    Total Citizen Educated in US_iqr  \
# 0                           36757.0
# 1                          103114.0
# 2                           18434.0
# 3                           15859.0
# 4                           39475.0
#
#    Citizen Less than High School  Education_iqr  \
# 0                                        4521.0
# 1                                       12942.5
# 2                                        4960.0
# 3                                        2833.0
# 4                                        7980.0
#
#    Citizen High School  Graduate_iqr  Citizen Some College  Education_iqr  \
# 0                            12363.0                             10697.00
# 1                            33918.0                             32031.75
# 2                             6549.0                              4707.00
# 3                             6958.0                              3971.00
# 4                            12740.0                             13583.00
#
#    Citizen College Degree_iqr  Citizen Graduate or Professional Degree_iqr  \
# 0                      5316.0                                     3860.000
# 1                     14823.0                                     8459.125
# 2                      1403.0                                      815.000
# 3                      1289.0                                      808.000
# 4                      3416.0                                     1756.000
#
#    Total Citizen Income_iqr  Citizen No Income_iqr  Citizen Income 1-9999_iqr  \
# 0                  44109.00                 6377.0                     6955.0
# 1                 124000.25                16089.5                    22224.0
# 2                  21627.00                 3968.0                     5090.0
# 3                  18743.00                 4170.0                     3268.0
# 4                  46501.00                10165.0                     6561.0
#
#    Citizen Income 10000-14999_iqr  Citizen Income 15000-24999_iqr  \
# 0                         4235.00                          6000.0
# 1                        12056.25                         19035.0
# 2                         2762.00                          3419.0
# 3                         1835.00                          2926.0
# 4                         4115.00                          6956.0
#
#    Citizen Income 25000-34999_iqr  Citizen Income 35000-49999_iqr  \
# 0                          4825.0                         5727.00
# 1                         14998.5                        15660.25
# 2                          1982.0                         1820.00
# 3                          2036.0                         1860.00
# 4                          5184.0                         5639.00
#
#    Citizen Income 50000-64999_iqr  Citizen Income 65000-74999_iqr  \
# 0                          3352.0                         1340.00
# 1                         10333.0                         4120.25
# 2                          1150.0                          417.00
# 3                          1044.0                          651.00
# 4                          3549.0                         1642.00
#
#    Citizen Income over 75000_iqr  One Race Population_iqr  White Race_iqr  \
# 0                         5298.0                 42855.00          9643.0
# 1                        11040.0                126090.75         13646.5
# 2                         1019.0                 13180.00         12875.0
# 3                          953.0                 17381.00          5047.0
# 4                         2690.0                 53068.00           761.0
#
#    Black Race_iqr  Native American Race_iqr  Asian Race_iqr  \
# 0         232.000                     474.0            32.0
# 1        1123.375                    1348.0            89.0
# 2         114.000                     107.0            29.0
# 3          64.000                      22.0            13.0
# 4         307.000                     117.0            38.0
#
#    Pacific Islander Race_iqr  Other Race Alone_iqr  Hispanic or Latino_iqr  \
# 0                      466.0                 869.0                53261.00
# 1                     3631.0                2723.0               140466.75
# 2                      894.0                 258.0                26070.00
# 3                      185.0                 203.0                22509.00
# 4                     2347.0                 684.0                52696.00
#
#    Median Age_iqr  Male Median Age_iqr  Female Median Age_iqr  \
# 0            37.0                 35.9                   37.9
# 1            41.1                 40.1                   42.2
# 2            39.0                 37.2                   41.6
# 3            37.8                 36.5                   39.5
# 4            39.0                 38.0                   40.0
#
#    Total Households_iqr  Average Household Size_iqr  Total Families_iqr  \
# 0               20221.0                         3.0            14613.00
# 1               57984.0                         2.0            34798.25
# 2                9820.0                         2.0             6015.00
# 3                7953.0                         3.0             5201.00
# 4               21578.0                         3.0            14106.00
#
#    Total Confirmed Cases_iqr  Total Deaths_iqr  Case Rate per 1000_iqr  \
# 0                        0.0               0.0                   7.330
# 1                      400.0               8.0                   2.200
# 2                      401.0               9.0                   9.579
# 3                      263.0               1.0                   5.280
# 4                      121.0               1.0                   2.268
#
#    Death Rate 1000_iqr  Total Population_iqr_bc  \
# 0                0.147                25.393962
# 1                0.049                30.283200
# 2                0.036                22.442567
# 3                0.044                21.710978
# 4                0.017                25.616212
#
#    Total Citizen Educated in US_iqr_bc  \
# 0                            23.030193
# 1                            27.544206
# 2                            20.339793
# 3                            19.785503
# 4                            23.322729
#
#    Citizen Less than High School  Education_iqr_bc  \
# 0                                        24.630089
# 1                                        32.281033
# 2                                        25.234875
# 3                                        21.762171
# 4                                        28.541406
#
#    Citizen High School  Graduate_iqr_bc  \
# 0                             24.000518
# 1                             29.739068
# 2                             20.874192
# 3                             21.157500
# 4                             24.157094
#
#    Citizen Some College  Education_iqr_bc  Citizen College Degree_iqr_bc  \
# 0                               16.479497                      11.490486
# 1                               19.840588                      13.344409
# 2                               14.224701                       9.259826
# 3                               13.783455                       9.124356
# 4                               17.176145                      10.728366
#
#    Total Citizen Income_iqr_bc  Citizen No Income_iqr_bc  \
# 0                    23.869015                 23.328267
# 1                    28.533103                 28.987045
# 2                    21.010093                 20.802075
# 3                    20.468259                 21.055584
# 4                    24.091943                 26.050817
#
#    Citizen Income 1-9999_iqr_bc  Citizen Income 10000-14999_iqr_bc  \
# 0                     18.421893                          18.524565
# 1                     23.185884                          23.295029
# 2                     17.276611                          16.807982
# 3                     15.740163                          15.279015
# 4                     18.203866                          18.405152
#
#    Citizen Income 15000-24999_iqr_bc  Citizen Income 25000-34999_iqr_bc  \
# 0                          17.581352                          15.722328
# 1                          22.077047                          19.509204
# 2                          15.651747                          13.127005
# 3                          15.145000                          13.200998
# 4                          18.115533                          15.945382
#
#    Citizen Income 35000-49999_iqr_bc  Citizen Income 50000-64999_iqr_bc  \
# 0                          15.576571                          12.915181
# 1                          18.731187                          15.760823
# 2                          12.432640                          10.510263
# 3                          12.488176                          10.306108
# 4                          15.531037                          13.051448
#
#    Citizen Income over 75000_iqr_bc  One Race Population_iqr_bc  \
# 0                         11.724161                   25.614632
# 1                         13.091283                   31.147157
# 2                          8.897251                   20.486132
# 3                          8.789127                   21.611601
# 4                         10.522534                   26.642446
#
#    Other Race Alone_iqr_bc  Hispanic or Latino_iqr_bc  Median Age_iqr_bc  \
# 0                 9.789879                  27.852099          59.875297
# 1                12.226061                  33.325527          67.920227
# 2                 7.495874                  24.306261          63.780229
# 3                 7.075960                  23.623865          61.432726
# 4                 9.314651                  27.796283          63.780229
#
#    Male Median Age_iqr_bc  Female Median Age_iqr_bc  Total Households_iqr_bc  \
# 0               29.414196                125.477485                20.314439
# 1               32.739371                146.423770                24.444291
# 2               30.445959                143.443501                17.794244
# 3               29.890687                133.158383                17.102271
# 4               31.079735                135.586434                20.552950
#
#    Average Household Size_iqr_bc
# 0                       0.485672
# 1                       0.400228
# 2                       0.400228
# 3                       0.485672
# 4                       0.485672

# %% [markdown]
# ### 2.6 Visualize the original features (incl. imputed outliers with IQR) versus the normalized features
# ___

# %% [markdown]
# <b> 2.6.1 Create a function to make subplots/histograms of a list of columns from a pandas dataframe

# %%
def hist_subplots(df, col_list):   
    ############################
    # Define variables
    ############################
    # set counter for for-loop
    i = 1
    # set the rows of the subplots
    nrows = int(len(col_list)/4)
    # set the columns of the subplots
    ncols = 4
   
    ############################
    # make the figure before 
    # populating it with data
    ############################
    fig, ax = plt.subplots(nrows,ncols)
    
    ############################
    # layout options
    ############################
    # set the style
    # reference: https://matplotlib.org/3.1.1/gallery/style_sheets/style_sheets_reference.html
    #plt.style.use('fivethirtyeight')
    # set the figure size
    ## height
    fig.set_figheight(3*nrows)
    ## width
    fig.set_figwidth(15)
    ## set tight layout
    fig.tight_layout(pad=1, w_pad=0.1, h_pad=1)
    # adjust relative positions of subplots
    plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.8, wspace=0.25)
    # set title (first part bold and second part on newline not-bold)
    fig.suptitle(r"$\bf{Continuous\ Features\ }$" + '\n Before and After Normalization', y=0.95, fontsize=16)
    
    ############################
    # Loop through each subplot
    ############################
    # flatten the axis
    ax = ax.flatten()
    
    for i, col in enumerate(df[col_list]):
        
        # set color based on even number or uneven of i (if even number -> green, if odd number -> red)
        if (i % 2) == 0:
            # set color for even numbers
            color_hist = 'g'
        else:
            # set color for uneven numbers
            color_hist = 'r'
        
        # calculate the average (mu) and standard deviation (std)
        mu, std = norm.fit(df[col])
        skewness = skew(df[col])
        
        # plot the histogram for the subplot
        ax[i].hist(df[col], bins=25, density=False, alpha=0.8, color=color_hist)
       
        # Get part of the title in bold letters and another part normal - using matplotlib mathtext syntax bold letters => (r"$\bf{" + str(title_name) + "}$")
        # first convert title name to mathtext - take care of special characters with escape sign
        # without this piece of code, the title of the subplot, which is the columnane, would mess up the underscore sign and interpret it as a math symbol and would not take care of spaces correctly between words
        escaped_string = col.translate(str.maketrans({"_": r"\_",
                                           " ": r"\ "}))

        # set the title of each subplot
        ax[i].set_title(label=(r"$\bf{" + str(escaped_string) + "}$" + '\n mu = %.2f,  std = %.2f, \n skewness = %.2f' % (mu, std, skewness)),  fontweight='normal', size=12)

# %% [markdown]
# <b> 2.6.2 Apply the function to create subplots/histograms of the continuous features_

# %%
# define (pair-wise) list to plot histograms of, in the following sequence: 
# 1st the feature before normalization, 
# 2nd the feature after outlier removal (IQR)
# 3rd the feature after normalization etc

lst_continuous_cols = ['Total Population','Total Citizen Educated in US',
                       'Citizen Less than High School  Education','Citizen High School  Graduate',
                       'Citizen Some College  Education','Citizen College Degree','Citizen Graduate or Professional Degree',
                       'Total Citizen Income','Citizen No Income','Citizen Income 1-9999','Citizen Income 10000-14999',
                       'Citizen Income 15000-24999','Citizen Income 25000-34999','Citizen Income 35000-49999',
                       'Citizen Income 50000-64999','Citizen Income 65000-74999','Citizen Income over 75000',
                       'White Race','Black Race','Native American Race','Asian Race',
                       'Pacific Islander Race','Hispanic or Latino','Total Households',
                       'Average Household Size','Total Families', 'Total Confirmed Cases', 'Total Deaths',
                      'Case Rate per 1000', 'Death Rate 1000','Total Population_iqr','Total Citizen Educated in US_iqr',
                       'Citizen Less than High School  Education_iqr', 'Citizen High School  Graduate_iqr',
                        'Citizen Some College  Education_iqr','Citizen College Degree_iqr','Citizen Graduate or Professional Degree_iqr',
                        'Total Citizen Income_iqr','Citizen No Income_iqr','Citizen Income 1-9999_iqr',
                        'Citizen Income 10000-14999_iqr','Citizen Income 15000-24999_iqr','Citizen Income 25000-34999_iqr',
                       'Citizen Income 35000-49999_iqr','Citizen Income 50000-64999_iqr','Citizen Income 65000-74999_iqr',
                        'Citizen Income over 75000_iqr','White Race_iqr','Black Race_iqr',
                         'Native American Race_iqr', 'Asian Race_iqr','Pacific Islander Race_iqr',
                        'Hispanic or Latino_iqr','Median Age_iqr', 'Male Median Age_iqr', 
                       'Female Median Age_iqr','Total Households_iqr','Average Household Size_iqr',
                       'Total Families_iqr','Total Confirmed Cases_iqr','Total Deaths_iqr','Case Rate per 1000_iqr',
                       'Death Rate 1000_iqr', 'Total Population_iqr_bc',
                        'Total Citizen Educated in US_iqr_bc','Citizen Less than High School  Education_iqr_bc',
                        'Citizen High School  Graduate_iqr_bc','Citizen Some College  Education_iqr_bc',
                         'Citizen College Degree_iqr_bc','Total Citizen Income_iqr_bc','Citizen No Income_iqr_bc',
                          'Citizen Income 1-9999_iqr_bc','Citizen Income 10000-14999_iqr_bc','Citizen Income 15000-24999_iqr_bc',
                         'Citizen Income 25000-34999_iqr_bc','Citizen Income 35000-49999_iqr_bc',
                        'Citizen Income 50000-64999_iqr_bc','Citizen Income over 75000_iqr_bc',
                        'Hispanic or Latino_iqr_bc','Median Age_iqr_bc',
                         'Male Median Age_iqr_bc', 'Female Median Age_iqr_bc','Total Households_iqr_bc',
                       'Average Household Size_iqr_bc']

# %%
hist_subplots(df, lst_continuous_cols)

# %% [markdown]
# <b> 2.7 Skewness before and after the normalization

# %% [markdown]
# ## Skewness ##
# >* If skewness is less than −1 or greater than +1, the distribution is highly skewed.
# * If skewness is between −1 and −½ or between +½ and +1, the distribution is moderately skewed.
# * If skewness is between −½ and +½, the distribution is approximately symmetric.
# * A symmetrical distribution has a skewness of zero.
# * An asymmetrical distribution with a long tail to the right (higher values) has a positive skew.
# * An asymmetrical distribution with a long tail to the left (lower values) has a negative skew.

# %% [markdown]
# <b> 2.7.1 Create a function to get the skewness of a list of features, whereby the sequence is as follows: </b>
# * First item in the list is the original feature
# * Second item in the list is the normalized feature etc.

# %%
def skewness_cols(df, col_list):
    # create empty lists to append to in the for-loop
    lst_skewness_original = []
    lst_skewness_normalized = []
    lst_original_cols = []
    lst_normalized_cols = []
    
    lst_original_cols_skewness_description = []
    lst_normalized_cols_skewness_description = []
    
    # iterate through the columns in the list and determine skewness for each and create a new pandas dataframe
    for i, col in enumerate(df[col_list]):
        skewness = skew(df[col])
        if i % 2 == 0:
            lst_skewness_original.append(skewness)
            lst_original_cols.append(col)
            if -0.5 < skewness < 0.5:
                lst_original_cols_skewness_description.append('~symmetric')
            elif  -0.5 < skewness < -1.0 or 0.5 < skewness < 1.0:
                lst_original_cols_skewness_description.append('moderate')
            else:
                lst_original_cols_skewness_description.append('high')
        else:
            lst_skewness_normalized.append(skewness)
            lst_normalized_cols.append(col)
            if -0.5 < skewness < 0.5:
                lst_normalized_cols_skewness_description.append('~symmetric')
            elif  -0.5 < skewness < -1.0 or 0.5 < skewness < 1.0:
                lst_normalized_cols_skewness_description.append('moderate')
            else:
                lst_normalized_cols_skewness_description.append('high')
            
    # convert 4 lists into a pandas dataframe
    df_skewness = pd.DataFrame([lst_original_cols, lst_skewness_original, lst_original_cols_skewness_description, 
                                lst_normalized_cols, lst_skewness_normalized, lst_normalized_cols_skewness_description]).T
    # add column headers
    df_skewness.columns = ['Original Feature', 'Skewness', 'Distribution Skewness', 'Normalized Feature', 'Skewness', 'Distribution Skewness']
    return(df_skewness)

# %% [markdown]
# <b> 2.7.2 Apply function to test the skewness of continuous features

# %%
# apply function
# show dataframe with skewness before and after normalization for continuous features
skewness_cols(df, lst_continuous_cols)
# Out:
#                                 Original Feature    Skewness  \
# 0                               Total Population     14.3599
# 1       Citizen Less than High School  Education     22.8189
# 2                Citizen Some College  Education     12.9807
# 3        Citizen Graduate or Professional Degree     10.7187
# 4                              Citizen No Income     17.6548
# 5                     Citizen Income 10000-14999     17.1424
# 6                     Citizen Income 25000-34999     12.9032
# 7                     Citizen Income 50000-64999     11.3348
# 8                      Citizen Income over 75000     11.7837
# 9                                     Black Race     11.6571
# 10                                    Asian Race      35.424
# 11                            Hispanic or Latino     9.51871
# 12                        Average Household Size    0.459784
# 13                         Total Confirmed Cases     14.1365
# 14                            Case Rate per 1000     8.42691
# 15                          Total Population_iqr     1.14894
# 16  Citizen Less than High School  Education_iqr     1.13186
# 17           Citizen Some College  Education_iqr     1.15806
# 18   Citizen Graduate or Professional Degree_iqr     1.16469
# 19                         Citizen No Income_iqr      1.1501
# 20                Citizen Income 10000-14999_iqr     1.15475
# 21                Citizen Income 25000-34999_iqr     1.16767
# 22                Citizen Income 50000-64999_iqr     1.15484
# 23                 Citizen Income over 75000_iqr     1.17516
# 24                                Black Race_iqr     1.17709
# 25                                Asian Race_iqr     1.39385
# 26                        Hispanic or Latino_iqr      1.1606
# 27                           Male Median Age_iqr   0.0230707
# 28                          Total Households_iqr     1.15195
# 29                            Total Families_iqr     1.13434
# 30                              Total Deaths_iqr     1.94899
# 31                           Death Rate 1000_iqr     1.79063
# 32           Total Citizen Educated in US_iqr_bc   -0.036345
# 33          Citizen High School  Graduate_iqr_bc  -0.0459634
# 34                 Citizen College Degree_iqr_bc  -0.0218644
# 35                      Citizen No Income_iqr_bc  -0.0629528
# 36             Citizen Income 10000-14999_iqr_bc  -0.0430476
# 37             Citizen Income 25000-34999_iqr_bc  -0.0369849
# 38             Citizen Income 50000-64999_iqr_bc  -0.0343615
# 39                     Hispanic or Latino_iqr_bc  -0.0418237
# 40                        Male Median Age_iqr_bc -0.00123517
# 41                       Total Households_iqr_bc  -0.0353255
#
#    Distribution Skewness                               Normalized Feature  \
# 0                   high                     Total Citizen Educated in US
# 1                   high                    Citizen High School  Graduate
# 2                   high                           Citizen College Degree
# 3                   high                             Total Citizen Income
# 4                   high                            Citizen Income 1-9999
# 5                   high                       Citizen Income 15000-24999
# 6                   high                       Citizen Income 35000-49999
# 7                   high                       Citizen Income 65000-74999
# 8                   high                                       White Race
# 9                   high                             Native American Race
# 10                  high                            Pacific Islander Race
# 11                  high                                 Total Households
# 12            ~symmetric                                   Total Families
# 13                  high                                     Total Deaths
# 14                  high                                  Death Rate 1000
# 15                  high                 Total Citizen Educated in US_iqr
# 16                  high                Citizen High School  Graduate_iqr
# 17                  high                       Citizen College Degree_iqr
# 18                  high                         Total Citizen Income_iqr
# 19                  high                        Citizen Income 1-9999_iqr
# 20                  high                   Citizen Income 15000-24999_iqr
# 21                  high                   Citizen Income 35000-49999_iqr
# 22                  high                   Citizen Income 65000-74999_iqr
# 23                  high                                   White Race_iqr
# 24                  high                         Native American Race_iqr
# 25                  high                        Pacific Islander Race_iqr
# 26                  high                                   Median Age_iqr
# 27            ~symmetric                            Female Median Age_iqr
# 28                  high                       Average Household Size_iqr
# 29                  high                        Total Confirmed Cases_iqr
# 30                  high                           Case Rate per 1000_iqr
# 31                  high                          Total Population_iqr_bc
# 32            ~symmetric  Citizen Less than High School  Education_iqr_bc
# 33            ~symmetric           Citizen Some College  Education_iqr_bc
# 34            ~symmetric                      Total Citizen Income_iqr_bc
# 35            ~symmetric                     Citizen Income 1-9999_iqr_bc
# 36            ~symmetric                Citizen Income 15000-24999_iqr_bc
# 37            ~symmetric                Citizen Income 35000-49999_iqr_bc
# 38            ~symmetric                 Citizen Income over 75000_iqr_bc
# 39            ~symmetric                                Median Age_iqr_bc
# 40            ~symmetric                         Female Median Age_iqr_bc
# 41            ~symmetric                    Average Household Size_iqr_bc
#
#       Skewness Distribution Skewness
# 0      13.9114                  high
# 1      11.8133                  high
# 2      12.7207                  high
# 3      14.0456                  high
# 4      13.9306                  high
# 5      14.9978                  high
# 6      11.8196                  high
# 7      11.3658                  high
# 8      11.5022                  high
# 9      22.1968                  high
# 10     30.4612                  high
# 11      12.639                  high
# 12     14.4214                  high
# 13     17.1776                  high
# 14     4.07293                  high
# 15     1.15304                  high
# 16     1.14193                  high
# 17     1.16329                  high
# 18     1.14865                  high
# 19     1.16687                  high
# 20      1.1634                  high
# 21     1.14974                  high
# 22     1.17873                  high
# 23     1.23584                  high
# 24     1.21964                  high
# 25     1.24072                  high
# 26  -0.0691551            ~symmetric
# 27   -0.154894            ~symmetric
# 28    0.459784            ~symmetric
# 29     1.25741                  high
# 30     1.18364                  high
# 31  -0.0372107            ~symmetric
# 32  -0.0644591            ~symmetric
# 33  -0.0315862            ~symmetric
# 34  -0.0371671            ~symmetric
# 35  -0.0386259            ~symmetric
# 36  -0.0393482            ~symmetric
# 37  -0.0368087            ~symmetric
# 38  -0.0252207            ~symmetric
# 39 -0.00137723            ~symmetric
# 40 -0.00484888            ~symmetric
# 41   0.0729573            ~symmetric

# %% [markdown]
# <a id = "44"> <h2> 3. Standardization Z-score </h2> </a>
# ___

# %% [markdown]
# <b> _Convert the features values to the same numeric level._ </b>
# <br> This is also called: Data Scaling.
#
# * Z-score standardization is used here, which is calculated as shown on [this page](https://www.statisticshowto.datasciencecentral.com/probability-and-statistics/z-score/).
# <br> _Requirement:_ First normalize the data before you standardize with z-score

# %% [markdown]
# <b> 3.1 Create a function for the z-score

# %%
def replace_columns_zscore(df, column_list): 
    for my_col in column_list:      
        # combine old column name with a suffix for the new name of the column
        suffix = '_zscore'
        my_new_col = ''.join([my_col, suffix])
        # create a new column with the name: (column name + suffix)
        df[my_new_col] = df[my_col]
        # apply zscore to new column
        df[my_new_col] = stats.zscore(df[my_new_col])
        
        # 2nd method to apply zscore without the scipy.stats.zscore package
        #df[my_new_col] = (df[my_new_col] - df[my_new_col].mean())/df[my_new_col].std(ddof=0)

# %% [markdown]
# <b> 3.2 Apply the function z-score to each normalized continuous feature

# %%
lst_continuous_cols = ['Total Population_iqr_bc',
                        'Total Citizen Educated in US_iqr_bc','Citizen Less than High School  Education_iqr_bc',
                        'Citizen High School  Graduate_iqr_bc','Citizen Some College  Education_iqr_bc',
                         'Citizen College Degree_iqr_bc','Total Citizen Income_iqr_bc','Citizen No Income_iqr_bc',
                          'Citizen Income 1-9999_iqr_bc','Citizen Income 10000-14999_iqr_bc','Citizen Income 15000-24999_iqr_bc',
                         'Citizen Income 25000-34999_iqr_bc','Citizen Income 35000-49999_iqr_bc',
                        'Citizen Income 50000-64999_iqr_bc','Citizen Income over 75000_iqr_bc',
                        'Hispanic or Latino_iqr_bc','Median Age_iqr_bc',
                         'Male Median Age_iqr_bc', 'Female Median Age_iqr_bc','Total Households_iqr_bc',
                       'Average Household Size_iqr_bc']

replace_columns_zscore(df=df, column_list=lst_continuous_cols)

# %% [markdown]
# <b> 3.3 Test if columns were created

# %%
# test if all additional columns were created with a suffix _zscore
zscore_cols = [col for col in df.columns if '_zscore' in col]
# show columns where names contains the string 'iqr'
print('number of continuous features:', len(zscore_cols))
zscore_cols
# Out:
# number of continuous features: 21
# ['Total Population_iqr_bc_zscore',
#  'Total Citizen Educated in US_iqr_bc_zscore',
#  'Citizen Less than High School  Education_iqr_bc_zscore',
#  'Citizen High School  Graduate_iqr_bc_zscore',
#  'Citizen Some College  Education_iqr_bc_zscore',
#  'Citizen College Degree_iqr_bc_zscore',
#  'Total Citizen Income_iqr_bc_zscore',
#  'Citizen No Income_iqr_bc_zscore',
#  'Citizen Income 1-9999_iqr_bc_zscore',
#  'Citizen Income 10000-14999_iqr_bc_zscore',
#  'Citizen Income 15000-24999_iqr_bc_zscore',
#  'Citizen Income 25000-34999_iqr_bc_zscore',
#  'Citizen Income 35000-49999_iqr_bc_zscore',
#  'Citizen Income 50000-64999_iqr_bc_zscore',
#  'Citizen Income over 75000_iqr_bc_zscore',
#  'Hispanic or Latino_iqr_bc_zscore',
#  'Median Age_iqr_bc_zscore',
#  'Male Median Age_iqr_bc_zscore',
#  'Female Median Age_iqr_bc_zscore',
#  'Total Households_iqr_bc_zscore',
#  'Average Household Size_iqr_bc_zscore']

# %% [markdown]
# <b> 3.4 Test if the zscore changed the mean and standard deviation to zero for the features

# %%
df[zscore_cols].describe().loc[['mean', 'std']].round(2)
# Out:
#       Total Population_iqr_bc_zscore  \
# mean                            -0.0
# std                              1.0
#
#       Total Citizen Educated in US_iqr_bc_zscore  \
# mean                                        -0.0
# std                                          1.0
#
#       Citizen Less than High School  Education_iqr_bc_zscore  \
# mean                                                0.0
# std                                                 1.0
#
#       Citizen High School  Graduate_iqr_bc_zscore  \
# mean                                          0.0
# std                                           1.0
#
#       Citizen Some College  Education_iqr_bc_zscore  \
# mean                                           -0.0
# std                                             1.0
#
#       Citizen College Degree_iqr_bc_zscore  \
# mean                                  -0.0
# std                                    1.0
#
#       Total Citizen Income_iqr_bc_zscore  Citizen No Income_iqr_bc_zscore  \
# mean                                 0.0                             -0.0
# std                                  1.0                              1.0
#
#       Citizen Income 1-9999_iqr_bc_zscore  \
# mean                                  0.0
# std                                   1.0
#
#       Citizen Income 10000-14999_iqr_bc_zscore  \
# mean                                       0.0
# std                                        1.0
#
#       Citizen Income 15000-24999_iqr_bc_zscore  \
# mean                                      -0.0
# std                                        1.0
#
#       Citizen Income 25000-34999_iqr_bc_zscore  \
# mean                                       0.0
# std                                        1.0
#
#       Citizen Income 35000-49999_iqr_bc_zscore  \
# mean                                      -0.0
# std                                        1.0
#
#       Citizen Income 50000-64999_iqr_bc_zscore  \
# mean                                      -0.0
# std                                        1.0
#
#       Citizen Income over 75000_iqr_bc_zscore  \
# mean                                     -0.0
# std                                       1.0
#
#       Hispanic or Latino_iqr_bc_zscore  Median Age_iqr_bc_zscore  \
# mean                               0.0                       0.0
# std                                1.0                       1.0
#
#       Male Median Age_iqr_bc_zscore  Female Median Age_iqr_bc_zscore  \
# mean                           -0.0                             -0.0
# std                             1.0                              1.0
#
#       Total Households_iqr_bc_zscore  Average Household Size_iqr_bc_zscore
# mean                             0.0                                  -0.0
# std                              1.0                                   1.0

# %% [markdown]
# <a id = "55"> <h2> 4. Correlation Analysis </h2> </a>
# ___

# %% [markdown]
# ### Pairwise Pearson's Correlation between Continuous Features
# ___

# %% [markdown]
# <b> 4.1 Define correlation matrix (absolute correlation values)

# %%
# source: https://machinelearningmastery.com/feature-selection-with-real-and-categorical-data/
corr_matrix = df[lst_continuous_cols].corr(method='pearson').abs()
# show correlation matrix
#corr_matrix

# %% [markdown]
# <b> 4.2 Creat a function to get a list of the Pearson's pairwise correlations higher than a threshold value (set to 0.5)

# %%
# create a function to drop the redundant pairs in the correlation matrix (all correlations are mirrored diagionaly)
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr(method='pearson').abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print('--------------------------------------------------------------------------------------------')
print('               Top Absolute Pearson`s Correlations between Continuous Features (>0.5)       ')
print('--------------------------------------------------------------------------------------------')

# only show correlations higher or equal to 0.5
get_top_abs_correlations(corr_matrix, n=10000)[get_top_abs_correlations(corr_matrix, n=10000) >= 0.5]

# Our threshold is set to 0.5 for dropping either one of the highly correlated variables
# Out:
# --------------------------------------------------------------------------------------------
#                Top Absolute Pearson`s Correlations between Continuous Features (>0.5)
# --------------------------------------------------------------------------------------------
# Total Population_iqr_bc              Total Citizen Income_iqr_bc      0.999978
# Total Citizen Income_iqr_bc          Total Households_iqr_bc          0.999922
# Total Citizen Educated in US_iqr_bc  Total Households_iqr_bc          0.999913
# Total Population_iqr_bc              Total Households_iqr_bc          0.999865
# Citizen Income 25000-34999_iqr_bc    Total Households_iqr_bc          0.999847
#                                                                         ...
# Citizen Income 1-9999_iqr_bc         Male Median Age_iqr_bc           0.737632
# Citizen No Income_iqr_bc             Male Median Age_iqr_bc           0.731379
# Female Median Age_iqr_bc             Average Household Size_iqr_bc    0.571590
# Median Age_iqr_bc                    Average Household Size_iqr_bc    0.548532
# Male Median Age_iqr_bc               Average Household Size_iqr_bc    0.522347
# Length: 210, dtype: float64

# %% [markdown]
# <b> 4.3 Visualize the Pairwise correlation between continuous features

# %%
# Create a heatmap from our Pearson's correlation matrix
# source: https://seaborn.pydata.org/generated/seaborn.heatmap.html
mask = np.zeros_like(corr_matrix)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("darkgrid"):
    f, ax = plt.subplots(figsize=(12, 10))
    # plot a seaborn heatmap with labels inside (annot=True), a title for the bar (cbar_kws) and colorstyle (cmap)
    ax = sns.heatmap(corr_matrix, mask=mask, vmax=1, square=True, annot=True, cbar_kws={'label': 'Pairwise Correlation \n (1=Perfect Correlation, 0=No Correlation)'}, cmap="coolwarm")

# %% [markdown]
# # Take Away
# - 'Total Households' has a high correlation with multiple feature. We will removes this feature when running the Linear Regression Model.

# %%
df_lingreg = pd.DataFrame (df, columns =['Total Population_iqr_bc',
                        'Total Citizen Educated in US_iqr_bc','Citizen Less than High School  Education_iqr_bc',
                        'Citizen High School  Graduate_iqr_bc','Citizen Some College  Education_iqr_bc',
                         'Citizen College Degree_iqr_bc','Total Citizen Income_iqr_bc','Citizen No Income_iqr_bc',
                          'Citizen Income 1-9999_iqr_bc','Citizen Income 10000-14999_iqr_bc','Citizen Income 15000-24999_iqr_bc',
                         'Citizen Income 25000-34999_iqr_bc','Citizen Income 35000-49999_iqr_bc',
                        'Citizen Income 50000-64999_iqr_bc','Citizen Income over 75000_iqr_bc',
                        'Hispanic or Latino_iqr_bc','Median Age_iqr_bc',
                         'Male Median Age_iqr_bc', 'Female Median Age_iqr_bc',
                       'Average Household Size_iqr_bc','Total Confirmed Cases', 'Total Deaths',
                      'Case Rate per 1000', 'Death Rate 1000'])

df_lingreg.head()
# Out:
#    Total Population_iqr_bc  Total Citizen Educated in US_iqr_bc  \
# 0                25.393962                            23.030193
# 1                30.283200                            27.544206
# 2                22.442567                            20.339793
# 3                21.710978                            19.785503
# 4                25.616212                            23.322729
#
#    Citizen Less than High School  Education_iqr_bc  \
# 0                                        24.630089
# 1                                        32.281033
# 2                                        25.234875
# 3                                        21.762171
# 4                                        28.541406
#
#    Citizen High School  Graduate_iqr_bc  \
# 0                             24.000518
# 1                             29.739068
# 2                             20.874192
# 3                             21.157500
# 4                             24.157094
#
#    Citizen Some College  Education_iqr_bc  Citizen College Degree_iqr_bc  \
# 0                               16.479497                      11.490486
# 1                               19.840588                      13.344409
# 2                               14.224701                       9.259826
# 3                               13.783455                       9.124356
# 4                               17.176145                      10.728366
#
#    Total Citizen Income_iqr_bc  Citizen No Income_iqr_bc  \
# 0                    23.869015                 23.328267
# 1                    28.533103                 28.987045
# 2                    21.010093                 20.802075
# 3                    20.468259                 21.055584
# 4                    24.091943                 26.050817
#
#    Citizen Income 1-9999_iqr_bc  Citizen Income 10000-14999_iqr_bc  \
# 0                     18.421893                          18.524565
# 1                     23.185884                          23.295029
# 2                     17.276611                          16.807982
# 3                     15.740163                          15.279015
# 4                     18.203866                          18.405152
#
#    Citizen Income 15000-24999_iqr_bc  Citizen Income 25000-34999_iqr_bc  \
# 0                          17.581352                          15.722328
# 1                          22.077047                          19.509204
# 2                          15.651747                          13.127005
# 3                          15.145000                          13.200998
# 4                          18.115533                          15.945382
#
#    Citizen Income 35000-49999_iqr_bc  Citizen Income 50000-64999_iqr_bc  \
# 0                          15.576571                          12.915181
# 1                          18.731187                          15.760823
# 2                          12.432640                          10.510263
# 3                          12.488176                          10.306108
# 4                          15.531037                          13.051448
#
#    Citizen Income over 75000_iqr_bc  Hispanic or Latino_iqr_bc  \
# 0                         11.724161                  27.852099
# 1                         13.091283                  33.325527
# 2                          8.897251                  24.306261
# 3                          8.789127                  23.623865
# 4                         10.522534                  27.796283
#
#    Median Age_iqr_bc  Male Median Age_iqr_bc  Female Median Age_iqr_bc  \
# 0          59.875297               29.414196                125.477485
# 1          67.920227               32.739371                146.423770
# 2          63.780229               30.445959                143.443501
# 3          61.432726               29.890687                133.158383
# 4          63.780229               31.079735                135.586434
#
#    Average Household Size_iqr_bc  Total Confirmed Cases  Total Deaths  \
# 0                       0.485672                      0             0
# 1                       0.400228                    400             8
# 2                       0.400228                    401             9
# 3                       0.485672                    263             1
# 4                       0.485672                    121             1
#
#    Case Rate per 1000  Death Rate 1000
# 0               7.330            0.147
# 1               2.200            0.049
# 2               9.579            0.036
# 3               5.280            0.044
# 4               2.268            0.017

# %% [markdown]
# <a id = "66"> <h2> 5. Feature Selection </h2> </a>
# ___

# %% [markdown]
# ## SelectKBest:
# - Removes all but the highest scoring K features
# - SelectKBest only works with positive features!
# <br> _source:_ https://scikit-learn.org/stable/modules/feature_selection.html

# %% [markdown]
# __Target Variable: Case Rate Categories__

# %% [markdown]
# <b> 6.3.1  Define positive features to apply SelectKBest to

# %%
# ------------------------------------------------------------------------------------------------
# find all features that have non-negative values and make a list of it
# in order to use Kbest Feature Selection
# ------------------------------------------------------------------------------------------------
# create a condition whereby you test which columns have a minimum bigger or equal to zero
condition_nonnegative_values = df[lst_continuous_cols].min() >= 0

# only show the features where condition equals True in a 2D array (columnname, True/False)
features_nonnegative_values = condition_nonnegative_values[condition_nonnegative_values == True]

# create a list with only positive features to use for Kbest method
list_kbest_features = features_nonnegative_values.index.tolist()

# %% [markdown]
# <b> 6.3.2 Define Features (X) and the Target (Y)

# %%
# ---------------------------------
# Define dependent variables
# ---------------------------------


list_kbest_features = ['Total Population','Total Citizen Educated in US',
                       'Citizen Less than High School  Education','Citizen High School  Graduate',
                       'Citizen Some College  Education','Citizen College Degree','Citizen Graduate or Professional Degree',
                       'Total Citizen Income','Citizen No Income','Citizen Income 1-9999','Citizen Income 10000-14999',
                       'Citizen Income 15000-24999','Citizen Income 25000-34999','Citizen Income 35000-49999',
                       'Citizen Income 50000-64999','Citizen Income 65000-74999','Citizen Income over 75000',
                       'White Race','Black Race','Native American Race','Asian Race',
                       'Pacific Islander Race','Hispanic or Latino','Total Households',
                       'Average Household Size','Total Families','Total Population_iqr','Total Citizen Educated in US_iqr',
                       'Citizen Less than High School  Education_iqr', 'Citizen High School  Graduate_iqr',
                        'Citizen Some College  Education_iqr','Citizen College Degree_iqr','Citizen Graduate or Professional Degree_iqr',
                        'Total Citizen Income_iqr','Citizen No Income_iqr','Citizen Income 1-9999_iqr',
                        'Citizen Income 10000-14999_iqr','Citizen Income 15000-24999_iqr','Citizen Income 25000-34999_iqr',
                       'Citizen Income 35000-49999_iqr','Citizen Income 50000-64999_iqr','Citizen Income 65000-74999_iqr',
                        'Citizen Income over 75000_iqr','White Race_iqr','Black Race_iqr',
                         'Native American Race_iqr', 'Asian Race_iqr','Pacific Islander Race_iqr',
                        'Hispanic or Latino_iqr','Median Age_iqr', 'Male Median Age_iqr', 
                       'Female Median Age_iqr','Total Households_iqr','Average Household Size_iqr',
                       'Total Families_iqr', 'Total Population_iqr_bc',
                        'Total Citizen Educated in US_iqr_bc','Citizen Less than High School  Education_iqr_bc',
                        'Citizen High School  Graduate_iqr_bc','Citizen Some College  Education_iqr_bc',
                         'Citizen College Degree_iqr_bc','Total Citizen Income_iqr_bc','Citizen No Income_iqr_bc',
                          'Citizen Income 1-9999_iqr_bc','Citizen Income 10000-14999_iqr_bc','Citizen Income 15000-24999_iqr_bc',
                         'Citizen Income 25000-34999_iqr_bc','Citizen Income 35000-49999_iqr_bc',
                        'Citizen Income 50000-64999_iqr_bc','Citizen Income over 75000_iqr_bc',
                        'Hispanic or Latino_iqr_bc','Median Age_iqr_bc',
                         'Male Median Age_iqr_bc', 'Female Median Age_iqr_bc','Total Households_iqr_bc',
                       'Average Household Size_iqr_bc']


# Define dependent variables and save it as a numpy array
X = df[list_kbest_features].to_numpy()
# ---------------------------------
# Define independent variable: "Case rate Categories"
# ---------------------------------
Y = df['Case Rate Categories']

# %% [markdown]
# <b> 6.3.3 Apply SelectKBest

# %%
# Feature extraction
test = SelectKBest(score_func=chi2, k=4)
fit = test.fit(X, Y)

# Summarize scores
#np.set_printoptions(precision=3)
#print(fit.scores_)

# %% [markdown]
# <b> 6.3.4 Show Results Kbest

# %%
# create a dataframe with scores ranked from large to small scores for features (transpose dataframe)
df_kbest_features = pd.DataFrame([list_kbest_features, fit.scores_.tolist()]).transpose()

# rename columns of dataframe
df_kbest_features.columns = ['Feature', 'Score']

## order by Score descending and reset index after sorting
df_kbest_rank = df_kbest_features.sort_values(by=['Score'], ascending=False).reset_index(drop=True)

# show dataframe (top 20 features of Kbest)
df_kbest_rank.head(23)
# Out:
#                                      Feature        Score
# 0                           Total Population  2.09317e+08
# 1                       Total Citizen Income   1.7745e+08
# 2                         Hispanic or Latino  1.63335e+08
# 3               Total Citizen Educated in US  1.48702e+08
# 4                           Total Households  7.64995e+07
# 5                                 White Race  6.37375e+07
# 6                             Total Families  4.93131e+07
# 7                       Total Population_iqr  4.23276e+07
# 8                     Hispanic or Latino_iqr  3.92289e+07
# 9              Citizen High School  Graduate  3.66977e+07
# 10                  Total Citizen Income_iqr   3.5082e+07
# 11           Citizen Some College  Education  3.49499e+07
# 12                    Citizen College Degree  3.37021e+07
# 13                 Citizen Income over 75000  3.25606e+07
# 14                         Citizen No Income  2.92939e+07
# 15          Total Citizen Educated in US_iqr   2.8874e+07
# 16                     Citizen Income 1-9999  2.64229e+07
# 17                     Pacific Islander Race  2.52274e+07
# 18                      Native American Race   2.5218e+07
# 19   Citizen Graduate or Professional Degree  2.52148e+07
# 20  Citizen Less than High School  Education  2.36052e+07
# 21                Citizen Income 15000-24999  2.15716e+07
# 22                Citizen Income 35000-49999  1.89725e+07

# %% [markdown]
# __Only Keep Top 21 Features & Target Variables__

# %% [markdown]
# _Define a new dataframe to use based on Feature Selection with 'Case Rate Categories' as the Target Variable._

# %%
df_features_case = pd.DataFrame (df, columns =['Total Population','Total Citizen Income','Hispanic or Latino','Total Citizen Educated in US',
                                    'Total Households','White Race','Total Families','Citizen College Degree','Citizen Some College  Education',
                                    'Citizen Income over 75000','Citizen High School  Graduate',
                                    'Citizen No Income','Pacific Islander Race','Citizen Graduate or Professional Degree',
                                    'Citizen Income 1-9999','Citizen Less than High School  Education',
                                     'Citizen Income 15000-24999','Citizen Income 15000-24999','Citizen Income 35000-49999',
                                    'Case Rate Categories'])


df_features_case.head()
# Out:
#    Total Population  Total Citizen Income  Hispanic or Latino  \
# 0             54571                 44109               53261
# 1            182265                166364              174273
# 2             27457                 21627               26070
# 3             22915                 18743               22509
# 4             57322                 46501               52696
#
#    Total Citizen Educated in US  Total Households  White Race  Total Families  \
# 0                         36757             20221        9643           14613
# 1                        143022             73180       17105           41898
# 2                         18434              9820       12875            6015
# 3                         15859              7953        5047            5201
# 4                         39475             21578         761           14106
#
#    Citizen College Degree  Citizen Some College  Education  \
# 0                    5316                            10697
# 1                   29237                            45286
# 2                    1403                             4707
# 3                    1289                             3971
# 4                    3416                            13583
#
#    Citizen Income over 75000  Citizen High School  Graduate  \
# 0                       5298                          12363
# 1                      17954                          39771
# 2                       1019                           6549
# 3                        953                           6958
# 4                       2690                          12740
#
#    Citizen No Income  Pacific Islander Race  \
# 0               6377                    466
# 1              20201                   3631
# 2               3968                    894
# 3               4170                    185
# 4              10165                   2347
#
#    Citizen Graduate or Professional Degree  Citizen Income 1-9999  \
# 0                                     3860                   6955
# 1                                    14731                  25080
# 2                                      815                   5090
# 3                                      808                   3268
# 4                                     1756                   6561
#
#    Citizen Less than High School  Education  Citizen Income 15000-24999  \
# 0                                      4521                        6000
# 1                                     13997                       26852
# 2                                      4960                        3419
# 3                                      2833                        2926
# 4                                      7980                        6956
#
#    Citizen Income 15000-24999  Citizen Income 35000-49999 Case Rate Categories
# 0                        6000                        5727                    2
# 1                       26852                       21502                    2
# 2                        3419                        1820                    3
# 3                        2926                        1860                    2
# 4                        6956                        5639                    2

# %% [markdown]
# ## SelectKBest:
# - Removes all but the highest scoring K features
# - SelectKBest only works with positive features!
# <br> _source:_ https://scikit-learn.org/stable/modules/feature_selection.html

# %% [markdown]
# __Target Variable: Death Rate Categories__

# %% [markdown]
# <b> 6.3.1  Define positive features to apply SelectKBest to

# %%
# ------------------------------------------------------------------------------------------------
# find all features that have non-negative values and make a list of it
# in order to use Kbest Feature Selection
# ------------------------------------------------------------------------------------------------
# create a condition whereby you test which columns have a minimum bigger or equal to zero
condition_nonnegative_values = df[lst_continuous_cols].min() >= 0

# only show the features where condition equals True in a 2D array (columnname, True/False)
features_nonnegative_values = condition_nonnegative_values[condition_nonnegative_values == True]

# create a list with only positive features to use for Kbest method
list_kbest_features = features_nonnegative_values.index.tolist()

# %% [markdown]
# <b> 6.3.2 Define Features (X) and the Target (Y)

# %%
# ---------------------------------
# Define dependent variables
# ---------------------------------


list_kbest_features = ['Total Population','Total Citizen Educated in US',
                       'Citizen Less than High School  Education','Citizen High School  Graduate',
                       'Citizen Some College  Education','Citizen College Degree','Citizen Graduate or Professional Degree',
                       'Total Citizen Income','Citizen No Income','Citizen Income 1-9999','Citizen Income 10000-14999',
                       'Citizen Income 15000-24999','Citizen Income 25000-34999','Citizen Income 35000-49999',
                       'Citizen Income 50000-64999','Citizen Income 65000-74999','Citizen Income over 75000',
                       'White Race','Black Race','Native American Race','Asian Race',
                       'Pacific Islander Race','Hispanic or Latino','Total Households',
                       'Average Household Size','Total Families','Total Population_iqr','Total Citizen Educated in US_iqr',
                       'Citizen Less than High School  Education_iqr', 'Citizen High School  Graduate_iqr',
                        'Citizen Some College  Education_iqr','Citizen College Degree_iqr','Citizen Graduate or Professional Degree_iqr',
                        'Total Citizen Income_iqr','Citizen No Income_iqr','Citizen Income 1-9999_iqr',
                        'Citizen Income 10000-14999_iqr','Citizen Income 15000-24999_iqr','Citizen Income 25000-34999_iqr',
                       'Citizen Income 35000-49999_iqr','Citizen Income 50000-64999_iqr','Citizen Income 65000-74999_iqr',
                        'Citizen Income over 75000_iqr','White Race_iqr','Black Race_iqr',
                         'Native American Race_iqr', 'Asian Race_iqr','Pacific Islander Race_iqr',
                        'Hispanic or Latino_iqr','Median Age_iqr', 'Male Median Age_iqr', 
                       'Female Median Age_iqr','Total Households_iqr','Average Household Size_iqr',
                       'Total Families_iqr', 'Total Population_iqr_bc',
                        'Total Citizen Educated in US_iqr_bc','Citizen Less than High School  Education_iqr_bc',
                        'Citizen High School  Graduate_iqr_bc','Citizen Some College  Education_iqr_bc',
                         'Citizen College Degree_iqr_bc','Total Citizen Income_iqr_bc','Citizen No Income_iqr_bc',
                          'Citizen Income 1-9999_iqr_bc','Citizen Income 10000-14999_iqr_bc','Citizen Income 15000-24999_iqr_bc',
                         'Citizen Income 25000-34999_iqr_bc','Citizen Income 35000-49999_iqr_bc',
                        'Citizen Income 50000-64999_iqr_bc','Citizen Income over 75000_iqr_bc',
                        'Hispanic or Latino_iqr_bc','Median Age_iqr_bc',
                         'Male Median Age_iqr_bc', 'Female Median Age_iqr_bc','Total Households_iqr_bc',
                       'Average Household Size_iqr_bc']


# Define dependent variables and save it as a numpy array
X = df[list_kbest_features].to_numpy()
# ---------------------------------
# Define independent variable: "Death Rate Categories"
# ---------------------------------
Y = df['Death Rate Categories']

# %% [markdown]
# <b> 6.3.3 Apply SelectKBest

# %%
# Feature extraction
test = SelectKBest(score_func=chi2, k=4)
fit = test.fit(X, Y)

# Summarize scores
#np.set_printoptions(precision=3)
#print(fit.scores_)

# %% [markdown]
# <b> 6.3.4 Show Results Kbest

# %%
# create a dataframe with scores ranked from large to small scores for features (transpose dataframe)
df_kbest_features = pd.DataFrame([list_kbest_features, fit.scores_.tolist()]).transpose()

# rename columns of dataframe
df_kbest_features.columns = ['Feature', 'Score']

## order by Score descending and reset index after sorting
df_kbest_rank = df_kbest_features.sort_values(by=['Score'], ascending=False).reset_index(drop=True)

# show dataframe (top 20 features of Kbest)
df_kbest_rank.head(23)
# Out:
#                                      Feature        Score
# 0                           Total Population  2.09317e+08
# 1                       Total Citizen Income   1.7745e+08
# 2                         Hispanic or Latino  1.63335e+08
# 3               Total Citizen Educated in US  1.48702e+08
# 4                           Total Households  7.64995e+07
# 5                                 White Race  6.37375e+07
# 6                             Total Families  4.93131e+07
# 7                       Total Population_iqr  4.23276e+07
# 8                     Hispanic or Latino_iqr  3.92289e+07
# 9              Citizen High School  Graduate  3.66977e+07
# 10                  Total Citizen Income_iqr   3.5082e+07
# 11           Citizen Some College  Education  3.49499e+07
# 12                    Citizen College Degree  3.37021e+07
# 13                 Citizen Income over 75000  3.25606e+07
# 14                         Citizen No Income  2.92939e+07
# 15          Total Citizen Educated in US_iqr   2.8874e+07
# 16                     Citizen Income 1-9999  2.64229e+07
# 17                     Pacific Islander Race  2.52274e+07
# 18                      Native American Race   2.5218e+07
# 19   Citizen Graduate or Professional Degree  2.52148e+07
# 20  Citizen Less than High School  Education  2.36052e+07
# 21                Citizen Income 15000-24999  2.15716e+07
# 22                Citizen Income 35000-49999  1.89725e+07

# %% [markdown]
# __Only Keep Top 21 Features & Add Target Variables__

# %% [markdown]
# _Define a new dataframe to use based on Feature Selection with 'Case Rate Categories' as the Target Variable._

# %%
df_features_death = pd.DataFrame (df, columns =['Total Population','Total Citizen Income','Hispanic or Latino','Total Citizen Educated in US',
                                    'Total Households','White Race','Total Families','Hispanic or Latino_iqr','Citizen High School  Graduate',
                                    'Citizen Some College  Education','Citizen College Degree','Citizen Income over 75000','Citizen No Income',
                                    'Citizen Income 1-9999','Pacific Islander Race','Native American Race','Citizen Graduate or Professional Degree',
                                    'Citizen Less than High School  Education','Citizen Income 15000-24999',
                                     'Citizen Income 35000-49999','Death Rate Categories'])

df_features_death.head()
# Out:
#    Total Population  Total Citizen Income  Hispanic or Latino  \
# 0             54571                 44109               53261
# 1            182265                166364              174273
# 2             27457                 21627               26070
# 3             22915                 18743               22509
# 4             57322                 46501               52696
#
#    Total Citizen Educated in US  Total Households  White Race  Total Families  \
# 0                         36757             20221        9643           14613
# 1                        143022             73180       17105           41898
# 2                         18434              9820       12875            6015
# 3                         15859              7953        5047            5201
# 4                         39475             21578         761           14106
#
#    Hispanic or Latino_iqr  Citizen High School  Graduate  \
# 0                53261.00                          12363
# 1               140466.75                          39771
# 2                26070.00                           6549
# 3                22509.00                           6958
# 4                52696.00                          12740
#
#    Citizen Some College  Education  Citizen College Degree  \
# 0                            10697                    5316
# 1                            45286                   29237
# 2                             4707                    1403
# 3                             3971                    1289
# 4                            13583                    3416
#
#    Citizen Income over 75000  Citizen No Income  Citizen Income 1-9999  \
# 0                       5298               6377                   6955
# 1                      17954              20201                  25080
# 2                       1019               3968                   5090
# 3                        953               4170                   3268
# 4                       2690              10165                   6561
#
#    Pacific Islander Race  Native American Race  \
# 0                    466                   474
# 1                   3631                  1348
# 2                    894                   107
# 3                    185                    22
# 4                   2347                   117
#
#    Citizen Graduate or Professional Degree  \
# 0                                     3860
# 1                                    14731
# 2                                      815
# 3                                      808
# 4                                     1756
#
#    Citizen Less than High School  Education  Citizen Income 15000-24999  \
# 0                                      4521                        6000
# 1                                     13997                       26852
# 2                                      4960                        3419
# 3                                      2833                        2926
# 4                                      7980                        6956
#
#    Citizen Income 35000-49999 Death Rate Categories
# 0                        5727                     2
# 1                       21502                     1
# 2                        1820                     1
# 3                        1860                     1
# 4                        5639                     1

# %% [markdown]
# # Take Away
# - Created 2 CSV files, one for Target Vairable Covid Cases and one for Target Variable Deaths.
# - The CSV files consist of the top 20 non-repeating features.

# %% [markdown]
# <a id = "77"> <h2> 6. Save Top Features and Target Dataset to a CSV File </h2> </a>

# %% [markdown]
# __Saving New CSV File for Linear Regression Model__

# %%
# define name of the csv file
file_name_linreg = 'final_linreg_data.csv'

# export pandas dataframe to csv
df_lingreg.to_csv(r'../Capstone-Project/' + file_name_linreg, index=False)

# %% [markdown]
# __Saving New CSV File for Case Rate Categories__

# %%
# define name of the csv file
file_name_case = 'final_case_data.csv'

# export pandas dataframe to csv
df_features_case.to_csv(r'../Capstone-Project/' + file_name_case, index=False)

# %% [markdown]
# __Saving New CSV File for Case Rate Categories__

# %%
# define name of the csv file
file_name_death = 'final_death_data.csv'

# export pandas dataframe to csv
df_features_death.to_csv(r'../Capstone-Project/' + file_name_death, index=False)
