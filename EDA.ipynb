# %% [markdown]
# # Descriptives
# COVID-19 and Census Data
# ___

# %% [markdown]
# <b> Table of Contents: </b>
# <br> [0. Loading Modules and Dataset](#01)
# <br> [1. Dataset Size](#02)
# <br> [2. Dataset Datatypes](#03)
# <br> [3. Dataset Statistics](#04)
# <br> [4. Dataset Zero's and Nan's](#05)
# <br> [5. Visualize Dataset](#06)
# <br> [6. Dataset Skewness](#07)
# <br> [7. Correlation Analysis](#08)

# %% [markdown]
# This data set consists of COVID-19 and Census data in one csv file. Three csv files were combinded to create this final working version.

# %% [markdown]
# The first data source utlized in the final combined csv file is COVID-19 data tracking for each county in the entire US. The csv file has data for COVID-19 cases and deaths on every single day since Janurary 22, 2020 through June 15, 2020. This project utlizes this data source because of the relability of its' county level data. The Census Economic and Income data is made up of county level data and in order to combine the two datasets there needed to be consistency in the formats.

# %% [markdown]
# Data source: USAFACTS https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/
#
# The data source consists of:
# - COVID-19 Confirmed Cases per day
# - COVID-19 Deathsper day
#
#
# Data date range:
# - Janurary 22, 2020 - June 15, 2020

# %% [markdown]
# The second data source utilized is Census data for every county in the US.

# %% [markdown]
# Quick Notes on Data Cleaning:
# - Calculated total cases and deaths per month
# - Changed state abbreviations to full name to match the Census data
# - Fill in state name for any counties that were left blank
# - Compare the county names and order from this dataset to the Census data
# - Delete counties not present in both datasets
# - Add county population counts if listed as 0

# %% [markdown]
# ___
# <a id = "01"> <h2> 0. Loading Modules and Dataset  </h2> </a>

# %% [markdown]
# <b> Importing Libraries </b>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as seabornInstance 
from scipy import stats
from scipy.stats import norm
import numpy as np
import csv

# %% [markdown]
# <b> Loading the Data </b>

# %%
df = pd.read_csv("census_covid_final.csv")
df.head()
# county not country -- noticed right before submitting
# Out:
#                  Full Name    Country Name    State State Abbr  \
# 0  Autauga County, Alabama  Autauga County  Alabama         AL
# 1  Baldwin County, Alabama  Baldwin County  Alabama         AL
# 2  Barbour County, Alabama  Barbour County  Alabama         AL
# 3     Bibb County, Alabama     Bibb County  Alabama         AL
# 4   Blount County, Alabama   Blount County  Alabama         AL
#
#     Total Population    Households SNAP    Estimated Individuals SNAP   \
# 0               54571               2802                          7509
# 1              182265               6644                         16344
# 2               27457               2468                          6096
# 3               22915                933                          2426
# 4               57322               2244                          5902
#
#     Total Citizen Educated in US    Citizen Less than High School  Education   \
# 0                           36757                                        4521
# 1                          143022                                       13997
# 2                           18434                                        4960
# 3                           15859                                        2833
# 4                           39475                                        7980
#
#     Citizen High School  Graduate   ...  Median Age  Male Median Age  \
# 0                            12363  ...        37.0             35.9
# 1                            39771  ...        41.1             40.1
# 2                             6549  ...        39.0             37.2
# 3                             6958  ...        37.8             36.5
# 4                            12740  ...        39.0             38.0
#
#    Female Median Age   Total Households    Average Household Size   \
# 0               37.9               20221                         3
# 1               42.2               73180                         2
# 2               41.6                9820                         2
# 3               39.5                7953                         3
# 4               40.0               21578                         3
#
#     Total Families   Total Confirmed Cases  Total Deaths  Case Rate per 1000  \
# 0             14613                    400             8               7.330
# 1             41898                    401             9               2.200
# 2              6015                    263             1               9.579
# 3              5201                    121             1               5.280
# 4             14106                    130             1               2.268
#
#    Death Rate 1000
# 0            0.147
# 1            0.049
# 2            0.036
# 3            0.044
# 4            0.017
#
# [5 rows x 41 columns]

# %%
# trim the spaces of the cells from the csv file
df.columns = df.columns.to_series().apply(lambda x: x.strip())

# %%
# did not print before trimming column name
# test if prints after trimming -- YES
df['Black Race'].head()
# Out:
# 0     232
# 1    1216
# 2     114
# 3      64
# 4     307
# Name: Black Race, dtype: int64

# %% [markdown]
# ___
# <a id = "02"> <h2> 1. Data Size </h2> </a>

# %% [markdown]
# <b> Number of rows, number of columns in dataset </b>

# %%
print('There are # number of rows in the dataset    :', df.shape[0])
print('There are # number of columns in the dataset :', df.shape[1])
# Out:
# There are # number of rows in the dataset    : 3139
# There are # number of columns in the dataset : 41

# %% [markdown]
# | **# Rows** | **# Features** |
# |----------|--------------|
# | 3139     | 41           |

# %% [markdown]
# ___
# <a id = "03"> <h2> 2. Dataset Datatypes </h2> </a>

# %% [markdown]
# <b> Features datatypes and non-null </b>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3139 entries, 0 to 3138
# Data columns (total 41 columns):
# Full Name                                   3139 non-null object
# Country Name                                3139 non-null object
# State                                       3139 non-null object
# State Abbr                                  3139 non-null object
# Total Population                            3139 non-null int64
# Households SNAP                             3139 non-null int64
# Estimated Individuals SNAP                  3139 non-null int64
# Total Citizen Educated in US                3139 non-null int64
# Citizen Less than High School  Education    3139 non-null int64
# Citizen High School  Graduate               3139 non-null int64
# Citizen Some College  Education             3139 non-null int64
# Citizen College Degree                      3139 non-null int64
# Citizen Graduate or Professional Degree     3139 non-null int64
# Total Citizen Income                        3139 non-null int64
# Citizen No Income                           3139 non-null int64
# Citizen Income 1-9999                       3139 non-null int64
# Citizen Income 10000-14999                  3139 non-null int64
# Citizen Income 15000-24999                  3139 non-null int64
# Citizen Income 25000-34999                  3139 non-null int64
# Citizen Income 35000-49999                  3139 non-null int64
# Citizen Income 50000-64999                  3139 non-null int64
# Citizen Income 65000-74999                  3139 non-null int64
# Citizen Income over 75000                   3139 non-null int64
# One Race Population                         3139 non-null int64
# White Race                                  3139 non-null int64
# Black Race                                  3139 non-null int64
# Native American Race                        3139 non-null int64
# Asian Race                                  3139 non-null int64
# Pacific Islander Race                       3139 non-null int64
# Other Race Alone                            3139 non-null int64
# Hispanic or Latino                          3139 non-null int64
# Median Age                                  3139 non-null float64
# Male Median Age                             3139 non-null float64
# Female Median Age                           3139 non-null float64
# Total Households                            3139 non-null int64
# Average Household Size                      3139 non-null int64
# Total Families                              3139 non-null int64
# Total Confirmed Cases                       3139 non-null int64
# Total Deaths                                3139 non-null int64
# Case Rate per 1000                          3139 non-null float64
# Death Rate 1000                             3139 non-null float64
# dtypes: float64(5), int64(32), object(4)
# memory usage: 1005.6+ KB

# %% [markdown]
# ## Take-Away
# * All features and the target variable have no null values

# %% [markdown]
# ___
# <a id = "04"> <h2> 3. Dataset Statistics </h2> </a>

# %% [markdown]
# <b> Descriptive Statistics </b>

# %%
df.describe().round(2)
# Out:
#        Total Population  Households SNAP  Estimated Individuals SNAP  \
# count           3139.00          3139.00                     3139.00
# mean           98157.55          5022.87                    12933.97
# std           312959.37         15772.62                    42674.98
# min               82.00             0.00                        0.00
# 25%            11116.00           573.00                     1396.50
# 50%            25887.00          1480.00                     3702.00
# 75%            66699.00          3635.00                     9149.00
# max          9818605.00        333729.00                   994512.00
#
#        Total Citizen Educated in US  Citizen Less than High School  Education  \
# count                       3139.00                                   3139.00
# mean                       68742.50                                   8725.07
# std                       220604.94                                  37843.65
# min                           64.00                                      4.00
# 25%                         7609.00                                   1022.50
# 50%                        17789.00                                   2535.00
# 75%                        45811.00                                   5790.50
# max                      6801851.00                                1485760.00
#
#        Citizen High School  Graduate  Citizen Some College  Education  \
# count                        3139.00                          3139.00
# mean                        18797.59                         19997.75
# std                         50608.84                         60443.97
# min                            20.00                            27.00
# 25%                          2758.00                          2278.00
# 50%                          6371.00                          5269.00
# 75%                         15222.00                         14179.50
# max                       1408905.00                       1782880.00
#
#        Citizen College Degree  Citizen Graduate or Professional Degree  \
# count                 3139.00                                  3139.00
# mean                 13145.09                                  8076.99
# std                  47721.88                                 30048.27
# min                      3.00                                     0.00
# 25%                    783.00                                   386.50
# 50%                   2016.00                                  1047.00
# 75%                   6399.00                                  3616.00
# max                1384333.00                                739973.00
#
#        Total Citizen Income  ...  Median Age  Male Median Age  \
# count               3139.00  ...     3139.00          3139.00
# mean               82640.21  ...       40.35            39.16
# std               265255.57  ...        5.04             5.09
# min                   67.00  ...       22.40            21.70
# 25%                 8889.00  ...       37.40            36.10
# 50%                21017.00  ...       40.30            39.10
# 75%                54933.50  ...       43.40            42.00
# max              8227851.00  ...       62.70            61.50
#
#        Female Median Age  Total Households  Average Household Size  \
# count            3139.00           3139.00                  3139.0
# mean               41.57          37095.28                     2.4
# std                 5.05         111966.14                     0.5
# min                21.60             39.00                     1.0
# 25%                38.80           4374.00                     2.0
# 50%                41.70          10020.00                     2.0
# 75%                44.80          25818.00                     3.0
# max                63.50        3241204.00                     4.0
#
#        Total Families  Total Confirmed Cases  Total Deaths  \
# count         3139.00                3139.00       3139.00
# mean         23596.98                 686.42         37.03
# std          77121.41                3546.71        256.18
# min              0.00                   0.00          0.00
# 25%           2556.00                  13.00          0.00
# 50%           6118.00                  57.00          1.00
# 75%          15446.00                 251.50          8.00
# max        2402208.00               86179.00       6965.00
#
#        Case Rate per 1000  Death Rate 1000
# count             3139.00          3139.00
# mean                 4.19             0.15
# std                  7.32             0.31
# min                  0.00             0.00
# 25%                  0.81             0.00
# 50%                  2.02             0.04
# 75%                  4.80             0.16
# max                186.02             3.34
#
# [8 rows x 37 columns]

# %% [markdown]
# ## Take-Away
# - The standar devations are very large for most of the dataset
# - Relatively smaller for Case Rate per 1000 and Death Rate per 1000 which is good because these are going to be used as the best comparisons between counties. This is because rates account for the variablity in population between counties.

# %% [markdown]
# <b> Features grouped by data type </b>

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {dtype('int64'): Index(['Total Population', 'Households SNAP', 'Estimated Individuals SNAP',
#         'Total Citizen Educated in US',
#         'Citizen Less than High School  Education',
#         'Citizen High School  Graduate', 'Citizen Some College  Education',
#         'Citizen College Degree', 'Citizen Graduate or Professional Degree',
#         'Total Citizen Income', 'Citizen No Income', 'Citizen Income 1-9999',
#         'Citizen Income 10000-14999', 'Citizen Income 15000-24999',
#         'Citizen Income 25000-34999', 'Citizen Income 35000-49999',
#         'Citizen Income 50000-64999', 'Citizen Income 65000-74999',
#         'Citizen Income over 75000', 'One Race Population', 'White Race',
#         'Black Race', 'Native American Race', 'Asian Race',
#         'Pacific Islander Race', 'Other Race Alone', 'Hispanic or Latino',
#         'Total Households', 'Average Household Size', 'Total Families',
#         'Total Confirmed Cases', 'Total Deaths'],
#        dtype='object'),
#  dtype('float64'): Index(['Median Age', 'Male Median Age', 'Female Median Age',
#         'Case Rate per 1000', 'Death Rate 1000'],
#        dtype='object'),
#  dtype('O'): Index(['Full Name', 'Country Name', 'State', 'State Abbr'], dtype='object')}

# %% [markdown]
# ___
# <a id = "05"> <h2> 4. Dataset Zero's and Nan's </h2> </a>

# %% [markdown]
# <b> Features - Zero's & NaN's </b>

# %% [markdown]
# _Create a function that creates a dataframe with Zero's and NaN's_

# %%
def function_missing(df):
    # Count NaN's
    list_nan = df.isna().sum()

    # Percentage of missing values for each column (To see the amount of usable data for each column and infer the effect replacing NaN's will have by some metric in part 2)
    list_nan_pct = df.isna().mean().round(4) * 100

    # Calculate the sum of the number of times a zero appears in a feature 
    list_zeros = df.isin([0]).sum()

    # Calculate a % of the number of times a zero appears in a feature
    list_zeros_pct = df.isin([0]).mean().round(4) * 100

    # create a dataframe showing the missing and percentage that is missing
    df_combined = pd.concat([list_nan.rename('# NaNs'), list_zeros.rename('# Zeros'), list_nan_pct.rename('% NaNs'), list_zeros_pct.rename('% Zeros')], axis=1)
    
    return(df_combined)

# %% [markdown]
# _Apply function to dataframe_

# %%
function_missing(df=df)
# Out:
#                                           # NaNs  # Zeros  % NaNs  % Zeros
# Full Name                                      0        0     0.0     0.00
# Country Name                                   0        0     0.0     0.00
# State                                          0        0     0.0     0.00
# State Abbr                                     0        0     0.0     0.00
# Total Population                               0        0     0.0     0.00
# Households SNAP                                0        3     0.0     0.10
# Estimated Individuals SNAP                     0        3     0.0     0.10
# Total Citizen Educated in US                   0        0     0.0     0.00
# Citizen Less than High School  Education       0        0     0.0     0.00
# Citizen High School  Graduate                  0        0     0.0     0.00
# Citizen Some College  Education                0        0     0.0     0.00
# Citizen College Degree                         0        0     0.0     0.00
# Citizen Graduate or Professional Degree        0        1     0.0     0.03
# Total Citizen Income                           0        0     0.0     0.00
# Citizen No Income                              0        0     0.0     0.00
# Citizen Income 1-9999                          0        0     0.0     0.00
# Citizen Income 10000-14999                     0        0     0.0     0.00
# Citizen Income 15000-24999                     0        0     0.0     0.00
# Citizen Income 25000-34999                     0        0     0.0     0.00
# Citizen Income 35000-49999                     0        0     0.0     0.00
# Citizen Income 50000-64999                     0        0     0.0     0.00
# Citizen Income 65000-74999                     0        4     0.0     0.13
# Citizen Income over 75000                      0        0     0.0     0.00
# One Race Population                            0        0     0.0     0.00
# White Race                                     0       30     0.0     0.96
# Black Race                                     0        7     0.0     0.22
# Native American Race                           0       21     0.0     0.67
# Asian Race                                     0      407     0.0    12.97
# Pacific Islander Race                          0       10     0.0     0.32
# Other Race Alone                               0        0     0.0     0.00
# Hispanic or Latino                             0        0     0.0     0.00
# Median Age                                     0        0     0.0     0.00
# Male Median Age                                0        0     0.0     0.00
# Female Median Age                              0        0     0.0     0.00
# Total Households                               0        0     0.0     0.00
# Average Household Size                         0        0     0.0     0.00
# Total Families                                 0        1     0.0     0.03
# Total Confirmed Cases                          0      137     0.0     4.36
# Total Deaths                                   0     1257     0.0    40.04
# Case Rate per 1000                             0      137     0.0     4.36
# Death Rate 1000                                0     1257     0.0    40.04

# %% [markdown]
# ## Take-Away
# - May have to account for 0 values in 'Households SNAP' and 'Estimated Individuals SNAP'
# - 0s for target variables are good, it means there were either 0 cases of COVID or 0 deaths
# - Race values that are 0 might be ok, but need to also consider later

# %% [markdown]
# ___
# <a id = "06"> <h2> 5. Visualize Dataset </h2> </a>

# %% [markdown]
# ## 1. Barcharts

# %% [markdown]
# <b> Visualize Heat Map of the Dataset </b>

# %%
# print out a correlation matrix of the data frame
corr = df.corr()

# display it
display(corr)
f, ax = plt.subplots(figsize=(20, 20)) # adjust the size of the heat map to see all the features 

# plot a heatmap
sns.heatmap(corr, xticklabels = corr.columns, yticklabels = corr.columns, cmap = "RdBu")
# Out:
#                                           Total Population  Households SNAP  \
# Total Population                                  1.000000         0.918044
# Households SNAP                                   0.918044         1.000000
# Estimated Individuals SNAP                        0.927689         0.995571
# Total Citizen Educated in US                      0.998909         0.916177
# Citizen Less than High School  Education          0.951975         0.877230
# Citizen High School  Graduate                     0.981833         0.943154
# Citizen Some College  Education                   0.989473         0.903543
# Citizen College Degree                            0.976399         0.866878
# Citizen Graduate or Professional Degree           0.940000         0.838680
# Total Citizen Income                              0.999427         0.916108
# Citizen No Income                                 0.984962         0.903435
# Citizen Income 1-9999                             0.994951         0.939424
# Citizen Income 10000-14999                        0.989717         0.917337
# Citizen Income 15000-24999                        0.994065         0.924635
# Citizen Income 25000-34999                        0.993056         0.924252
# Citizen Income 35000-49999                        0.991328         0.918032
# Citizen Income 50000-64999                        0.989203         0.904170
# Citizen Income 65000-74999                        0.984475         0.887108
# Citizen Income over 75000                         0.949479         0.813650
# One Race Population                               0.976991         0.891303
# White Race                                        0.786742         0.887058
# Black Race                                        0.608964         0.551375
# Native American Race                              0.833221         0.656936
# Asian Race                                        0.372151         0.282654
# Pacific Islander Race                             0.877209         0.737055
# Other Race Alone                                  0.925970         0.805513
# Hispanic or Latino                                0.969776         0.904779
# Median Age                                       -0.189325        -0.193395
# Male Median Age                                  -0.190410        -0.197061
# Female Median Age                                -0.190031        -0.191398
# Total Households                                  0.995891         0.929257
# Average Household Size                            0.130014         0.102754
# Total Families                                    0.994930         0.910229
# Total Confirmed Cases                             0.799636         0.810653
# Total Deaths                                      0.601321         0.688951
# Case Rate per 1000                                0.120232         0.131714
# Death Rate 1000                                   0.222972         0.266249
#
#                                           Estimated Individuals SNAP  \
# Total Population                                            0.927689
# Households SNAP                                             0.995571
# Estimated Individuals SNAP                                  1.000000
# Total Citizen Educated in US                                0.924101
# Citizen Less than High School  Education                    0.904537
# Citizen High School  Graduate                               0.948490
# Citizen Some College  Education                             0.912559
# Citizen College Degree                                      0.868661
# Citizen Graduate or Professional Degree                     0.832508
# Total Citizen Income                                        0.924931
# Citizen No Income                                           0.924371
# Citizen Income 1-9999                                       0.947784
# Citizen Income 10000-14999                                  0.931257
# Citizen Income 15000-24999                                  0.934789
# Citizen Income 25000-34999                                  0.930036
# Citizen Income 35000-49999                                  0.920968
# Citizen Income 50000-64999                                  0.906135
# Citizen Income 65000-74999                                  0.889235
# Citizen Income over 75000                                   0.816167
# One Race Population                                         0.895425
# White Race                                                  0.872232
# Black Race                                                  0.564883
# Native American Race                                        0.681566
# Asian Race                                                  0.296814
# Pacific Islander Race                                       0.774924
# Other Race Alone                                            0.825993
# Hispanic or Latino                                          0.897063
# Median Age                                                 -0.196589
# Male Median Age                                            -0.199668
# Female Median Age                                          -0.194954
# Total Households                                            0.930923
# Average Household Size                                      0.120103
# Total Families                                              0.925511
# Total Confirmed Cases                                       0.812047
# Total Deaths                                                0.680379
# Case Rate per 1000                                          0.130163
# Death Rate 1000                                             0.257329
#
#                                           Total Citizen Educated in US  \
# Total Population                                              0.998909
# Households SNAP                                               0.916177
# Estimated Individuals SNAP                                    0.924101
# Total Citizen Educated in US                                  1.000000
# Citizen Less than High School  Education                      0.947006
# Citizen High School  Graduate                                 0.981423
# Citizen Some College  Education                               0.989214
# Citizen College Degree                                        0.981720
# Citizen Graduate or Professional Degree                       0.947026
# Total Citizen Income                                          0.999744
# Citizen No Income                                             0.982299
# Citizen Income 1-9999                                         0.993216
# Citizen Income 10000-14999                                    0.987826
# Citizen Income 15000-24999                                    0.993208
# Citizen Income 25000-34999                                    0.993444
# Citizen Income 35000-49999                                    0.992645
# Citizen Income 50000-64999                                    0.991207
# Citizen Income 65000-74999                                    0.986820
# Citizen Income over 75000                                     0.955229
# One Race Population                                           0.977904
# White Race                                                    0.783833
# Black Race                                                    0.605299
# Native American Race                                          0.835821
# Asian Race                                                    0.373442
# Pacific Islander Race                                         0.868389
# Other Race Alone                                              0.925039
# Hispanic or Latino                                            0.971273
# Median Age                                                   -0.180294
# Male Median Age                                              -0.181255
# Female Median Age                                            -0.181299
# Total Households                                              0.996770
# Average Household Size                                        0.125884
# Total Families                                                0.991149
# Total Confirmed Cases                                         0.798248
# Total Deaths                                                  0.603097
# Case Rate per 1000                                            0.119470
# Death Rate 1000                                               0.223542
#
#                                           Citizen Less than High School  Education  \
# Total Population                                                          0.951975
# Households SNAP                                                           0.877230
# Estimated Individuals SNAP                                                0.904537
# Total Citizen Educated in US                                              0.947006
# Citizen Less than High School  Education                                  1.000000
# Citizen High School  Graduate                                             0.928333
# Citizen Some College  Education                                           0.928655
# Citizen College Degree                                                    0.897074
# Citizen Graduate or Professional Degree                                   0.836890
# Total Citizen Income                                                      0.949285
# Citizen No Income                                                         0.982062
# Citizen Income 1-9999                                                     0.952580
# Citizen Income 10000-14999                                                0.972763
# Citizen Income 15000-24999                                                0.959246
# Citizen Income 25000-34999                                                0.936191
# Citizen Income 35000-49999                                                0.917842
# Citizen Income 50000-64999                                                0.905684
# Citizen Income 65000-74999                                                0.896620
# Citizen Income over 75000                                                 0.860073
# One Race Population                                                       0.889693
# White Race                                                                0.736622
# Black Race                                                                0.598482
# Native American Race                                                      0.846698
# Asian Race                                                                0.342088
# Pacific Islander Race                                                     0.957351
# Other Race Alone                                                          0.911531
# Hispanic or Latino                                                        0.858411
# Median Age                                                               -0.157128
# Male Median Age                                                          -0.157923
# Female Median Age                                                        -0.157022
# Total Households                                                          0.929470
# Average Household Size                                                    0.123634
# Total Families                                                            0.954800
# Total Confirmed Cases                                                     0.765931
# Total Deaths                                                              0.571744
# Case Rate per 1000                                                        0.105000
# Death Rate 1000                                                           0.184015
#
#                                           Citizen High School  Graduate  \
# Total Population                                               0.981833
# Households SNAP                                                0.943154
# Estimated Individuals SNAP                                     0.948490
# Total Citizen Educated in US                                   0.981423
# Citizen Less than High School  Education                       0.928333
# Citizen High School  Graduate                                  1.000000
# Citizen Some College  Education                                0.977636
# Citizen College Degree                                         0.937588
# Citizen Graduate or Professional Degree                        0.896248
# Total Citizen Income                                           0.981045
# Citizen No Income                                              0.963451
# Citizen Income 1-9999                                          0.984009
# Citizen Income 10000-14999                                     0.976470
# Citizen Income 15000-24999                                     0.985920
# Citizen Income 25000-34999                                     0.987641
# Citizen Income 35000-49999                                     0.983552
# Citizen Income 50000-64999                                     0.974031
# Citizen Income 65000-74999                                     0.962440
# Citizen Income over 75000                                      0.899858
# One Race Population                                            0.968893
# White Race                                                     0.814113
# Black Race                                                     0.585780
# Native American Race                                           0.765448
# Asian Race                                                     0.351974
# Pacific Islander Race                                          0.822951
# Other Race Alone                                               0.888604
# Hispanic or Latino                                             0.963606
# Median Age                                                    -0.181495
# Male Median Age                                               -0.184438
# Female Median Age                                             -0.180886
# Total Households                                               0.982459
# Average Household Size                                         0.132402
# Total Families                                                 0.975229
# Total Confirmed Cases                                          0.808829
# Total Deaths                                                   0.629783
# Case Rate per 1000                                             0.130100
# Death Rate 1000                                                0.252009
#
#                                           Citizen Some College  Education  \
# Total Population                                                 0.989473
# Households SNAP                                                  0.903543
# Estimated Individuals SNAP                                       0.912559
# Total Citizen Educated in US                                     0.989214
# Citizen Less than High School  Education                         0.928655
# Citizen High School  Graduate                                    0.977636
# Citizen Some College  Education                                  1.000000
# Citizen College Degree                                           0.959497
# Citizen Graduate or Professional Degree                          0.910930
# Total Citizen Income                                             0.989877
# Citizen No Income                                                0.970901
# Citizen Income 1-9999                                            0.984460
# Citizen Income 10000-14999                                       0.981693
# Citizen Income 15000-24999                                       0.989764
# Citizen Income 25000-34999                                       0.993151
# Citizen Income 35000-49999                                       0.991541
# Citizen Income 50000-64999                                       0.983036
# Citizen Income 65000-74999                                       0.974411
# Citizen Income over 75000                                        0.926109
# One Race Population                                              0.979706
# White Race                                                       0.755652
# Black Race                                                       0.629046
# Native American Race                                             0.800581
# Asian Race                                                       0.393489
# Pacific Islander Race                                            0.855828
# Other Race Alone                                                 0.923542
# Hispanic or Latino                                               0.964402
# Median Age                                                      -0.188428
# Male Median Age                                                 -0.189433
# Female Median Age                                               -0.189435
# Total Households                                                 0.986378
# Average Household Size                                           0.131050
# Total Families                                                   0.987831
# Total Confirmed Cases                                            0.742405
# Total Deaths                                                     0.535658
# Case Rate per 1000                                               0.100797
# Death Rate 1000                                                  0.188148
#
#                                           Citizen College Degree  \
# Total Population                                        0.976399
# Households SNAP                                         0.866878
# Estimated Individuals SNAP                              0.868661
# Total Citizen Educated in US                            0.981720
# Citizen Less than High School  Education                0.897074
# Citizen High School  Graduate                           0.937588
# Citizen Some College  Education                         0.959497
# Citizen College Degree                                  1.000000
# Citizen Graduate or Professional Degree                 0.980285
# Total Citizen Income                                    0.980031
# Citizen No Income                                       0.945980
# Citizen Income 1-9999                                   0.963047
# Citizen Income 10000-14999                              0.949761
# Citizen Income 15000-24999                              0.958418
# Citizen Income 25000-34999                              0.964744
# Citizen Income 35000-49999                              0.973013
# Citizen Income 50000-64999                              0.983806
# Citizen Income 65000-74999                              0.987162
# Citizen Income over 75000                               0.984608
# One Race Population                                     0.961043
# White Race                                              0.751343
# Black Race                                              0.571290
# Native American Race                                    0.849492
# Asian Race                                              0.370886
# Pacific Islander Race                                   0.822854
# Other Race Alone                                        0.902761
# Hispanic or Latino                                      0.966864
# Median Age                                             -0.172840
# Male Median Age                                        -0.172299
# Female Median Age                                      -0.175481
# Total Households                                        0.980380
# Average Household Size                                  0.114267
# Total Families                                          0.961545
# Total Confirmed Cases                                   0.783253
# Total Deaths                                            0.594374
# Case Rate per 1000                                      0.118559
# Death Rate 1000                                         0.222480
#
#                                           Citizen Graduate or Professional Degree  \
# Total Population                                                         0.940000
# Households SNAP                                                          0.838680
# Estimated Individuals SNAP                                               0.832508
# Total Citizen Educated in US                                             0.947026
# Citizen Less than High School  Education                                 0.836890
# Citizen High School  Graduate                                            0.896248
# Citizen Some College  Education                                          0.910930
# Citizen College Degree                                                   0.980285
# Citizen Graduate or Professional Degree                                  1.000000
# Total Citizen Income                                                     0.944267
# Citizen No Income                                                        0.896788
# Citizen Income 1-9999                                                    0.925065
# Citizen Income 10000-14999                                               0.899437
# Citizen Income 15000-24999                                               0.910077
# Citizen Income 25000-34999                                               0.921087
# Citizen Income 35000-49999                                               0.935321
# Citizen Income 50000-64999                                               0.956077
# Citizen Income 65000-74999                                               0.966832
# Citizen Income over 75000                                                0.987548
# One Race Population                                                      0.930052
# White Race                                                               0.742458
# Black Race                                                               0.530892
# Native American Race                                                     0.821210
# Asian Race                                                               0.337487
# Pacific Islander Race                                                    0.755282
# Other Race Alone                                                         0.855196
# Hispanic or Latino                                                       0.951214
# Median Age                                                              -0.166551
# Male Median Age                                                         -0.166493
# Female Median Age                                                       -0.168869
# Total Households                                                         0.951490
# Average Household Size                                                   0.100403
# Total Families                                                           0.917487
# Total Confirmed Cases                                                    0.796248
# Total Deaths                                                             0.625487
# Case Rate per 1000                                                       0.134700
# Death Rate 1000                                                          0.253168
#
#                                           Total Citizen Income  ...  \
# Total Population                                      0.999427  ...
# Households SNAP                                       0.916108  ...
# Estimated Individuals SNAP                            0.924931  ...
# Total Citizen Educated in US                          0.999744  ...
# Citizen Less than High School  Education              0.949285  ...
# Citizen High School  Graduate                         0.981045  ...
# Citizen Some College  Education                       0.989877  ...
# Citizen College Degree                                0.980031  ...
# Citizen Graduate or Professional Degree               0.944267  ...
# Total Citizen Income                                  1.000000  ...
# Citizen No Income                                     0.983998  ...
# Citizen Income 1-9999                                 0.994445  ...
# Citizen Income 10000-14999                            0.988971  ...
# Citizen Income 15000-24999                            0.993961  ...
# Citizen Income 25000-34999                            0.993745  ...
# Citizen Income 35000-49999                            0.992528  ...
# Citizen Income 50000-64999                            0.990573  ...
# Citizen Income 65000-74999                            0.985853  ...
# Citizen Income over 75000                             0.952959  ...
# One Race Population                                   0.978013  ...
# White Race                                            0.782894  ...
# Black Race                                            0.608281  ...
# Native American Race                                  0.834593  ...
# Asian Race                                            0.373619  ...
# Pacific Islander Race                                 0.872714  ...
# Other Race Alone                                      0.926349  ...
# Hispanic or Latino                                    0.969901  ...
# Median Age                                           -0.187656  ...
# Male Median Age                                      -0.188460  ...
# Female Median Age                                    -0.188646  ...
# Total Households                                      0.996305  ...
# Average Household Size                                0.127259  ...
# Total Families                                        0.992967  ...
# Total Confirmed Cases                                 0.795591  ...
# Total Deaths                                          0.598405  ...
# Case Rate per 1000                                    0.119007  ...
# Death Rate 1000                                       0.221165  ...
#
#                                           Median Age  Male Median Age  \
# Total Population                           -0.189325        -0.190410
# Households SNAP                            -0.193395        -0.197061
# Estimated Individuals SNAP                 -0.196589        -0.199668
# Total Citizen Educated in US               -0.180294        -0.181255
# Citizen Less than High School  Education   -0.157128        -0.157923
# Citizen High School  Graduate              -0.181495        -0.184438
# Citizen Some College  Education            -0.188428        -0.189433
# Citizen College Degree                     -0.172840        -0.172299
# Citizen Graduate or Professional Degree    -0.166551        -0.166493
# Total Citizen Income                       -0.187656        -0.188460
# Citizen No Income                          -0.178019        -0.178504
# Citizen Income 1-9999                      -0.206121        -0.207508
# Citizen Income 10000-14999                 -0.178096        -0.179980
# Citizen Income 15000-24999                 -0.182272        -0.183984
# Citizen Income 25000-34999                 -0.190666        -0.191963
# Citizen Income 35000-49999                 -0.195711        -0.196608
# Citizen Income 50000-64999                 -0.192313        -0.192716
# Citizen Income 65000-74999                 -0.186274        -0.186367
# Citizen Income over 75000                  -0.161517        -0.160569
# One Race Population                        -0.196130        -0.197014
# White Race                                 -0.179135        -0.185147
# Black Race                                 -0.204806        -0.199306
# Native American Race                       -0.105337        -0.104120
# Asian Race                                 -0.070251        -0.068919
# Pacific Islander Race                      -0.123781        -0.122201
# Other Race Alone                           -0.164662        -0.163902
# Hispanic or Latino                         -0.201739        -0.203910
# Median Age                                  1.000000         0.990713
# Male Median Age                             0.990713         1.000000
# Female Median Age                           0.984846         0.955367
# Total Households                           -0.187137        -0.188710
# Average Household Size                     -0.510256        -0.487886
# Total Families                             -0.201827        -0.202160
# Total Confirmed Cases                      -0.133783        -0.137195
# Total Deaths                               -0.087156        -0.092057
# Case Rate per 1000                         -0.229268        -0.240292
# Death Rate 1000                            -0.137767        -0.156197
#
#                                           Female Median Age  Total Households  \
# Total Population                                  -0.190031          0.995891
# Households SNAP                                   -0.191398          0.929257
# Estimated Individuals SNAP                        -0.194954          0.930923
# Total Citizen Educated in US                      -0.181299          0.996770
# Citizen Less than High School  Education          -0.157022          0.929470
# Citizen High School  Graduate                     -0.180886          0.982459
# Citizen Some College  Education                   -0.189435          0.986378
# Citizen College Degree                            -0.175481          0.980380
# Citizen Graduate or Professional Degree           -0.168869          0.951490
# Total Citizen Income                              -0.188646          0.996305
# Citizen No Income                                 -0.178333          0.969385
# Citizen Income 1-9999                             -0.206207          0.992053
# Citizen Income 10000-14999                        -0.177932          0.980866
# Citizen Income 15000-24999                        -0.182370          0.989588
# Citizen Income 25000-34999                        -0.191329          0.993358
# Citizen Income 35000-49999                        -0.196936          0.994661
# Citizen Income 50000-64999                        -0.194183          0.993496
# Citizen Income 65000-74999                        -0.188536          0.988292
# Citizen Income over 75000                         -0.164783          0.952080
# One Race Population                               -0.197610          0.980449
# White Race                                        -0.174822          0.804631
# Black Race                                        -0.209029          0.599875
# Native American Race                              -0.107235          0.808581
# Asian Race                                        -0.071840          0.357347
# Pacific Islander Race                             -0.125240          0.841253
# Other Race Alone                                  -0.166238          0.908417
# Hispanic or Latino                                -0.202183          0.982184
# Median Age                                         0.984846         -0.187137
# Male Median Age                                    0.955367         -0.188710
# Female Median Age                                  1.000000         -0.187724
# Total Households                                  -0.187724          1.000000
# Average Household Size                            -0.528522          0.116093
# Total Families                                    -0.203129          0.985806
# Total Confirmed Cases                             -0.131871          0.801620
# Total Deaths                                      -0.084067          0.613041
# Case Rate per 1000                                -0.211033          0.121843
# Death Rate 1000                                   -0.123372          0.233009
#
#                                           Average Household Size  \
# Total Population                                        0.130014
# Households SNAP                                         0.102754
# Estimated Individuals SNAP                              0.120103
# Total Citizen Educated in US                            0.125884
# Citizen Less than High School  Education                0.123634
# Citizen High School  Graduate                           0.132402
# Citizen Some College  Education                         0.131050
# Citizen College Degree                                  0.114267
# Citizen Graduate or Professional Degree                 0.100403
# Total Citizen Income                                    0.127259
# Citizen No Income                                       0.136699
# Citizen Income 1-9999                                   0.121291
# Citizen Income 10000-14999                              0.115112
# Citizen Income 15000-24999                              0.117933
# Citizen Income 25000-34999                              0.120881
# Citizen Income 35000-49999                              0.124022
# Citizen Income 50000-64999                              0.131007
# Citizen Income 65000-74999                              0.132832
# Citizen Income over 75000                               0.128786
# One Race Population                                     0.133600
# White Race                                              0.089291
# Black Race                                              0.134484
# Native American Race                                    0.095649
# Asian Race                                              0.076976
# Pacific Islander Race                                   0.106090
# Other Race Alone                                        0.124460
# Hispanic or Latino                                      0.122695
# Median Age                                             -0.510256
# Male Median Age                                        -0.487886
# Female Median Age                                      -0.528522
# Total Households                                        0.116093
# Average Household Size                                  1.000000
# Total Families                                          0.150762
# Total Confirmed Cases                                   0.122511
# Total Deaths                                            0.090155
# Case Rate per 1000                                      0.218274
# Death Rate 1000                                         0.165698
#
#                                           Total Families  \
# Total Population                                0.994930
# Households SNAP                                 0.910229
# Estimated Individuals SNAP                      0.925511
# Total Citizen Educated in US                    0.991149
# Citizen Less than High School  Education        0.954800
# Citizen High School  Graduate                   0.975229
# Citizen Some College  Education                 0.987831
# Citizen College Degree                          0.961545
# Citizen Graduate or Professional Degree         0.917487
# Total Citizen Income                            0.992967
# Citizen No Income                               0.985852
# Citizen Income 1-9999                           0.988747
# Citizen Income 10000-14999                      0.984378
# Citizen Income 15000-24999                      0.989390
# Citizen Income 25000-34999                      0.988044
# Citizen Income 35000-49999                      0.984876
# Citizen Income 50000-64999                      0.981143
# Citizen Income 65000-74999                      0.974335
# Citizen Income over 75000                       0.933897
# One Race Population                             0.971645
# White Race                                      0.777516
# Black Race                                      0.620883
# Native American Race                            0.817286
# Asian Race                                      0.368726
# Pacific Islander Race                           0.887617
# Other Race Alone                                0.922009
# Hispanic or Latino                              0.956694
# Median Age                                     -0.201827
# Male Median Age                                -0.202160
# Female Median Age                              -0.203129
# Total Households                                0.985806
# Average Household Size                          0.150762
# Total Families                                  1.000000
# Total Confirmed Cases                           0.779358
# Total Deaths                                    0.572086
# Case Rate per 1000                              0.117182
# Death Rate 1000                                 0.208866
#
#                                           Total Confirmed Cases  Total Deaths  \
# Total Population                                       0.799636      0.601321
# Households SNAP                                        0.810653      0.688951
# Estimated Individuals SNAP                             0.812047      0.680379
# Total Citizen Educated in US                           0.798248      0.603097
# Citizen Less than High School  Education               0.765931      0.571744
# Citizen High School  Graduate                          0.808829      0.629783
# Citizen Some College  Education                        0.742405      0.535658
# Citizen College Degree                                 0.783253      0.594374
# Citizen Graduate or Professional Degree                0.796248      0.625487
# Total Citizen Income                                   0.795591      0.598405
# Citizen No Income                                      0.787999      0.589546
# Citizen Income 1-9999                                  0.796185      0.606720
# Citizen Income 10000-14999                             0.773540      0.575884
# Citizen Income 15000-24999                             0.776349      0.572879
# Citizen Income 25000-34999                             0.773429      0.572002
# Citizen Income 35000-49999                             0.778295      0.583750
# Citizen Income 50000-64999                             0.794530      0.605539
# Citizen Income 65000-74999                             0.801448      0.616442
# Citizen Income over 75000                              0.780277      0.596085
# One Race Population                                    0.751676      0.547467
# White Race                                             0.780403      0.681167
# Black Race                                             0.435544      0.299117
# Native American Race                                   0.656719      0.515127
# Asian Race                                             0.181643      0.102481
# Pacific Islander Race                                  0.675420      0.461585
# Other Race Alone                                       0.690089      0.508538
# Hispanic or Latino                                     0.797245      0.629583
# Median Age                                            -0.133783     -0.087156
# Male Median Age                                       -0.137195     -0.092057
# Female Median Age                                     -0.131871     -0.084067
# Total Households                                       0.801620      0.613041
# Average Household Size                                 0.122511      0.090155
# Total Families                                         0.779358      0.572086
# Total Confirmed Cases                                  1.000000      0.905361
# Total Deaths                                           0.905361      1.000000
# Case Rate per 1000                                     0.270247      0.230364
# Death Rate 1000                                        0.433009      0.492948
#
#                                           Case Rate per 1000  Death Rate 1000
# Total Population                                    0.120232         0.222972
# Households SNAP                                     0.131714         0.266249
# Estimated Individuals SNAP                          0.130163         0.257329
# Total Citizen Educated in US                        0.119470         0.223542
# Citizen Less than High School  Education            0.105000         0.184015
# Citizen High School  Graduate                       0.130100         0.252009
# Citizen Some College  Education                     0.100797         0.188148
# Citizen College Degree                              0.118559         0.222480
# Citizen Graduate or Professional Degree             0.134700         0.253168
# Total Citizen Income                                0.119007         0.221165
# Citizen No Income                                   0.112019         0.201111
# Citizen Income 1-9999                               0.118506         0.224415
# Citizen Income 10000-14999                          0.106018         0.200838
# Citizen Income 15000-24999                          0.108535         0.201986
# Citizen Income 25000-34999                          0.113008         0.207823
# Citizen Income 35000-49999                          0.117536         0.219283
# Citizen Income 50000-64999                          0.125484         0.236687
# Citizen Income 65000-74999                          0.130159         0.247356
# Citizen Income over 75000                           0.131077         0.242495
# One Race Population                                 0.114547         0.217533
# White Race                                          0.153185         0.280050
# Black Race                                          0.101224         0.139686
# Native American Race                                0.075944         0.152293
# Asian Race                                         -0.002172         0.001437
# Pacific Islander Race                               0.075754         0.119102
# Other Race Alone                                    0.084971         0.161177
# Hispanic or Latino                                  0.133775         0.260350
# Median Age                                         -0.229268        -0.137767
# Male Median Age                                    -0.240292        -0.156197
# Female Median Age                                  -0.211033        -0.123372
# Total Households                                    0.121843         0.233009
# Average Household Size                              0.218274         0.165698
# Total Families                                      0.117182         0.208866
# Total Confirmed Cases                               0.270247         0.433009
# Total Deaths                                        0.230364         0.492948
# Case Rate per 1000                                  1.000000         0.526189
# Death Rate 1000                                     0.526189         1.000000
#
# [37 rows x 37 columns]

# %% [markdown]
# <b> Visualize all Covid target variables: 'Total Confirmed Cases' </b>

# %%
# check the average level of COVID Confirmed Cases
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(df['Total Confirmed Cases'])

# %% [markdown]
# <b> Visualize all Covid target variables: 'Total Deaths' </b>

# %%
# check the average level of COVID Deaths
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(df['Total Deaths'])

# %% [markdown]
# <b> Visualize all Covid target variables: 'Case Rate per 1000' </b>

# %%
# check the average level of COVID Case Rate per 1000
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(df['Case Rate per 1000'])

# %% [markdown]
# <b> Visualize all Covid target variables: 'Death Rate per 1000' </b>

# %%
# check the average level of COVID Death Rate per 1000
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(df['Death Rate 1000']) # removed 'per' in original csv file

# %% [markdown]
# Take-away from Target Variables Distributions:
# --------------------
# The data is unevenly distributed, with more lower values for total cases, deaths and case and death rates. These distrubutions should not be even because it would be even more concerning if there were more deaths. Additionally, there cannot be more deaths than total population. This confirms the integrity of the data is good.

# %% [markdown]
# ## Goal of the Next Section: Exploring Relationships between Variable
# Most Importantly:
# - COVID data vs Race
# - COVID data vs Education
# - COVID data vs Income Bracket
# - COVID data vs Household Size

# %%
# make sure these relationships makes sense, check for data integrity
# look at relationship between total case - case rate 
# total deaths - death rate

# %%
df.plot(kind='scatter', x='Total Confirmed Cases', y='Case Rate per 1000', c=['b'])

# %%
df.plot(kind='scatter', x='Total Deaths', y='Death Rate 1000', c=['b'])

# %%
# hard to create a boxplot with so many rows -- too small
ax = sns.boxplot(y="Death Rate 1000",x="Total Deaths", data=df)

# %%
# simple one line code for scatter plot
# same as below code block
df.plot(kind='scatter', x='Black Race', y='Death Rate 1000', c=['b'])

# %%
# scatter plot relationship between Death Rate and Black Race
plt.scatter(df['Black Race'],df['Death Rate 1000'], color='red')
plt.title('Black Race vs Total Death Rate', fontsize=14)
plt.xlabel('Death Rate', fontsize=14)
plt.ylabel('Black Race', fontsize=14)
plt.grid(True)
plt.show()

# %%
# scatter plot relationship between Death Rate and white Race
plt.scatter(df['White Race'],df['Death Rate 1000'], color='red')
plt.title('White Race vs Total Death Rate', fontsize=14)
plt.xlabel('Death Rate', fontsize=14)
plt.ylabel('White Race', fontsize=14)
plt.grid(True)
plt.show()

# %%
# scatter plot relationship between Death Rate and white Race
plt.scatter(df['Death Rate 1000'],df['White Race'], color='red')
plt.title('Death Rate 1000 vs White Race', fontsize=14)
plt.xlabel('White Race', fontsize=14)
plt.ylabel('Death Rate', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Take Away
# Visually hard to tell, but it seems like there is a bigger cluster of 'White Race' near low 'Death Rate per 1000' compared to 'Black Race'.

# %%
# scatter plot relationship between Death Rate and lowest income bracket
plt.scatter(df['Citizen Less than High School  Education'],df['Death Rate 1000'], color='red')
plt.title('Death Rate (per 1000) vs Low Education', fontsize=14)
plt.xlabel('Low education', fontsize=14)
plt.ylabel('Death Rate', fontsize=14)
plt.grid(True)
plt.show()

# %%
# scatter plot relationship between Death Rate and high Education (master's/professional - highest edu)
plt.scatter(df['Citizen Graduate or Professional Degree'],df['Death Rate 1000'],color='red')
plt.title('High Education vs Death Rate (per 1000)', fontsize=14)
plt.xlabel('High education', fontsize=14)
plt.ylabel('Death Rate', fontsize=14)
plt.grid(True)
plt.show()

# %%
df.plot(kind='scatter', x='Total Confirmed Cases', y='Hispanic or Latino', c=['b'])

# %%
df.plot(kind='scatter', x='Case Rate per 1000', y='Total Population', c=['b'])

# %%
df.plot(kind='scatter', x='Total Deaths', y='Total Citizen Educated in US', c=['b'])

# %%
df.plot(kind='scatter', x='Total Deaths', y='Citizen Income over 75000', c=['b'])

# %% [markdown]
# ## Take Away
# - The variability in Death Rate is wider for Higher Education, meaning, high education allows higher chance of survival during the COVID outbreak compared to low education.

# %%
# scatter plot relationship between Death Rate and high Education (master's/professional - highest edu)
plt.scatter(df['Citizen Income 1-9999'],df['Death Rate 1000'],color='red')
plt.title('Citizen Income 1-9999 vs Death Rate (per 1000)', fontsize=14)
plt.xlabel('Citizen Income 1-9999', fontsize=14)
plt.ylabel('Death Rate', fontsize=14)
plt.grid(True)
plt.show()

# %%
#scatter plot relationship between Death Rate and highest income bracket
plt.scatter(df['Citizen Income over 75000'],df['Death Rate 1000'],color='red')
plt.title('Citizen Income over 75000 vs Death Rate (per 1000)', fontsize=14)
plt.xlabel('Citizen Income over 75000', fontsize=14)
plt.ylabel('Death Rate', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Take Away
# Visually very hard to tell in these scatter plots -- will conduct further analysis in Data Mining Models.

# %% [markdown]
# ## Histograms

# %%
## show all features
list(df.columns)

# Make a list of the continuous features + Revenue
lst_continuous_features = ['Citizen Less than High School  Education',
        'Citizen High School  Graduate', 'Citizen Some College  Education',
        'Citizen College Degree', 'Citizen Graduate or Professional Degree',
        'Total Citizen Income', 'Citizen No Income', 'Citizen Income 1-9999',
        'Citizen Income 10000-14999', 'Citizen Income 15000-24999',
        'Citizen Income 25000-34999', 'Citizen Income 35000-49999',
        'Citizen Income 50000-64999', 'Citizen Income 65000-74999',
        'Citizen Income over 75000', 'White Race',
        'Black Race']

# %%
# define all continuous features in new dataframe
pd.DataFrame.hist(df[lst_continuous_features], figsize = [20,20])
plt.suptitle("Distribution of Continuous Features", fontsize=16)
# Out:
# /opt/tljh/user/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /opt/tljh/user/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /opt/tljh/user/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /opt/tljh/user/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# Text(0.5, 0.98, 'Distribution of Continuous Features')

# %% [markdown]
# ___
# <a id = "07"> <h2> 6. Dataset Skewness </h2> </a>

# %% [markdown]
# # Skewness
# - If skewness is less than −1 or greater than +1, the distribution is highly skewed.
# - If skewness is between −1 and −½ or between +½ and +1, the distribution is moderately skewed.
# - If skewness is between −½ and +½, the distribution is approximately symmetric.
# - A symmetrical distribution has a skewness of zero.
# - An asymmetrical distribution with a long tail to the right (higher values) has a positive skew.
# - An asymmetrical distribution with a long tail to the left (lower values) has a negative skew.

# %%
# check the skewness of the dataframe
df.skew()
# Out:
# Total Population                            14.366738
# Households SNAP                             10.877823
# Estimated Individuals SNAP                  11.652447
# Total Citizen Educated in US                13.918064
# Citizen Less than High School  Education    22.829845
# Citizen High School  Graduate               11.818992
# Citizen Some College  Education             12.986895
# Citizen College Degree                      12.726770
# Citizen Graduate or Professional Degree     10.723848
# Total Citizen Income                        14.052336
# Citizen No Income                           17.663261
# Citizen Income 1-9999                       13.937301
# Citizen Income 10000-14999                  17.150624
# Citizen Income 15000-24999                  15.004945
# Citizen Income 25000-34999                  12.909407
# Citizen Income 35000-49999                  11.825275
# Citizen Income 50000-64999                  11.340243
# Citizen Income 65000-74999                  11.371222
# Citizen Income over 75000                   11.789367
# One Race Population                         10.685128
# White Race                                  11.507716
# Black Race                                  11.662716
# Native American Race                        22.207426
# Asian Race                                  35.440969
# Pacific Islander Race                       30.475735
# Other Race Alone                            17.535843
# Hispanic or Latino                           9.523264
# Median Age                                  -0.132728
# Male Median Age                              0.026902
# Female Median Age                           -0.275575
# Total Households                            12.645005
# Average Household Size                       0.460004
# Total Families                              14.428310
# Total Confirmed Cases                       14.143268
# Total Deaths                                17.185772
# Case Rate per 1000                           8.430936
# Death Rate 1000                              4.074873
# dtype: float64

# %% [markdown]
# # Take Away
# - All features seem to be highly skewed and normalization is necessary in the data preparation phase.

# %% [markdown]
# ___
# <a id = "08"> <h2> 7. Correlation Analysis </h2> </a>

# %%
# define correlation matrix (absolute corr values)
data_corr = df[['Citizen Less than High School  Education',
        'Citizen High School  Graduate', 'Citizen Some College  Education',
        'Citizen College Degree', 'Citizen Graduate or Professional Degree',
        'Total Citizen Income', 'Citizen No Income', 'Citizen Income 1-9999',
        'Citizen Income 10000-14999', 'Citizen Income 15000-24999',
        'Citizen Income 25000-34999', 'Citizen Income 35000-49999',
        'Citizen Income 50000-64999', 'Citizen Income 65000-74999',
        'Citizen Income over 75000', 'White Race',
        'Black Race', 'Total Confirmed Cases', 'Total Deaths', 'Case Rate per 1000', 
               'Death Rate 1000']]

# define a correlation matrix
corr_matrix = data_corr.corr().abs()

# show correlation matrix
#corr_matrix

# %%
#source:  https://stackoverflow.com/questions/17778394/list-highest-correlation-pairs-from-a-large-correlation-matrix-in-pandas
# create a function to drop the redundant pairs in the correlation matrix (all correlations are mirrored diagionaly)
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print('----------------------------------------------------')
print('Top Absolute Correlations')
print('----------------------------------------------------')
# show top 'n' correlations
get_top_abs_correlations(data_corr, n=10)

# only show correlations higher or equal to 0.5
get_top_abs_correlations(data_corr, n=10)[get_top_abs_correlations(data_corr, n=10) >= 0.5]

# Our threshold is set to 0.5 for dropping either one of the highly correlated variables
# Out:
# ----------------------------------------------------
# Top Absolute Correlations
# ----------------------------------------------------
# Citizen Income 25000-34999       Citizen Income 35000-49999    0.996982
# Citizen Income 50000-64999       Citizen Income 65000-74999    0.996918
# Citizen Income 15000-24999       Citizen Income 25000-34999    0.995865
# Citizen Income 10000-14999       Citizen Income 15000-24999    0.994883
# Citizen Income 35000-49999       Citizen Income 50000-64999    0.994818
# Total Citizen Income             Citizen Income 1-9999         0.994445
#                                  Citizen Income 15000-24999    0.993961
# Citizen Income 1-9999            Citizen Income 15000-24999    0.993904
# Total Citizen Income             Citizen Income 25000-34999    0.993745
# Citizen Some College  Education  Citizen Income 25000-34999    0.993151
# dtype: float64

# %%
# Create a heatmap from our Pearson's correlation matrix
# source: https://seaborn.pydata.org/generated/seaborn.heatmap.html
mask = np.zeros_like(corr_matrix)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("darkgrid"):
    f, ax = plt.subplots(figsize=(10, 8))
    # plot a seaborn heatmap with labels inside (annot=True), a title for the bar (cbar_kws) and colorstyle (cmap)
    ax = sns.heatmap(corr_matrix, mask=mask, vmax=1, square=True, annot=True, cbar_kws={'label': 'Pairwise Correlation \n (1=Perfect Correlation, 0=No Correlation)'}, cmap="coolwarm")

# %% [markdown]
# # Take Away
# - The most clear conclusion is that there is a difference between 'White Race' and 'Black Race' when looking at Education and Income brackets.
# - 'White Race' is more correlated with higher income and higher education compared to 'Black Race'
