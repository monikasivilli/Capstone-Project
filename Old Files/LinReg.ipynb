# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# In this notebook, the Multiple Linear Regression Model is used with 4 different target variables.
# 1. Covid Confirmed Cases
# 2. Covid Deaths
# 3. Covid Confirmed Cases Rate
# 4. Covid Death Rate

# %% [markdown]
# <b> Table of Contents: </b>
# <br> [Import and Load the Dataset](#000)
# <br> [LinReg with Target Var 'Covid Confirmed Cases'](#100)
# <br> [LinReg with Target Var 'Covid Death Cases'](#200)
# <br> [LinReg with Target Var 'Covid Confirmed Case Rate'](#300)
# <br> [LinReg with Target Var 'Covid Confirmed Death Rate'](#400)
# <br> [Comparing Evaluations'](#500)

# %% [markdown]
# ___
# <a id = "000"> <h2> Import and Load the Dataset </h2> </a>

# %%
import pandas as pd  
import numpy as np  
import seaborn as sns
import copy
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
import statsmodel.api as sm
from sklearn import metrics
from scipy  import stats
sns.set()
# %matplotlib inline

from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import MinMaxScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-265a903ebc9c> in <module>
#       8 from sklearn.linear_model import LinearRegression
#       9 from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
# ---> 10 import statsmodel.api as sm
#      11 from sklearn import metrics
#      12 from scipy  import stats
#
# ModuleNotFoundError: No module named 'statsmodel'

# %% [markdown]
# ___
# <a id = "100"> <h2> LinReg with Target Var 'Covid Confirmed Cases' </h2> </a>

# %%
data = pd.read_csv('tristate_final_data.csv')  # load data set
data.tail()
# Out:
#                               NAME  Covid Confirmed Cases  Covid Deaths   \
# 86   Middlesex County, Connecticut                  50786           6341
# 87   New Haven County, Connecticut                 544454          40947
# 88  New London County, Connecticut                  46001           3303
# 89     Tolland County, Connecticut                  36536           2859
# 90     Windham County, Connecticut                  16276            490
#
#     Population  Covid Case Rate (per 1000)  Covid Death Rate (per 1000)  \
# 86      165676                  306.538062                    38.273498
# 87      862477                  631.267848                    47.476049
# 88      274055                  167.853168                    12.052325
# 89      152691                  239.280639                    18.724090
# 90      118428                  137.433715                     4.137535
#
#      Households SNAP    Estimated Individuals SNAP   \
# 86               5850                         13982
# 87              52580                        130924
# 88              13837                         33762
# 89               4556                         11436
# 90               7426                         18862
#
#      Total Citizen Educated in US   \
# 86                          118781
# 87                          595779
# 88                          188628
# 89                           95679
# 90                           80756
#
#      Citizen Less than High School  Education   ...   Asian Race   \
# 86                                        7140  ...            58
# 87                                       59891  ...           334
# 88                                       15314  ...           180
# 89                                        5616  ...            36
# 90                                        9407  ...            44
#
#      Pacific Islander Race    Other Race Alone    Hispanic or Latino   \
# 86                     2154                3414                157842
# 87                    51981               22808                732734
# 88                     8722               10027                250841
# 89                     2367                2754                146089
# 90                     5002                2715                107077
#
#     Median Age  Male Median Age  Female Median Age   Total Households   \
# 86        43.1             41.9               44.1               67202
# 87        39.3             37.8               40.6              334502
# 88        40.4             38.8               42.0              107057
# 89        38.3             37.0               39.4               54477
# 90        39.2             38.1               40.4               44810
#
#      Average Household Size    Total Families
# 86                         2             35098
# 87                         2            192974
# 88                         2             59599
# 89                         3             30884
# 90                         3             26446
#
# [5 rows x 39 columns]

# %%
data.shape
# Out:
# (91, 39)

# %%
# test output of specific column
data[['Citizen Income 10000-14999']]
# Out:
#     Citizen Income 10000-14999
# 0                        20235
# 1                         3776
# 2                       123943
# 3                        15421
# 4                         7100
# ..                         ...
# 86                        9329
# 87                       54410
# 88                       18272
# 89                        9094
# 90                        8000
#
# [91 rows x 1 columns]

# %% [markdown]
# __Describe the Dataset__

# %%
desc_data = data.describe()
desc_data
# Out:
#        Covid Confirmed Cases  Covid Deaths     Population  \
# count           9.100000e+01      91.000000  9.100000e+01
# mean            3.456057e+05   24234.989011  3.488362e+05
# std             7.060102e+05   59348.612086  4.688670e+05
# min             3.040000e+02       0.000000  4.836000e+03
# 25%             5.696000e+03     222.500000  6.495600e+04
# 50%             3.653600e+04    1815.000000  1.492650e+05
# 75%             2.973320e+05   19315.000000  4.678780e+05
# max             3.587059e+06  347696.000000  2.504700e+06
#
#        Covid Case Rate (per 1000)  Covid Death Rate (per 1000)  \
# count                   91.000000                    91.000000
# mean                   494.782434                    30.009640
# std                    569.681260                    36.520683
# min                     16.823179                     0.000000
# 25%                     88.358613                     3.932980
# 50%                    230.123991                    13.455905
# 75%                    698.363567                    48.039981
# max                   2523.785079                   168.955056
#
#         Households SNAP    Estimated Individuals SNAP   \
# count          91.000000                     91.000000
# mean        18293.857143                  47275.835165
# std         35039.232590                  93199.614618
# min           112.000000                    235.000000
# 25%          3339.000000                   8134.500000
# 50%          6896.000000                  17693.000000
# 75%         16277.000000                  41301.500000
# max        231794.000000                 623526.000000
#
#         Total Citizen Educated in US   \
# count                    9.100000e+01
# mean                     2.451077e+05
# std                      3.390094e+05
# min                      3.604000e+03
# 25%                      4.454750e+04
# 50%                      9.567900e+04
# 75%                      3.225095e+05
# max                      1.789355e+06
#
#         Citizen Less than High School  Education   \
# count                                   91.000000
# mean                                 30821.109890
# std                                  58806.714504
# min                                    441.000000
# 25%                                   4884.500000
# 50%                                   9121.000000
# 75%                                  29749.500000
# max                                 345445.000000
#
#         Citizen High School  Graduate   ...   Asian Race   \
# count                        91.000000  ...     91.000000
# mean                      65796.329670  ...    145.461538
# std                       84838.264728  ...    264.790622
# min                        1155.000000  ...      2.000000
# 25%                       15221.000000  ...     16.500000
# 50%                       31537.000000  ...     37.000000
# 75%                       85696.000000  ...    164.000000
# max                      461228.000000  ...   1530.000000
#
#         Pacific Islander Race    Other Race Alone    Hispanic or Latino   \
# count                91.000000           91.000000          9.100000e+01
# mean              24173.087912        10097.010989          2.889334e+05
# std               57081.322656        17237.898715          3.622369e+05
# min                   4.000000           53.000000          4.785000e+03
# 25%                 526.000000         1006.500000          6.262450e+04
# 50%                2211.000000         3036.000000          1.266640e+05
# 75%               18173.000000        11900.000000          3.770460e+05
# max              351011.000000       100913.000000          2.008415e+06
#
#        Median Age  Male Median Age  Female Median Age   Total Households   \
# count   91.000000        91.000000          91.000000           91.000000
# mean    40.156044        38.840659          41.445055       130804.417582
# std      3.098071         3.229894           3.023473       174684.685378
# min     29.800000        28.500000          31.100000         2262.000000
# 25%     38.500000        37.000000          39.900000        25598.000000
# 50%     40.400000        39.200000          41.900000        54244.000000
# 75%     41.700000        40.550000          42.950000       166551.500000
# max     51.300000        50.900000          51.800000       916856.000000
#
#         Average Household Size    Total Families
# count                 91.000000         91.000000
# mean                   2.439560      79199.538462
# std                    0.499083     106185.924341
# min                    2.000000        795.000000
# 25%                    2.000000      13431.000000
# 50%                    2.000000      30884.000000
# 75%                    3.000000     108228.000000
# max                    3.000000     594378.000000
#
# [8 rows x 38 columns]

# %%
# epxploring outliers in the dataset
# add the standard deviation metric 
data.loc['+3_std'] = desc_data.loc['mean'] + (desc_data.loc['std']*3)
data.loc['-3_std'] = desc_data.loc['mean'] - (desc_data.loc['std']*3)

desc_data
# Out:
#        Covid Confirmed Cases  Covid Deaths     Population  \
# count           9.100000e+01      91.000000  9.100000e+01
# mean            3.456057e+05   24234.989011  3.488362e+05
# std             7.060102e+05   59348.612086  4.688670e+05
# min             3.040000e+02       0.000000  4.836000e+03
# 25%             5.696000e+03     222.500000  6.495600e+04
# 50%             3.653600e+04    1815.000000  1.492650e+05
# 75%             2.973320e+05   19315.000000  4.678780e+05
# max             3.587059e+06  347696.000000  2.504700e+06
#
#        Covid Case Rate (per 1000)  Covid Death Rate (per 1000)  \
# count                   91.000000                    91.000000
# mean                   494.782434                    30.009640
# std                    569.681260                    36.520683
# min                     16.823179                     0.000000
# 25%                     88.358613                     3.932980
# 50%                    230.123991                    13.455905
# 75%                    698.363567                    48.039981
# max                   2523.785079                   168.955056
#
#         Households SNAP    Estimated Individuals SNAP   \
# count          91.000000                     91.000000
# mean        18293.857143                  47275.835165
# std         35039.232590                  93199.614618
# min           112.000000                    235.000000
# 25%          3339.000000                   8134.500000
# 50%          6896.000000                  17693.000000
# 75%         16277.000000                  41301.500000
# max        231794.000000                 623526.000000
#
#         Total Citizen Educated in US   \
# count                    9.100000e+01
# mean                     2.451077e+05
# std                      3.390094e+05
# min                      3.604000e+03
# 25%                      4.454750e+04
# 50%                      9.567900e+04
# 75%                      3.225095e+05
# max                      1.789355e+06
#
#         Citizen Less than High School  Education   \
# count                                   91.000000
# mean                                 30821.109890
# std                                  58806.714504
# min                                    441.000000
# 25%                                   4884.500000
# 50%                                   9121.000000
# 75%                                  29749.500000
# max                                 345445.000000
#
#         Citizen High School  Graduate   ...   Asian Race   \
# count                        91.000000  ...     91.000000
# mean                      65796.329670  ...    145.461538
# std                       84838.264728  ...    264.790622
# min                        1155.000000  ...      2.000000
# 25%                       15221.000000  ...     16.500000
# 50%                       31537.000000  ...     37.000000
# 75%                       85696.000000  ...    164.000000
# max                      461228.000000  ...   1530.000000
#
#         Pacific Islander Race    Other Race Alone    Hispanic or Latino   \
# count                91.000000           91.000000          9.100000e+01
# mean              24173.087912        10097.010989          2.889334e+05
# std               57081.322656        17237.898715          3.622369e+05
# min                   4.000000           53.000000          4.785000e+03
# 25%                 526.000000         1006.500000          6.262450e+04
# 50%                2211.000000         3036.000000          1.266640e+05
# 75%               18173.000000        11900.000000          3.770460e+05
# max              351011.000000       100913.000000          2.008415e+06
#
#        Median Age  Male Median Age  Female Median Age   Total Households   \
# count   91.000000        91.000000          91.000000           91.000000
# mean    40.156044        38.840659          41.445055       130804.417582
# std      3.098071         3.229894           3.023473       174684.685378
# min     29.800000        28.500000          31.100000         2262.000000
# 25%     38.500000        37.000000          39.900000        25598.000000
# 50%     40.400000        39.200000          41.900000        54244.000000
# 75%     41.700000        40.550000          42.950000       166551.500000
# max     51.300000        50.900000          51.800000       916856.000000
#
#         Average Household Size    Total Families
# count                 91.000000         91.000000
# mean                   2.439560      79199.538462
# std                    0.499083     106185.924341
# min                    2.000000        795.000000
# 25%                    2.000000      13431.000000
# 50%                    2.000000      30884.000000
# 75%                    3.000000     108228.000000
# max                    3.000000     594378.000000
#
# [8 rows x 38 columns]

# %%
# filter the outliers
#data_remove = data[(np.abs(stats.zscore(data))<3).all(axis=1)]

# show what rows were removed 
#data.index.difference(data_remove.index)
# Outcome: New York Counties with high amount of Covid Cases would be removed

# %% [markdown]
# __Take Away__
# Should we remove the outliers?
# - No, outliers are necessary in this dataset because it shows counties with the highest or lowest amount of COVID Confirmed Cases. In the above code block, when run, the New York counties with the highest amount of COVID cases were removed. We DO NOT want to do that; this project is focused on finding the counties with the most amount of Covid Confirmed Cases.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93 entries, 0 to -3_std
# Data columns (total 39 columns):
# NAME                                          91 non-null object
# Covid Confirmed Cases                         93 non-null float64
# Covid Deaths                                  93 non-null float64
# Population                                    93 non-null float64
# Covid Case Rate (per 1000)                    93 non-null float64
# Covid Death Rate (per 1000)                   93 non-null float64
#  Households SNAP                              93 non-null float64
#  Estimated Individuals SNAP                   93 non-null float64
#  Total Citizen Educated in US                 93 non-null float64
#  Citizen Less than High School  Education     93 non-null float64
#  Citizen High School  Graduate                93 non-null float64
#  Citizen Some College  Education              93 non-null float64
#  Citizen College Degree                       93 non-null float64
#  Citizen Graduate or Professional Degree      93 non-null float64
#  Total Citizen Income                         93 non-null float64
#  Citizen No Income                            93 non-null float64
# Citizen Income 1-9999                         93 non-null float64
# Citizen Income 10000-14999                    93 non-null float64
# Citizen Income 15000-24999                    93 non-null float64
# Citizen Income 25000-34999                    93 non-null float64
# Citizen Income 35000-49999                    93 non-null float64
# Citizen Income 50000-64999                    93 non-null float64
# Citizen Income 65000-74999                    93 non-null float64
# Citizen Income over 75000                     93 non-null float64
#  Total Population                             93 non-null float64
#  One Race Population                          93 non-null float64
#  White Race                                   93 non-null float64
#  Black Race                                   93 non-null float64
#  Native American Race                         93 non-null float64
#  Asian Race                                   93 non-null float64
#  Pacific Islander Race                        93 non-null float64
#  Other Race Alone                             93 non-null float64
#  Hispanic or Latino                           93 non-null float64
# Median Age                                    93 non-null float64
# Male Median Age                               93 non-null float64
# Female Median Age                             93 non-null float64
#  Total Households                             93 non-null float64
#  Average Household Size                       93 non-null float64
#  Total Families                               93 non-null float64
# dtypes: float64(38), object(1)
# memory usage: 29.1+ KB

# %%
#data1.hist()

# %%
# set the index equal to the NAME column (county, state) 
# drop the NAME column from the data df
data.index = data['NAME']
data = data.drop('NAME', axis=1)
data.head()
# Out:
#                               Covid Confirmed Cases  Covid Deaths   \
# NAME
# Albany County, New York                     87943.0         3989.0
# Allegany County, New York                    2601.0          126.0
# Bronx County, New York                    2544478.0       234021.0
# Broome County, New York                     24218.0         1802.0
# Cattaraugus County, New York                 3875.0          128.0
#
#                               Population  Covid Case Rate (per 1000)  \
# NAME
# Albany County, New York         304204.0                  289.092188
# Allegany County, New York        48946.0                   53.140195
# Bronx County, New York         1385108.0                 1837.024983
# Broome County, New York         200600.0                  120.727817
# Cattaraugus County, New York     80317.0                   48.246324
#
#                               Covid Death Rate (per 1000)   Households SNAP   \
# NAME
# Albany County, New York                         13.112911            15087.0
# Allegany County, New York                        2.574266             2994.0
# Bronx County, New York                         168.955056           184934.0
# Broome County, New York                          8.983051            13226.0
# Cattaraugus County, New York                     1.593685             5801.0
#
#                                Estimated Individuals SNAP   \
# NAME
# Albany County, New York                            34247.0
# Allegany County, New York                           7305.0
# Bronx County, New York                            512267.0
# Broome County, New York                            30684.0
# Cattaraugus County, New York                       13980.0
#
#                                Total Citizen Educated in US   \
# NAME
# Albany County, New York                             204833.0
# Allegany County, New York                            30331.0
# Bronx County, New York                              927374.0
# Broome County, New York                             129802.0
# Cattaraugus County, New York                         53201.0
#
#                                Citizen Less than High School  Education   \
# NAME
# Albany County, New York                                          15255.0
# Allegany County, New York                                         3219.0
# Bronx County, New York                                          264309.0
# Broome County, New York                                          12429.0
# Cattaraugus County, New York                                      6188.0
#
#                                Citizen High School  Graduate   ...  \
# NAME                                                           ...
# Albany County, New York                               50589.0  ...
# Allegany County, New York                             11464.0  ...
# Bronx County, New York                               256066.0  ...
# Broome County, New York                               40700.0  ...
# Cattaraugus County, New York                          21015.0  ...
#
#                                Asian Race    Pacific Islander Race   \
# NAME
# Albany County, New York               98.0                   4744.0
# Allegany County, New York              9.0                    206.0
# Bronx County, New York              1288.0                 351011.0
# Broome County, New York               82.0                   1912.0
# Cattaraugus County, New York          15.0                    305.0
#
#                                Other Race Alone    Hispanic or Latino   \
# NAME
# Albany County, New York                   7647.0              289287.0
# Allegany County, New York                  557.0               48276.0
# Bronx County, New York                   73243.0              643695.0
# Broome County, New York                   5087.0              193822.0
# Cattaraugus County, New York              1363.0               78972.0
#
#                               Median Age  Male Median Age  Female Median Age  \
# NAME
# Albany County, New York             38.5             36.8               40.0
# Allegany County, New York           37.8             36.2               39.2
# Bronx County, New York              32.8             30.6               34.9
# Broome County, New York             40.2             38.1               42.2
# Cattaraugus County, New York        40.7             39.8               41.6
#
#                                Total Households    Average Household Size   \
# NAME
# Albany County, New York                 126251.0                       2.0
# Allegany County, New York                18208.0                       2.0
# Bronx County, New York                  483449.0                       3.0
# Broome County, New York                  82167.0                       2.0
# Cattaraugus County, New York             32263.0                       2.0
#
#                                Total Families
# NAME
# Albany County, New York                60631.0
# Allegany County, New York              10576.0
# Bronx County, New York                368196.0
# Broome County, New York                40559.0
# Cattaraugus County, New York           18801.0
#
# [5 rows x 38 columns]

# %%
data.isnull().any()
# Out:
# Covid Confirmed Cases                         False
# Covid Deaths                                  False
# Population                                    False
# Covid Case Rate (per 1000)                    False
# Covid Death Rate (per 1000)                   False
#  Households SNAP                              False
#  Estimated Individuals SNAP                   False
#  Total Citizen Educated in US                 False
#  Citizen Less than High School  Education     False
#  Citizen High School  Graduate                False
#  Citizen Some College  Education              False
#  Citizen College Degree                       False
#  Citizen Graduate or Professional Degree      False
#  Total Citizen Income                         False
#  Citizen No Income                            False
# Citizen Income 1-9999                         False
# Citizen Income 10000-14999                    False
# Citizen Income 15000-24999                    False
# Citizen Income 25000-34999                    False
# Citizen Income 35000-49999                    False
# Citizen Income 50000-64999                    False
# Citizen Income 65000-74999                    False
# Citizen Income over 75000                     False
#  Total Population                             False
#  One Race Population                          False
#  White Race                                   False
#  Black Race                                   False
#  Native American Race                         False
#  Asian Race                                   False
#  Pacific Islander Race                        False
#  Other Race Alone                             False
#  Hispanic or Latino                           False
# Median Age                                    False
# Male Median Age                               False
# Female Median Age                             False
#  Total Households                             False
#  Average Household Size                       False
#  Total Families                               False
# dtype: bool

# %%
# set the data type to float for the data frame
data = data.astype(float)
data.dtypes
# Out:
# Covid Confirmed Cases                         float64
# Covid Deaths                                  float64
# Population                                    float64
# Covid Case Rate (per 1000)                    float64
# Covid Death Rate (per 1000)                   float64
#  Households SNAP                              float64
#  Estimated Individuals SNAP                   float64
#  Total Citizen Educated in US                 float64
#  Citizen Less than High School  Education     float64
#  Citizen High School  Graduate                float64
#  Citizen Some College  Education              float64
#  Citizen College Degree                       float64
#  Citizen Graduate or Professional Degree      float64
#  Total Citizen Income                         float64
#  Citizen No Income                            float64
# Citizen Income 1-9999                         float64
# Citizen Income 10000-14999                    float64
# Citizen Income 15000-24999                    float64
# Citizen Income 25000-34999                    float64
# Citizen Income 35000-49999                    float64
# Citizen Income 50000-64999                    float64
# Citizen Income 65000-74999                    float64
# Citizen Income over 75000                     float64
#  Total Population                             float64
#  One Race Population                          float64
#  White Race                                   float64
#  Black Race                                   float64
#  Native American Race                         float64
#  Asian Race                                   float64
#  Pacific Islander Race                        float64
#  Other Race Alone                             float64
#  Hispanic or Latino                           float64
# Median Age                                    float64
# Male Median Age                               float64
# Female Median Age                             float64
#  Total Households                             float64
#  Average Household Size                       float64
#  Total Families                               float64
# dtype: object

# %% [markdown]
# ___
# # Data Exploration

# %%
# print out a correlation matrix of the data frame
corr = data.corr()

# display it
display(corr)
f, ax = plt.subplots(figsize=(20, 20)) # adjust the size of the heat map to see all the features 

# plot a heatmap
sns.heatmap(corr, xticklabels = corr.columns, yticklabels = corr.columns, cmap = "RdBu")
# Out:
#                                             Covid Confirmed Cases  \
# Covid Confirmed Cases                                    1.000000
# Covid Deaths                                             0.946343
# Population                                               0.939945
# Covid Case Rate (per 1000)                               0.809679
# Covid Death Rate (per 1000)                              0.882591
#  Households SNAP                                         0.824807
#  Estimated Individuals SNAP                              0.839012
#  Total Citizen Educated in US                            0.937521
#  Citizen Less than High School  Education                0.931299
#  Citizen High School  Graduate                           0.930849
#  Citizen Some College  Education                         0.921499
#  Citizen College Degree                                  0.886149
#  Citizen Graduate or Professional Degree                 0.835805
#  Total Citizen Income                                    0.938884
#  Citizen No Income                                       0.961823
# Citizen Income 1-9999                                    0.929262
# Citizen Income 10000-14999                               0.931616
# Citizen Income 15000-24999                               0.932621
# Citizen Income 25000-34999                               0.923989
# Citizen Income 35000-49999                               0.919611
# Citizen Income 50000-64999                               0.915804
# Citizen Income 65000-74999                               0.906722
# Citizen Income over 75000                                0.848939
#  Total Population                                        0.939963
#  One Race Population                                     0.845245
#  White Race                                              0.859275
#  Black Race                                              0.875550
#  Native American Race                                    0.836901
#  Asian Race                                              0.916453
#  Pacific Islander Race                                   0.908096
#  Other Race Alone                                        0.942518
#  Hispanic or Latino                                      0.900000
# Median Age                                              -0.151396
# Male Median Age                                         -0.167396
# Female Median Age                                       -0.134063
#  Total Households                                        0.911245
#  Average Household Size                                  0.528366
#  Total Families                                          0.943920
#
#                                             Covid Deaths   Population  \
# Covid Confirmed Cases                            0.946343    0.939945
# Covid Deaths                                     1.000000    0.930824
# Population                                       0.930824    1.000000
# Covid Case Rate (per 1000)                       0.672282    0.712426
# Covid Death Rate (per 1000)                      0.860526    0.844080
#  Households SNAP                                 0.919649    0.883241
#  Estimated Individuals SNAP                      0.929755    0.879921
#  Total Citizen Educated in US                    0.932932    0.997955
#  Citizen Less than High School  Education        0.987584    0.940400
#  Citizen High School  Graduate                   0.928184    0.980252
#  Citizen Some College  Education                 0.899062    0.984640
#  Citizen College Degree                          0.874996    0.964699
#  Citizen Graduate or Professional Degree         0.800255    0.919353
#  Total Citizen Income                            0.933130    0.998658
#  Citizen No Income                               0.977872    0.980951
# Citizen Income 1-9999                            0.949499    0.989394
# Citizen Income 10000-14999                       0.954845    0.987155
# Citizen Income 15000-24999                       0.942750    0.990633
# Citizen Income 25000-34999                       0.925074    0.991409
# Citizen Income 35000-49999                       0.916981    0.992554
# Citizen Income 50000-64999                       0.900619    0.992485
# Citizen Income 65000-74999                       0.881166    0.986720
# Citizen Income over 75000                        0.784979    0.915831
#  Total Population                                0.930819    0.999220
#  One Race Population                             0.768241    0.941322
#  White Race                                      0.943677    0.889958
#  Black Race                                      0.925500    0.874488
#  Native American Race                            0.882616    0.846008
#  Asian Race                                      0.963049    0.927249
#  Pacific Islander Race                           0.944415    0.876092
#  Other Race Alone                                0.964880    0.958579
#  Hispanic or Latino                              0.882440    0.987286
# Median Age                                      -0.157190   -0.164414
# Male Median Age                                 -0.168183   -0.182925
# Female Median Age                               -0.143524   -0.149657
#  Total Households                                0.913807    0.992372
#  Average Household Size                          0.452970    0.475680
#  Total Families                                  0.926314    0.989351
#
#                                             Covid Case Rate (per 1000)  \
# Covid Confirmed Cases                                         0.809679
# Covid Deaths                                                  0.672282
# Population                                                    0.712426
# Covid Case Rate (per 1000)                                    1.000000
# Covid Death Rate (per 1000)                                   0.886569
#  Households SNAP                                              0.563662
#  Estimated Individuals SNAP                                   0.580082
#  Total Citizen Educated in US                                 0.704882
#  Citizen Less than High School  Education                     0.658982
#  Citizen High School  Graduate                                0.699773
#  Citizen Some College  Education                              0.697160
#  Citizen College Degree                                       0.681811
#  Citizen Graduate or Professional Degree                      0.654386
#  Total Citizen Income                                         0.707937
#  Citizen No Income                                            0.716829
# Citizen Income 1-9999                                         0.682983
# Citizen Income 10000-14999                                    0.676579
# Citizen Income 15000-24999                                    0.689824
# Citizen Income 25000-34999                                    0.679830
# Citizen Income 35000-49999                                    0.678136
# Citizen Income 50000-64999                                    0.693117
# Citizen Income 65000-74999                                    0.700660
# Citizen Income over 75000                                     0.699266
#  Total Population                                             0.713420
#  One Race Population                                          0.692966
#  White Race                                                   0.600408
#  Black Race                                                   0.617407
#  Native American Race                                         0.570804
#  Asian Race                                                   0.653435
#  Pacific Islander Race                                        0.685112
#  Other Race Alone                                             0.698708
#  Hispanic or Latino                                           0.677851
# Median Age                                                   -0.150018
# Male Median Age                                              -0.175034
# Female Median Age                                            -0.126506
#  Total Households                                             0.683121
#  Average Household Size                                       0.658162
#  Total Families                                               0.736174
#
#                                             Covid Death Rate (per 1000)  \
# Covid Confirmed Cases                                          0.882591
# Covid Deaths                                                   0.860526
# Population                                                     0.844080
# Covid Case Rate (per 1000)                                     0.886569
# Covid Death Rate (per 1000)                                    1.000000
#  Households SNAP                                               0.775890
#  Estimated Individuals SNAP                                    0.787589
#  Total Citizen Educated in US                                  0.840472
#  Citizen Less than High School  Education                      0.844259
#  Citizen High School  Graduate                                 0.835307
#  Citizen Some College  Education                               0.813926
#  Citizen College Degree                                        0.805162
#  Citizen Graduate or Professional Degree                       0.744328
#  Total Citizen Income                                          0.842439
#  Citizen No Income                                             0.869129
# Citizen Income 1-9999                                          0.841124
# Citizen Income 10000-14999                                     0.836663
# Citizen Income 15000-24999                                     0.837263
# Citizen Income 25000-34999                                     0.817048
# Citizen Income 35000-49999                                     0.814105
# Citizen Income 50000-64999                                     0.817044
# Citizen Income 65000-74999                                     0.812659
# Citizen Income over 75000                                      0.766692
#  Total Population                                              0.844355
#  One Race Population                                           0.745795
#  White Race                                                    0.800028
#  Black Race                                                    0.795832
#  Native American Race                                          0.725268
#  Asian Race                                                    0.836986
#  Pacific Islander Race                                         0.860707
#  Other Race Alone                                              0.860661
#  Hispanic or Latino                                            0.791937
# Median Age                                                    -0.157934
# Male Median Age                                               -0.176625
# Female Median Age                                             -0.142832
#  Total Households                                              0.825232
#  Average Household Size                                        0.635488
#  Total Families                                                0.855646
#
#                                              Households SNAP   \
# Covid Confirmed Cases                                0.824807
# Covid Deaths                                         0.919649
# Population                                           0.883241
# Covid Case Rate (per 1000)                           0.563662
# Covid Death Rate (per 1000)                          0.775890
#  Households SNAP                                     1.000000
#  Estimated Individuals SNAP                          0.996045
#  Total Citizen Educated in US                        0.880110
#  Citizen Less than High School  Education            0.955703
#  Citizen High School  Graduate                       0.869095
#  Citizen Some College  Education                     0.853093
#  Citizen College Degree                              0.810779
#  Citizen Graduate or Professional Degree             0.756252
#  Total Citizen Income                                0.883676
#  Citizen No Income                                   0.913261
# Citizen Income 1-9999                                0.935820
# Citizen Income 10000-14999                           0.937478
# Citizen Income 15000-24999                           0.904101
# Citizen Income 25000-34999                           0.882153
# Citizen Income 35000-49999                           0.873715
# Citizen Income 50000-64999                           0.843198
# Citizen Income 65000-74999                           0.820125
# Citizen Income over 75000                            0.707177
#  Total Population                                    0.883640
#  One Race Population                                 0.727764
#  White Race                                          0.963573
#  Black Race                                          0.933872
#  Native American Race                                0.713132
#  Asian Race                                          0.922313
#  Pacific Islander Race                               0.913779
#  Other Race Alone                                    0.908570
#  Hispanic or Latino                                  0.834604
# Median Age                                          -0.209990
# Male Median Age                                     -0.224703
# Female Median Age                                   -0.195080
#  Total Households                                    0.888667
#  Average Household Size                              0.344237
#  Total Families                                      0.884345
#
#                                              Estimated Individuals SNAP   \
# Covid Confirmed Cases                                           0.839012
# Covid Deaths                                                    0.929755
# Population                                                      0.879921
# Covid Case Rate (per 1000)                                      0.580082
# Covid Death Rate (per 1000)                                     0.787589
#  Households SNAP                                                0.996045
#  Estimated Individuals SNAP                                     1.000000
#  Total Citizen Educated in US                                   0.874055
#  Citizen Less than High School  Education                       0.961490
#  Citizen High School  Graduate                                  0.878202
#  Citizen Some College  Education                                0.856088
#  Citizen College Degree                                         0.791165
#  Citizen Graduate or Professional Degree                        0.725316
#  Total Citizen Income                                           0.878457
#  Citizen No Income                                              0.918602
# Citizen Income 1-9999                                           0.933092
# Citizen Income 10000-14999                                      0.936422
# Citizen Income 15000-24999                                      0.905359
# Citizen Income 25000-34999                                      0.882517
# Citizen Income 35000-49999                                      0.871998
# Citizen Income 50000-64999                                      0.836642
# Citizen Income 65000-74999                                      0.810104
# Citizen Income over 75000                                       0.682482
#  Total Population                                               0.880295
#  One Race Population                                            0.716285
#  White Race                                                     0.970384
#  Black Race                                                     0.938449
#  Native American Race                                           0.715925
#  Asian Race                                                     0.925084
#  Pacific Islander Race                                          0.921144
#  Other Race Alone                                               0.907778
#  Hispanic or Latino                                             0.828016
# Median Age                                                     -0.210691
# Male Median Age                                                -0.227555
# Female Median Age                                              -0.193126
#  Total Households                                               0.875297
#  Average Household Size                                         0.370239
#  Total Families                                                 0.890993
#
#                                              Total Citizen Educated in US   \
# Covid Confirmed Cases                                             0.937521
# Covid Deaths                                                      0.932932
# Population                                                        0.997955
# Covid Case Rate (per 1000)                                        0.704882
# Covid Death Rate (per 1000)                                       0.840472
#  Households SNAP                                                  0.880110
#  Estimated Individuals SNAP                                       0.874055
#  Total Citizen Educated in US                                     1.000000
#  Citizen Less than High School  Education                         0.941104
#  Citizen High School  Graduate                                    0.975534
#  Citizen Some College  Education                                  0.979830
#  Citizen College Degree                                           0.973971
#  Citizen Graduate or Professional Degree                          0.930696
#  Total Citizen Income                                             0.999777
#  Citizen No Income                                                0.980829
# Citizen Income 1-9999                                             0.987710
# Citizen Income 10000-14999                                        0.985624
# Citizen Income 15000-24999                                        0.988947
# Citizen Income 25000-34999                                        0.989602
# Citizen Income 35000-49999                                        0.991326
# Citizen Income 50000-64999                                        0.994195
# Citizen Income 65000-74999                                        0.989587
# Citizen Income over 75000                                         0.925090
#  Total Population                                                 0.998735
#  One Race Population                                              0.938764
#  White Race                                                       0.884702
#  Black Race                                                       0.873271
#  Native American Race                                             0.861386
#  Asian Race                                                       0.929175
#  Pacific Islander Race                                            0.875952
#  Other Race Alone                                                 0.962095
#  Hispanic or Latino                                               0.986764
# Median Age                                                       -0.159595
# Male Median Age                                                  -0.175957
# Female Median Age                                                -0.146319
#  Total Households                                                 0.995602
#  Average Household Size                                           0.465539
#  Total Families                                                   0.982494
#
#                                              Citizen Less than High School  Education   \
# Covid Confirmed Cases                                                         0.931299
# Covid Deaths                                                                  0.987584
# Population                                                                    0.940400
# Covid Case Rate (per 1000)                                                    0.658982
# Covid Death Rate (per 1000)                                                   0.844259
#  Households SNAP                                                              0.955703
#  Estimated Individuals SNAP                                                   0.961490
#  Total Citizen Educated in US                                                 0.941104
#  Citizen Less than High School  Education                                     1.000000
#  Citizen High School  Graduate                                                0.936939
#  Citizen Some College  Education                                              0.914184
#  Citizen College Degree                                                       0.874045
#  Citizen Graduate or Professional Degree                                      0.804701
#  Total Citizen Income                                                         0.942379
#  Citizen No Income                                                            0.979285
# Citizen Income 1-9999                                                         0.968411
# Citizen Income 10000-14999                                                    0.973408
# Citizen Income 15000-24999                                                    0.959254
# Citizen Income 25000-34999                                                    0.940761
# Citizen Income 35000-49999                                                    0.931107
# Citizen Income 50000-64999                                                    0.908699
# Citizen Income 65000-74999                                                    0.887087
# Citizen Income over 75000                                                     0.778973
#  Total Population                                                             0.940657
#  One Race Population                                                          0.780779
#  White Race                                                                   0.957369
#  Black Race                                                                   0.955947
#  Native American Race                                                         0.858386
#  Asian Race                                                                   0.978162
#  Pacific Islander Race                                                        0.961590
#  Other Race Alone                                                             0.978376
#  Hispanic or Latino                                                           0.889527
# Median Age                                                                   -0.196483
# Male Median Age                                                              -0.209368
# Female Median Age                                                            -0.181522
#  Total Households                                                             0.929672
#  Average Household Size                                                       0.434403
#  Total Families                                                               0.935792
#
#                                              Citizen High School  Graduate   \
# Covid Confirmed Cases                                              0.930849
# Covid Deaths                                                       0.928184
# Population                                                         0.980252
# Covid Case Rate (per 1000)                                         0.699773
# Covid Death Rate (per 1000)                                        0.835307
#  Households SNAP                                                   0.869095
#  Estimated Individuals SNAP                                        0.878202
#  Total Citizen Educated in US                                      0.975534
#  Citizen Less than High School  Education                          0.936939
#  Citizen High School  Graduate                                     1.000000
#  Citizen Some College  Education                                   0.989097
#  Citizen College Degree                                            0.908719
#  Citizen Graduate or Professional Degree                           0.835428
#  Total Citizen Income                                              0.977112
#  Citizen No Income                                                 0.973271
# Citizen Income 1-9999                                              0.973434
# Citizen Income 10000-14999                                         0.978260
# Citizen Income 15000-24999                                         0.990126
# Citizen Income 25000-34999                                         0.990819
# Citizen Income 35000-49999                                         0.988685
# Citizen Income 50000-64999                                         0.976428
# Citizen Income 65000-74999                                         0.961572
# Citizen Income over 75000                                          0.840656
#  Total Population                                                  0.981022
#  One Race Population                                               0.913730
#  White Race                                                        0.885694
#  Black Race                                                        0.872485
#  Native American Race                                              0.847710
#  Asian Race                                                        0.915315
#  Pacific Islander Race                                             0.864888
#  Other Race Alone                                                  0.941665
#  Hispanic or Latino                                                0.968614
# Median Age                                                        -0.158470
# Male Median Age                                                   -0.182700
# Female Median Age                                                 -0.136912
#  Total Households                                                  0.958648
#  Average Household Size                                            0.489731
#  Total Families                                                    0.985229
#
#                                             ...   Asian Race   \
# Covid Confirmed Cases                       ...      0.916453
# Covid Deaths                                ...      0.963049
# Population                                  ...      0.927249
# Covid Case Rate (per 1000)                  ...      0.653435
# Covid Death Rate (per 1000)                 ...      0.836986
#  Households SNAP                            ...      0.922313
#  Estimated Individuals SNAP                 ...      0.925084
#  Total Citizen Educated in US               ...      0.929175
#  Citizen Less than High School  Education   ...      0.978162
#  Citizen High School  Graduate              ...      0.915315
#  Citizen Some College  Education            ...      0.904717
#  Citizen College Degree                     ...      0.867889
#  Citizen Graduate or Professional Degree    ...      0.808866
#  Total Citizen Income                       ...      0.930489
#  Citizen No Income                          ...      0.958273
# Citizen Income 1-9999                       ...      0.952417
# Citizen Income 10000-14999                  ...      0.954107
# Citizen Income 15000-24999                  ...      0.943513
# Citizen Income 25000-34999                  ...      0.924677
# Citizen Income 35000-49999                  ...      0.917622
# Citizen Income 50000-64999                  ...      0.899114
# Citizen Income 65000-74999                  ...      0.879727
# Citizen Income over 75000                   ...      0.786804
#  Total Population                           ...      0.927243
#  One Race Population                        ...      0.778131
#  White Race                                 ...      0.909107
#  Black Race                                 ...      0.953279
#  Native American Race                       ...      0.856069
#  Asian Race                                 ...      1.000000
#  Pacific Islander Race                      ...      0.966277
#  Other Race Alone                           ...      0.983146
#  Hispanic or Latino                         ...      0.871425
# Median Age                                  ...     -0.215244
# Male Median Age                             ...     -0.227624
# Female Median Age                           ...     -0.200996
#  Total Households                           ...      0.920115
#  Average Household Size                     ...      0.444652
#  Total Families                             ...      0.915237
#
#                                              Pacific Islander Race   \
# Covid Confirmed Cases                                      0.908096
# Covid Deaths                                               0.944415
# Population                                                 0.876092
# Covid Case Rate (per 1000)                                 0.685112
# Covid Death Rate (per 1000)                                0.860707
#  Households SNAP                                           0.913779
#  Estimated Individuals SNAP                                0.921144
#  Total Citizen Educated in US                              0.875952
#  Citizen Less than High School  Education                  0.961590
#  Citizen High School  Graduate                             0.864888
#  Citizen Some College  Education                           0.846935
#  Citizen College Degree                                    0.806251
#  Citizen Graduate or Professional Degree                   0.746316
#  Total Citizen Income                                      0.878652
#  Citizen No Income                                         0.925546
# Citizen Income 1-9999                                      0.909976
# Citizen Income 10000-14999                                 0.913728
# Citizen Income 15000-24999                                 0.894242
# Citizen Income 25000-34999                                 0.865835
# Citizen Income 35000-49999                                 0.856676
# Citizen Income 50000-64999                                 0.833582
# Citizen Income 65000-74999                                 0.812707
# Citizen Income over 75000                                  0.729524
#  Total Population                                          0.876026
#  One Race Population                                       0.704751
#  White Race                                                0.888330
#  Black Race                                                0.962270
#  Native American Race                                      0.795938
#  Asian Race                                                0.966277
#  Pacific Islander Race                                     1.000000
#  Other Race Alone                                          0.963319
#  Hispanic or Latino                                        0.794313
# Median Age                                                -0.206908
# Male Median Age                                           -0.216364
# Female Median Age                                         -0.193755
#  Total Households                                          0.865407
#  Average Household Size                                    0.440892
#  Total Families                                            0.872146
#
#                                              Other Race Alone   \
# Covid Confirmed Cases                                 0.942518
# Covid Deaths                                          0.964880
# Population                                            0.958579
# Covid Case Rate (per 1000)                            0.698708
# Covid Death Rate (per 1000)                           0.860661
#  Households SNAP                                      0.908570
#  Estimated Individuals SNAP                           0.907778
#  Total Citizen Educated in US                         0.962095
#  Citizen Less than High School  Education             0.978376
#  Citizen High School  Graduate                        0.941665
#  Citizen Some College  Education                      0.934829
#  Citizen College Degree                               0.914735
#  Citizen Graduate or Professional Degree              0.859765
#  Total Citizen Income                                 0.962451
#  Citizen No Income                                    0.977460
# Citizen Income 1-9999                                 0.969650
# Citizen Income 10000-14999                            0.971776
# Citizen Income 15000-24999                            0.966960
# Citizen Income 25000-34999                            0.953636
# Citizen Income 35000-49999                            0.949012
# Citizen Income 50000-64999                            0.938744
# Citizen Income 65000-74999                            0.924895
# Citizen Income over 75000                             0.844018
#  Total Population                                     0.958674
#  One Race Population                                  0.830439
#  White Race                                           0.900847
#  Black Race                                           0.945000
#  Native American Race                                 0.886182
#  Asian Race                                           0.983146
#  Pacific Islander Race                                0.963319
#  Other Race Alone                                     1.000000
#  Hispanic or Latino                                   0.909938
# Median Age                                           -0.202302
# Male Median Age                                      -0.213765
# Female Median Age                                    -0.190132
#  Total Households                                     0.953595
#  Average Household Size                               0.448427
#  Total Families                                       0.940400
#
#                                              Hispanic or Latino   Median Age  \
# Covid Confirmed Cases                                   0.900000   -0.151396
# Covid Deaths                                            0.882440   -0.157190
# Population                                              0.987286   -0.164414
# Covid Case Rate (per 1000)                              0.677851   -0.150018
# Covid Death Rate (per 1000)                             0.791937   -0.157934
#  Households SNAP                                        0.834604   -0.209990
#  Estimated Individuals SNAP                             0.828016   -0.210691
#  Total Citizen Educated in US                           0.986764   -0.159595
#  Citizen Less than High School  Education               0.889527   -0.196483
#  Citizen High School  Graduate                          0.968614   -0.158470
#  Citizen Some College  Education                        0.980350   -0.146111
#  Citizen College Degree                                 0.965393   -0.123913
#  Citizen Graduate or Professional Degree                0.926787   -0.101709
#  Total Citizen Income                                   0.986803   -0.166411
#  Citizen No Income                                      0.949839   -0.189724
# Citizen Income 1-9999                                   0.966763   -0.197497
# Citizen Income 10000-14999                              0.962827   -0.184965
# Citizen Income 15000-24999                              0.972953   -0.178056
# Citizen Income 25000-34999                              0.983097   -0.163442
# Citizen Income 35000-49999                              0.987541   -0.153866
# Citizen Income 50000-64999                              0.993615   -0.140763
# Citizen Income 65000-74999                              0.992210   -0.131517
# Citizen Income over 75000                               0.925719   -0.081377
#  Total Population                                       0.988293   -0.167157
#  One Race Population                                    0.967563   -0.090883
#  White Race                                             0.850422   -0.196821
#  Black Race                                             0.807011   -0.212144
#  Native American Race                                   0.823515   -0.086617
#  Asian Race                                             0.871425   -0.215244
#  Pacific Islander Race                                  0.794313   -0.206908
#  Other Race Alone                                       0.909938   -0.202302
#  Hispanic or Latino                                     1.000000   -0.131319
# Median Age                                             -0.131319    1.000000
# Male Median Age                                        -0.152237    0.993257
# Female Median Age                                      -0.116021    0.992612
#  Total Households                                       0.983349   -0.163434
#  Average Household Size                                 0.460077   -0.124620
#  Total Families                                         0.976774   -0.172653
#
#                                             Male Median Age  \
# Covid Confirmed Cases                             -0.167396
# Covid Deaths                                      -0.168183
# Population                                        -0.182925
# Covid Case Rate (per 1000)                        -0.175034
# Covid Death Rate (per 1000)                       -0.176625
#  Households SNAP                                  -0.224703
#  Estimated Individuals SNAP                       -0.227555
#  Total Citizen Educated in US                     -0.175957
#  Citizen Less than High School  Education         -0.209368
#  Citizen High School  Graduate                    -0.182700
#  Citizen Some College  Education                  -0.172502
#  Citizen College Degree                           -0.131497
#  Citizen Graduate or Professional Degree          -0.105210
#  Total Citizen Income                             -0.183465
#  Citizen No Income                                -0.204604
# Citizen Income 1-9999                             -0.216566
# Citizen Income 10000-14999                        -0.204572
# Citizen Income 15000-24999                        -0.199643
# Citizen Income 25000-34999                        -0.185302
# Citizen Income 35000-49999                        -0.175496
# Citizen Income 50000-64999                        -0.159239
# Citizen Income 65000-74999                        -0.148825
# Citizen Income over 75000                         -0.086680
#  Total Population                                 -0.185891
#  One Race Population                              -0.114556
#  White Race                                       -0.212020
#  Black Race                                       -0.227862
#  Native American Race                             -0.086607
#  Asian Race                                       -0.227624
#  Pacific Islander Race                            -0.216364
#  Other Race Alone                                 -0.213765
#  Hispanic or Latino                               -0.152237
# Median Age                                         0.993257
# Male Median Age                                    1.000000
# Female Median Age                                  0.973090
#  Total Households                                 -0.179099
#  Average Household Size                           -0.122408
#  Total Families                                   -0.196782
#
#                                             Female Median Age  \
# Covid Confirmed Cases                               -0.134063
# Covid Deaths                                        -0.143524
# Population                                          -0.149657
# Covid Case Rate (per 1000)                          -0.126506
# Covid Death Rate (per 1000)                         -0.142832
#  Households SNAP                                    -0.195080
#  Estimated Individuals SNAP                         -0.193126
#  Total Citizen Educated in US                       -0.146319
#  Citizen Less than High School  Education           -0.181522
#  Citizen High School  Graduate                      -0.136912
#  Citizen Some College  Education                    -0.124565
#  Citizen College Degree                             -0.120105
#  Citizen Graduate or Professional Degree            -0.103081
#  Total Citizen Income                               -0.152548
#  Citizen No Income                                  -0.174594
# Citizen Income 1-9999                               -0.181145
# Citizen Income 10000-14999                          -0.167502
# Citizen Income 15000-24999                          -0.159214
# Citizen Income 25000-34999                          -0.145261
# Citizen Income 35000-49999                          -0.136347
# Citizen Income 50000-64999                          -0.126864
# Citizen Income 65000-74999                          -0.119285
# Citizen Income over 75000                           -0.081202
#  Total Population                                   -0.151914
#  One Race Population                                -0.075589
#  White Race                                         -0.181086
#  Black Race                                         -0.191855
#  Native American Race                               -0.082919
#  Asian Race                                         -0.200996
#  Pacific Islander Race                              -0.193755
#  Other Race Alone                                   -0.190132
#  Hispanic or Latino                                 -0.116021
# Median Age                                           0.992612
# Male Median Age                                      0.973090
# Female Median Age                                    1.000000
#  Total Households                                   -0.151825
#  Average Household Size                             -0.129110
#  Total Families                                     -0.152441
#
#                                              Total Households   \
# Covid Confirmed Cases                                 0.911245
# Covid Deaths                                          0.913807
# Population                                            0.992372
# Covid Case Rate (per 1000)                            0.683121
# Covid Death Rate (per 1000)                           0.825232
#  Households SNAP                                      0.888667
#  Estimated Individuals SNAP                           0.875297
#  Total Citizen Educated in US                         0.995602
#  Citizen Less than High School  Education             0.929672
#  Citizen High School  Graduate                        0.958648
#  Citizen Some College  Education                      0.969341
#  Citizen College Degree                               0.979224
#  Citizen Graduate or Professional Degree              0.946920
#  Total Citizen Income                                 0.995222
#  Citizen No Income                                    0.966515
# Citizen Income 1-9999                                 0.985336
# Citizen Income 10000-14999                            0.981107
# Citizen Income 15000-24999                            0.980293
# Citizen Income 25000-34999                            0.980819
# Citizen Income 35000-49999                            0.984163
# Citizen Income 50000-64999                            0.989543
# Citizen Income 65000-74999                            0.987366
# Citizen Income over 75000                             0.933810
#  Total Population                                     0.993177
#  One Race Population                                  0.940851
#  White Race                                           0.879228
#  Black Race                                           0.867397
#  Native American Race                                 0.835414
#  Asian Race                                           0.920115
#  Pacific Islander Race                                0.865407
#  Other Race Alone                                     0.953595
#  Hispanic or Latino                                   0.983349
# Median Age                                           -0.163434
# Male Median Age                                      -0.179099
# Female Median Age                                    -0.151825
#  Total Households                                     1.000000
#  Average Household Size                               0.437341
#  Total Families                                       0.970730
#
#                                              Average Household Size   \
# Covid Confirmed Cases                                       0.528366
# Covid Deaths                                                0.452970
# Population                                                  0.475680
# Covid Case Rate (per 1000)                                  0.658162
# Covid Death Rate (per 1000)                                 0.635488
#  Households SNAP                                            0.344237
#  Estimated Individuals SNAP                                 0.370239
#  Total Citizen Educated in US                               0.465539
#  Citizen Less than High School  Education                   0.434403
#  Citizen High School  Graduate                              0.489731
#  Citizen Some College  Education                            0.468735
#  Citizen College Degree                                     0.452518
#  Citizen Graduate or Professional Degree                    0.395821
#  Total Citizen Income                                       0.467998
#  Citizen No Income                                          0.483881
# Citizen Income 1-9999                                       0.449518
# Citizen Income 10000-14999                                  0.440488
# Citizen Income 15000-24999                                  0.460655
# Citizen Income 25000-34999                                  0.453184
# Citizen Income 35000-49999                                  0.444720
# Citizen Income 50000-64999                                  0.461254
# Citizen Income 65000-74999                                  0.464675
# Citizen Income over 75000                                   0.462049
#  Total Population                                           0.475680
#  One Race Population                                        0.462768
#  White Race                                                 0.418156
#  Black Race                                                 0.375320
#  Native American Race                                       0.412077
#  Asian Race                                                 0.444652
#  Pacific Islander Race                                      0.440892
#  Other Race Alone                                           0.448427
#  Hispanic or Latino                                         0.460077
# Median Age                                                 -0.124620
# Male Median Age                                            -0.122408
# Female Median Age                                          -0.129110
#  Total Households                                           0.437341
#  Average Household Size                                     1.000000
#  Total Families                                             0.511821
#
#                                              Total Families
# Covid Confirmed Cases                               0.943920
# Covid Deaths                                        0.926314
# Population                                          0.989351
# Covid Case Rate (per 1000)                          0.736174
# Covid Death Rate (per 1000)                         0.855646
#  Households SNAP                                    0.884345
#  Estimated Individuals SNAP                         0.890993
#  Total Citizen Educated in US                       0.982494
#  Citizen Less than High School  Education           0.935792
#  Citizen High School  Graduate                      0.985229
#  Citizen Some College  Education                    0.985593
#  Citizen College Degree                             0.929795
#  Citizen Graduate or Professional Degree            0.873678
#  Total Citizen Income                               0.985342
#  Citizen No Income                                  0.976997
# Citizen Income 1-9999                               0.983442
# Citizen Income 10000-14999                          0.981509
# Citizen Income 15000-24999                          0.985797
# Citizen Income 25000-34999                          0.985784
# Citizen Income 35000-49999                          0.984574
# Citizen Income 50000-64999                          0.976768
# Citizen Income 65000-74999                          0.966829
# Citizen Income over 75000                           0.877540
#  Total Population                                   0.990125
#  One Race Population                                0.931803
#  White Race                                         0.901581
#  Black Race                                         0.871916
#  Native American Race                               0.806418
#  Asian Race                                         0.915237
#  Pacific Islander Race                              0.872146
#  Other Race Alone                                   0.940400
#  Hispanic or Latino                                 0.976774
# Median Age                                         -0.172653
# Male Median Age                                    -0.196782
# Female Median Age                                  -0.152441
#  Total Households                                   0.970730
#  Average Household Size                             0.511821
#  Total Families                                     1.000000
#
# [38 rows x 38 columns]

# %% [markdown]
# __Take Away__
# - The darker the spots the higher the correlation between the features.
# - We are looking at our __Target Variable: Covid Confirmed Cases__ and you see for
#     - Income 'No Income' has the highest correlation
#     - Race 'Other Race Alone', 'Asian Race', 'Hispanic or Lation', and 'Black Race' have a higher correlation than 'White Race'
#     - Gender 'Male Median Age' has a higher correlation compared to 'Female Median Age'

# %%
# check the average level of COVID Confirmed Cases
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(data['Covid Confirmed Cases'])

# %% [markdown]
# - Looking at the relationships between Covid Confirmed Cases and Race (White vs Black), Education (No high degree vs Masters or Professional), and Income Level (Second lowest income bracket vs Highest income bracket)

# %%
# trim the spaces of the cells from the csv file
data.columns = data.columns.to_series().apply(lambda x: x.strip())

# %%
# scatter plot relationship between Covid Cases and Black Race
plt.scatter(data['Covid Confirmed Cases'], data['Black Race'], color='red')
plt.title('Covid Confirmed Cases Vs Black Race', fontsize=14)
plt.xlabel('Black Race', fontsize=14)
plt.ylabel('Covid Confirmed Cases', fontsize=14)
plt.grid(True)
plt.show()

# %%
# scatter plot relationship between Covid Cases and and White Race
plt.scatter(data['Covid Confirmed Cases'], data['White Race'], color='red')
plt.title('Covid Confirmed Cases Vs White Race', fontsize=14)
plt.xlabel('White Race', fontsize=14)
plt.ylabel('Covid Confirmed Cases', fontsize=14)
plt.grid(True)
plt.show()

# %%
# scatter plot relationship between Covid Cases and Citizen Less than High School Education
plt.scatter(data['Covid Confirmed Cases'], data['Citizen Less than High School  Education'], color='red')
plt.title('Covid Confirmed Cases Vs Citizen Less than High School Education', fontsize=14)
plt.xlabel('Citizen Less than High School Education', fontsize=14)
plt.ylabel('Covid Confirmed Cases', fontsize=14)
plt.grid(True)
plt.show()

# %%
# scatter plot relationship between Covid Cases and Citizen Graduate or Professional Degree
plt.scatter(data['Covid Confirmed Cases'], data['Citizen Graduate or Professional Degree'], color='red')
plt.title('Covid Confirmed Cases Vs Citizen Graduate or Professional Degree', fontsize=14)
plt.xlabel('Citizen Graduate or Professional Degree', fontsize=14)
plt.ylabel('Covid Confirmed Cases', fontsize=14)
plt.grid(True)
plt.show()

# %%
# scatter plot relationship between Covid Cases and Citizen Income $75,000 + (highest income bracket)
plt.scatter(data['Covid Confirmed Cases'], data['Citizen Income over 75000'], color='red')
plt.title('Covid Confirmed Cases Vs Citizen Income 75000 +', fontsize=14)
plt.xlabel('Citizen Income $75000 +', fontsize=14)
plt.ylabel('Covid Confirmed Cases', fontsize=14)
plt.grid(True)
plt.show()

# %%
# scatter plot relationship between Covid Cases and Citizen Income $10,000-$14,999 (second lowest income bracket)
plt.scatter(data['Covid Confirmed Cases'], data['Citizen Income 10000-14999'], color='red')
plt.title('Covid Confirmed Cases Vs Citizen Income $10000-$14999', fontsize=14)
plt.xlabel('Citizen Income $10000-$14999', fontsize=14)
plt.ylabel('Covid Confirmed Cases', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# __Take Away__
# - Visually it is hard to tell with these scatter plots, however, there seems to be a more linear, in other words, stronger correlation between Black Race, Low Education, and Low Income and the number of Covid Confirmed Cases than features of the opposite race, education and income level.
# ___

# %% [markdown]
# # Build the Model

# %%
# divide the dataset into attributes and lables 
# x variable contains all the attributes/features-- took out Age bc float type
# y varaible contains labels

features = ['Population','Households SNAP','Estimated Individuals SNAP','Total Citizen Educated in US','Citizen Less than High School  Education','Citizen High School  Graduate','Citizen Some College  Education','Citizen College Degree','Citizen Graduate or Professional Degree','Total Citizen Income','Citizen No Income','Citizen Income 1-9999','Citizen Income 10000-14999','Citizen Income 15000-24999','Citizen Income 25000-34999','Citizen Income 35000-49999','Citizen Income 50000-64999','Citizen Income 65000-74999','Citizen Income over 75000','One Race Population','White Race','Black Race','Native American Race','Asian Race','Pacific Islander Race','Other Race Alone','Hispanic or Latino','Total Households','Average Household Size','Total Families']

X = data[features]
y = data['Covid Confirmed Cases']

# %%
# splait data set 
# split 80% of the data to the training set while 20% of the data to test set using below code
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2019)

# %%
# train our model
regressor = LinearRegression() 

# fit the model
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predictions = regressor.predict(X_test)

plt.scatter(y_test,predictions)

# %% [markdown]
# ___
# # Exploring the Output

# %%
# get the intercept and coef
intercept = regressor.intercept_

# %%
coef = regressor.coef_

# %%
# print the intercept of the model
print('The intercept of our model is {:.4}'.format(intercept))
print('-'*100)

# loop through the dict and print the coef for each variable
for cf in zip(X.columns, coef):
    print('The Coefficient for {} is {:.2}'.format(cf[0],cf[1]))
# Out:
# The intercept of our model is -6.165e+04
# ----------------------------------------------------------------------------------------------------
# The Coefficient for Population is 0.33
# The Coefficient for Households SNAP is -1e+02
# The Coefficient for Estimated Individuals SNAP is 3.5e+01
# The Coefficient for Total Citizen Educated in US is 1.7e+01
# The Coefficient for Citizen Less than High School  Education is -2.9
# The Coefficient for Citizen High School  Graduate is -1.2e+01
# The Coefficient for Citizen Some College  Education is -1.4e+01
# The Coefficient for Citizen College Degree is -1.4e+01
# The Coefficient for Citizen Graduate or Professional Degree is 1.1e+01
# The Coefficient for Total Citizen Income is 8.2
# The Coefficient for Citizen No Income is -7.3
# The Coefficient for Citizen Income 1-9999 is -2.8e+01
# The Coefficient for Citizen Income 10000-14999 is 6.1e+01
# The Coefficient for Citizen Income 15000-24999 is -1.1e+01
# The Coefficient for Citizen Income 25000-34999 is -3.9e+01
# The Coefficient for Citizen Income 35000-49999 is -1.2e+01
# The Coefficient for Citizen Income 50000-64999 is -3.6e+01
# The Coefficient for Citizen Income 65000-74999 is 6.7e+01
# The Coefficient for Citizen Income over 75000 is -2.4e+01
# The Coefficient for One Race Population is 7.0
# The Coefficient for White Race is 7.8
# The Coefficient for Black Race is -4.7
# The Coefficient for Native American Race is 3.1
# The Coefficient for Asian Race is 1.2e+02
# The Coefficient for Pacific Islander Race is -3.2
# The Coefficient for Other Race Alone is -6.9
# The Coefficient for Hispanic or Latino is -4.2
# The Coefficient for Total Households is -7.9
# The Coefficient for Average Household Size is 2.1e+04
# The Coefficient for Total Families is -7.3

# %%
# mutlivariable lin reg, reg model will show the most optimal coefficients for all attributes 
coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])  
coeff_df
# Out:
#                                            Coefficient
# Population                                    0.334298
# Households SNAP                            -102.991005
# Estimated Individuals SNAP                   34.692501
# Total Citizen Educated in US                 17.409532
# Citizen Less than High School  Education     -2.948770
# Citizen High School  Graduate               -12.044721
# Citizen Some College  Education             -14.073315
# Citizen College Degree                      -13.662630
# Citizen Graduate or Professional Degree      10.968904
# Total Citizen Income                          8.165950
# Citizen No Income                            -7.283606
# Citizen Income 1-9999                       -27.914049
# Citizen Income 10000-14999                   61.035065
# Citizen Income 15000-24999                  -10.807068
# Citizen Income 25000-34999                  -39.271876
# Citizen Income 35000-49999                  -11.575733
# Citizen Income 50000-64999                  -35.776886
# Citizen Income 65000-74999                   67.413657
# Citizen Income over 75000                   -23.998286
# One Race Population                           6.992192
# White Race                                    7.827684
# Black Race                                   -4.675419
# Native American Race                          3.100194
# Asian Race                                  115.985468
# Pacific Islander Race                        -3.181778
# Other Race Alone                             -6.873867
# Hispanic or Latino                           -4.175971
# Total Households                             -7.869718
# Average Household Size                    20837.724484
# Total Families                               -7.324156

# %% [markdown]
# # Evaluating the Model

# %%
# predicition on the test data
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([-3.68939554e+03,  9.97806977e+04,  6.67269457e+05, -1.50807679e+04,
#         1.03320424e+05, -4.04841068e+03, -3.68245350e+04,  6.30692950e+05,
#         3.69665068e+04,  1.05930805e+05,  7.67293639e+04, -6.53487744e+03,
#         5.04031358e+06, -1.35656890e+04,  4.18926803e+04,  3.37017592e+05,
#         9.49868211e+04, -5.44662584e+03, -1.21247830e+04])

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1 = df.head(25)

df1
# Out:
#                                   Actual     Predicted
# NAME
# Salem County, New Jersey         23756.0 -3.689396e+03
# Gloucester County, New Jersey    98935.0  9.978070e+04
# Richmond County, New York       792054.0  6.672695e+05
# Chautauqua County, New York       3302.0 -1.508077e+04
# Greene County, New York          10814.0  1.033204e+05
# Clinton County, New York          5039.0 -4.048411e+03
# Allegany County, New York         2601.0 -3.682454e+04
# Rockland County, New York       786631.0  6.306930e+05
# Rensselaer County, New York      22753.0  3.696651e+04
# Putnam County, New York          65769.0  1.059308e+05
# Schenectady County, New York     34226.0  7.672936e+04
# Cape May County, New Jersey      26807.0 -6.534877e+03
# Kings County, New York         3161699.0  5.040314e+06
# Cattaraugus County, New York      3875.0 -1.356569e+04
# Warren County, New York          11993.0  4.189268e+04
# Orange County, New York         583025.0  3.370176e+05
# Albany County, New York          87943.0  9.498682e+04
# Tolland County, Connecticut      36536.0 -5.446626e+03
# Hamilton County, New York          304.0 -1.212478e+04

# %%
# dont have to print 
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 149055.47166656243
# Mean Squared Error: 192041290647.0154
# Root Mean Squared Error: 438225.1597603855

# %%
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     Covid Confirmed Cases   R-squared:                       0.995
# Model:                               OLS   Adj. R-squared:                  0.992
# Method:                    Least Squares   F-statistic:                     412.0
# Date:                   Fri, 19 Jun 2020   Prob (F-statistic):           1.56e-61
# Time:                           03:02:14   Log-Likelihood:                -1147.2
# No. Observations:                     93   AIC:                             2354.
# Df Residuals:                         63   BIC:                             2430.
# Df Model:                             29
# Covariance Type:               nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# const                                    -9.053e+04   5.53e+04     -1.638      0.106   -2.01e+05    1.99e+04
# Population                                   0.1673      0.373      0.449      0.655      -0.578       0.913
# Households SNAP                            -66.8638     35.550     -1.881      0.065    -137.905       4.177
# Estimated Individuals SNAP                  20.0163     14.269      1.403      0.166      -8.497      48.530
# Total Citizen Educated in US                18.2555     13.918      1.312      0.194      -9.557      46.068
# Citizen Less than High School  Education   -10.4107     14.262     -0.730      0.468     -38.911      18.089
# Citizen High School  Graduate              -13.9198     14.418     -0.965      0.338     -42.733      14.893
# Citizen Some College  Education             -6.4124     13.208     -0.485      0.629     -32.806      19.982
# Citizen College Degree                     -14.4127     13.474     -1.070      0.289     -41.339      12.514
# Citizen Graduate or Professional Degree     11.6517     13.409      0.869      0.388     -15.143      38.447
# Total Citizen Income                         2.7879      3.705      0.752      0.455      -4.616      10.192
# Citizen No Income                           -1.3660      7.735     -0.177      0.860     -16.824      14.092
# Citizen Income 1-9999                      -24.2473      7.815     -3.103      0.003     -39.864      -8.631
# Citizen Income 10000-14999                  45.6868     12.674      3.605      0.001      20.359      71.014
# Citizen Income 15000-24999                  11.0939      9.727      1.140      0.258      -8.345      30.533
# Citizen Income 25000-34999                 -58.0077     13.702     -4.234      0.000     -85.388     -30.627
# Citizen Income 35000-49999                 -10.4778      8.621     -1.215      0.229     -27.706       6.750
# Citizen Income 50000-64999                 -24.0863     15.853     -1.519      0.134     -55.767       7.594
# Citizen Income 65000-74999                  48.3992     17.977      2.692      0.009      12.476      84.322
# Citizen Income over 75000                  -22.4657      7.252     -3.098      0.003     -36.957      -7.974
# One Race Population                          7.8701      5.397      1.458      0.150      -2.915      18.656
# White Race                                   8.2769      5.563      1.488      0.142      -2.840      19.394
# Black Race                                  -7.0743     13.430     -0.527      0.600     -33.911      19.762
# Native American Race                         4.2213      6.110      0.691      0.492      -7.989      16.432
# Asian Race                                -197.4256    228.203     -0.865      0.390    -653.453     258.602
# Pacific Islander Race                        4.4065      4.178      1.055      0.296      -3.943      12.756
# Other Race Alone                            13.4158      9.186      1.460      0.149      -4.941      31.772
# Hispanic or Latino                          -2.9716      1.919     -1.549      0.126      -6.806       0.863
# Total Households                            -9.0726      4.378     -2.073      0.042     -17.820      -0.325
# Average Household Size                    3.756e+04   2.37e+04      1.584      0.118   -9814.478    8.49e+04
# Total Families                              -6.6985      4.906     -1.365      0.177     -16.503       3.106
# ==============================================================================
# Omnibus:                        1.327   Durbin-Watson:                   2.130
# Prob(Omnibus):                  0.515   Jarque-Bera (JB):                0.837
# Skew:                          -0.199   Prob(JB):                        0.658
# Kurtosis:                       3.239   Cond. No.                     1.23e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.48e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /opt/tljh/user/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %% [markdown]
# ___
# <a id = "200"> <h2> LinReg with Target Var 'Covid Deaths' </h2> </a>

# %%
# check the average level of COVID Deaths
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(data['Covid Deaths'])

# %% [markdown]
# __Describe the Dataset__

# %%
# scatter plot relationship between Covid Cases and Black Race
plt.scatter(data['Covid Deaths'], data['Black Race'], color='red')
plt.title('Covid Deaths Vs Black Race', fontsize=14)
plt.xlabel('Black Race', fontsize=14)
plt.ylabel('Covid Deaths', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# # CHANGE ALL THESE -- covid deaths

# %%
# scatter plot relationship between Covid Cases and and White Race
plt.scatter(data['Covid Confirmed Cases'], data['White Race'], color='red')
plt.title('Covid Confirmed Cases Vs White Race', fontsize=14)
plt.xlabel('White Race', fontsize=14)
plt.ylabel('Covid Confirmed Cases', fontsize=14)
plt.grid(True)
plt.show()

# %%
# scatter plot relationship between Covid Cases and Citizen Less than High School Education
plt.scatter(data['Covid Confirmed Cases'], data['Citizen Less than High School  Education'], color='red')
plt.title('Covid Confirmed Cases Vs Citizen Less than High School Education', fontsize=14)
plt.xlabel('Citizen Less than High School Education', fontsize=14)
plt.ylabel('Covid Confirmed Cases', fontsize=14)
plt.grid(True)
plt.show()

# %%
# scatter plot relationship between Covid Cases and Citizen Graduate or Professional Degree
plt.scatter(data['Covid Confirmed Cases'], data['Citizen Graduate or Professional Degree'], color='red')
plt.title('Covid Confirmed Cases Vs Citizen Graduate or Professional Degree', fontsize=14)
plt.xlabel('Citizen Graduate or Professional Degree', fontsize=14)
plt.ylabel('Covid Confirmed Cases', fontsize=14)
plt.grid(True)
plt.show()

# %%
# scatter plot relationship between Covid Cases and Citizen Income $75,000 + (highest income bracket)
plt.scatter(data['Covid Confirmed Cases'], data['Citizen Income $75,000 +'], color='red')
plt.title('Covid Confirmed Cases Vs Citizen Income $75,000 +', fontsize=14)
plt.xlabel('Citizen Income $75,000 +', fontsize=14)
plt.ylabel('Covid Confirmed Cases', fontsize=14)
plt.grid(True)
plt.show()

# %%
# scatter plot relationship between Covid Cases and Citizen Income $10,000-$14,999 (second lowest income bracket)
plt.scatter(data['Covid Confirmed Cases'], data['Citizen Income $10,000-$14,999'], color='red')
plt.title('Covid Confirmed Cases Vs Citizen Income $10,000-$14,999', fontsize=14)
plt.xlabel('Citizen Income $10,000-$14,999', fontsize=14)
plt.ylabel('Covid Confirmed Cases', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# __Take Away__
# - Visually it is hard to tell with these scatter plots, however, there seems to be a more linear, in other words, stronger correlation between Black Race, Low Education, and Low Income and the number of Covid Confirmed Cases than features of the opposite race, education and income level.
# ___
#
# CHANGE FOR COVID DEATHS

# %% [markdown]
# # Build the Model

# %%
# divide the dataset into attributes and lables 
# x variable contains all the attributes/features-- took out Age bc float type
# y varaible contains labels

X = data[features]
y = data['Covid Deaths']

# %%
# splait data set 
# split 80% of the data to the training set while 20% of the data to test set using below code
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2019)

# %%
# train our model
regressor = LinearRegression() 

# fit the model
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ___
# # Exploring the Output

# %%
# get the intercept and coef
intercept = regressor.intercept_

# %%
coef = regressor.coef_

# %%
# print the intercept of the model
print('The intercept of our model is {:.4}'.format(intercept))
print('-'*100)

# loop through the dict and print the coef for each variable
for cf in zip(X.columns, coef):
    print('The Coefficient for {} is {:.2}'.format(cf[0],cf[1]))
# Out:
# The intercept of our model is 977.1
# ----------------------------------------------------------------------------------------------------
# The Coefficient for Population is 0.033
# The Coefficient for Households SNAP is -1.1e+01
# The Coefficient for Estimated Individuals SNAP is 4.4
# The Coefficient for Total Citizen Educated in US is -1.1
# The Coefficient for Citizen Less than High School  Education is 1.7
# The Coefficient for Citizen High School  Graduate is 0.74
# The Coefficient for Citizen Some College  Education is 0.33
# The Coefficient for Citizen College Degree is 0.8
# The Coefficient for Citizen Graduate or Professional Degree is 0.95
# The Coefficient for Total Citizen Income is 0.6
# The Coefficient for Citizen No Income is 0.085
# The Coefficient for Citizen Income 1-9999 is -1.0
# The Coefficient for Citizen Income 10000-14999 is 3.5
# The Coefficient for Citizen Income 15000-24999 is 1.1
# The Coefficient for Citizen Income 25000-34999 is -2.8
# The Coefficient for Citizen Income 35000-49999 is 2.3
# The Coefficient for Citizen Income 50000-64999 is -0.43
# The Coefficient for Citizen Income 65000-74999 is 1.4
# The Coefficient for Citizen Income over 75000 is 0.62
# The Coefficient for One Race Population is -0.56
# The Coefficient for White Race is -0.36
# The Coefficient for Black Race is -1.2
# The Coefficient for Native American Race is -0.52
# The Coefficient for Asian Race is 2.1e+01
# The Coefficient for Pacific Islander Race is -1.1
# The Coefficient for Other Race Alone is -2.1
# The Coefficient for Hispanic or Latino is 0.062
# The Coefficient for Total Households is 0.16
# The Coefficient for Average Household Size is -6.6e+02
# The Coefficient for Total Families is -0.61

# %%
# mutlivariable lin reg, reg model will show the most optimal coefficients for all attributes 
coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])  
coeff_df
# Out:
#                                           Coefficient
# Population                                   0.033495
# Households SNAP                            -10.776295
# Estimated Individuals SNAP                   4.385261
# Total Citizen Educated in US                -1.054716
# Citizen Less than High School  Education     1.728938
# Citizen High School  Graduate                0.740972
# Citizen Some College  Education              0.327395
# Citizen College Degree                       0.799521
# Citizen Graduate or Professional Degree      0.953096
# Total Citizen Income                         0.603144
# Citizen No Income                            0.084889
# Citizen Income 1-9999                       -1.010791
# Citizen Income 10000-14999                   3.465177
# Citizen Income 15000-24999                   1.092663
# Citizen Income 25000-34999                  -2.796589
# Citizen Income 35000-49999                   2.302459
# Citizen Income 50000-64999                  -0.425982
# Citizen Income 65000-74999                   1.414716
# Citizen Income over 75000                    0.619348
# One Race Population                         -0.557326
# White Race                                  -0.363276
# Black Race                                  -1.248722
# Native American Race                        -0.520365
# Asian Race                                  20.595457
# Pacific Islander Race                       -1.086643
# Other Race Alone                            -2.135459
# Hispanic or Latino                           0.061868
# Total Households                             0.155405
# Average Household Size                    -659.749407
# Total Families                              -0.612686

# %% [markdown]
# # Evaluating the Model

# %%
# predicition on the test data
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([ 1.68747720e+03,  1.44616489e+04,  4.10066420e+04, -5.03311586e+03,
#         5.15904586e+03,  7.06195516e+02, -9.64822565e+02,  3.40783676e+04,
#         1.74795412e+03,  2.77691205e+03,  1.42055910e+03,  2.11040589e+03,
#         5.36626366e+05,  4.08714626e+01,  1.08721682e+03,  4.16232165e+03,
#         1.81580740e+04,  4.12607125e+03, -2.48197885e+02])

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1 = df.head(25)

df1
# Out:
#                                  Actual      Predicted
# NAME
# Salem County, New Jersey         1302.0    1687.477203
# Gloucester County, New Jersey    5268.0   14461.648899
# Richmond County, New York       50674.0   41006.642019
# Chautauqua County, New York       119.0   -5033.115861
# Greene County, New York           456.0    5159.045857
# Clinton County, New York          228.0     706.195516
# Allegany County, New York         126.0    -964.822565
# Rockland County, New York       26203.0   34078.367639
# Rensselaer County, New York      1131.0    1747.954117
# Putnam County, New York          3142.0    2776.912050
# Schenectady County, New York     1443.0    1420.559104
# Cape May County, New Jersey      2004.0    2110.405893
# Kings County, New York         347696.0  536626.365742
# Cattaraugus County, New York      128.0      40.871463
# Warren County, New York          1086.0    1087.216817
# Orange County, New York         18069.0    4162.321654
# Albany County, New York          3989.0   18158.073974
# Tolland County, Connecticut      2859.0    4126.071252
# Hamilton County, New York          35.0    -248.197885

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 13594.823838433635
# Mean Squared Error: 1914804893.2574928
# Root Mean Squared Error: 43758.48367182635

# %%
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Covid Deaths   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                     579.4
# Date:                Fri, 19 Jun 2020   Prob (F-statistic):           3.60e-66
# Time:                        03:04:37   Log-Likelihood:                -901.17
# No. Observations:                  93   AIC:                             1862.
# Df Residuals:                      63   BIC:                             1938.
# Df Model:                          29
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# const                                    -1209.5540   3921.089     -0.308      0.759   -9045.226    6626.118
# Population                                   0.0245      0.026      0.925      0.359      -0.028       0.077
# Households SNAP                             -7.6212      2.522     -3.022      0.004     -12.661      -2.582
# Estimated Individuals SNAP                   3.0088      1.012      2.973      0.004       0.986       5.032
# Total Citizen Educated in US                -0.1748      0.987     -0.177      0.860      -2.148       1.798
# Citizen Less than High School  Education     0.5369      1.012      0.531      0.597      -1.485       2.559
# Citizen High School  Graduate                0.5286      1.023      0.517      0.607      -1.515       2.573
# Citizen Some College  Education              0.8314      0.937      0.887      0.378      -1.041       2.704
# Citizen College Degree                       0.7182      0.956      0.751      0.455      -1.192       2.628
# Citizen Graduate or Professional Degree      0.9582      0.951      1.007      0.318      -0.943       2.859
# Total Citizen Income                        -0.4029      0.263     -1.533      0.130      -0.928       0.122
# Citizen No Income                            0.7208      0.549      1.314      0.194      -0.376       1.817
# Citizen Income 1-9999                       -0.1706      0.554     -0.308      0.759      -1.278       0.937
# Citizen Income 10000-14999                   1.2229      0.899      1.360      0.179      -0.574       3.020
# Citizen Income 15000-24999                   1.8864      0.690      2.734      0.008       0.507       3.265
# Citizen Income 25000-34999                  -3.0468      0.972     -3.135      0.003      -4.989      -1.104
# Citizen Income 35000-49999                   2.1517      0.612      3.518      0.001       0.930       3.374
# Citizen Income 50000-64999                   0.2579      1.125      0.229      0.819      -1.990       2.505
# Citizen Income 65000-74999                  -1.0404      1.275     -0.816      0.418      -3.589       1.508
# Citizen Income over 75000                    0.3856      0.514      0.750      0.456      -0.642       1.414
# One Race Population                         -0.3505      0.383     -0.915      0.363      -1.116       0.415
# White Race                                  -0.2048      0.395     -0.519      0.606      -0.993       0.584
# Black Race                                  -0.9667      0.953     -1.015      0.314      -2.871       0.937
# Native American Race                        -0.3870      0.433     -0.893      0.375      -1.253       0.479
# Asian Race                                   4.4764     16.189      0.277      0.783     -27.874      36.827
# Pacific Islander Race                        0.0325      0.296      0.110      0.913      -0.560       0.625
# Other Race Alone                            -0.8044      0.652     -1.234      0.222      -2.107       0.498
# Hispanic or Latino                           0.1530      0.136      1.124      0.265      -0.119       0.425
# Total Households                             0.0598      0.311      0.193      0.848      -0.561       0.680
# Average Household Size                     366.0534   1681.840      0.218      0.828   -2994.836    3726.943
# Total Families                              -0.7022      0.348     -2.018      0.048      -1.398      -0.007
# ==============================================================================
# Omnibus:                       13.399   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               19.525
# Skew:                          -0.640   Prob(JB):                     5.76e-05
# Kurtosis:                       4.844   Cond. No.                     1.23e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.48e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /opt/tljh/user/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %% [markdown]
# ___
# <a id = "300"> <h2> LinReg with Target Var 'Covid Case Rate' </h2> </a>

# %%
# check the average level of COVID Confirmed Cases
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(data['Covid Case Rate (per 1000)'])

# %% [markdown]
# # Build the Model

# %%
# divide the dataset into attributes and lables 
# x variable contains all the attributes/features-- took out Age bc float type
# y varaible contains labels

X = data[features]
y = data['Covid Case Rate (per 1000)']

# %%
# splait data set 
# split 80% of the data to the training set while 20% of the data to test set using below code
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2019)

# %%
# train our model
regressor = LinearRegression() 

# fit the model
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ___
# # Exploring the Output

# %%
# get the intercept and coef
intercept = regressor.intercept_

# %%
coef = regressor.coef_

# %%
# print the intercept of the model
print('The intercept of our model is {:.4}'.format(intercept))
print('-'*100)

# loop through the dict and print the coef for each variable
for cf in zip(X.columns, coef):
    print('The Coefficient for {} is {:.2}'.format(cf[0],cf[1]))
# Out:
# The intercept of our model is 8.901
# ----------------------------------------------------------------------------------------------------
# The Coefficient for Population is -0.0011
# The Coefficient for Households SNAP is -0.25
# The Coefficient for Estimated Individuals SNAP is 0.091
# The Coefficient for Total Citizen Educated in US is 0.09
# The Coefficient for Citizen Less than High School  Education is -0.073
# The Coefficient for Citizen High School  Graduate is -0.071
# The Coefficient for Citizen Some College  Education is -0.069
# The Coefficient for Citizen College Degree is -0.077
# The Coefficient for Citizen Graduate or Professional Degree is -0.045
# The Coefficient for Total Citizen Income is 0.0089
# The Coefficient for Citizen No Income is -0.048
# The Coefficient for Citizen Income 1-9999 is -0.02
# The Coefficient for Citizen Income 10000-14999 is -0.024
# The Coefficient for Citizen Income 15000-24999 is -0.046
# The Coefficient for Citizen Income 25000-34999 is -0.074
# The Coefficient for Citizen Income 35000-49999 is -0.053
# The Coefficient for Citizen Income 50000-64999 is -0.13
# The Coefficient for Citizen Income 65000-74999 is 0.15
# The Coefficient for Citizen Income over 75000 is -0.064
# The Coefficient for One Race Population is 0.039
# The Coefficient for White Race is 0.041
# The Coefficient for Black Race is 0.016
# The Coefficient for Native American Race is 0.04
# The Coefficient for Asian Race is -0.64
# The Coefficient for Pacific Islander Race is -0.0017
# The Coefficient for Other Race Alone is 0.019
# The Coefficient for Hispanic or Latino is -0.023
# The Coefficient for Total Households is 0.017
# The Coefficient for Average Household Size is 8.2e+01
# The Coefficient for Total Families is -0.019

# %%
# mutlivariable lin reg, reg model will show the most optimal coefficients for all attributes 
coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])  
coeff_df
# Out:
#                                           Coefficient
# Population                                  -0.001082
# Households SNAP                             -0.252085
# Estimated Individuals SNAP                   0.090959
# Total Citizen Educated in US                 0.089609
# Citizen Less than High School  Education    -0.073082
# Citizen High School  Graduate               -0.070797
# Citizen Some College  Education             -0.068624
# Citizen College Degree                      -0.076650
# Citizen Graduate or Professional Degree     -0.044549
# Total Citizen Income                         0.008920
# Citizen No Income                           -0.048210
# Citizen Income 1-9999                       -0.020227
# Citizen Income 10000-14999                  -0.023885
# Citizen Income 15000-24999                  -0.045716
# Citizen Income 25000-34999                  -0.074235
# Citizen Income 35000-49999                  -0.052616
# Citizen Income 50000-64999                  -0.125618
# Citizen Income 65000-74999                   0.150190
# Citizen Income over 75000                   -0.063659
# One Race Population                          0.038645
# White Race                                   0.040696
# Black Race                                   0.015887
# Native American Race                         0.040498
# Asian Race                                  -0.637116
# Pacific Islander Race                       -0.001736
# Other Race Alone                             0.019428
# Hispanic or Latino                          -0.022604
# Total Households                             0.017073
# Average Household Size                      81.567420
# Total Families                              -0.019056

# %% [markdown]
# # Evaluating the Model

# %%
# predicition on the test data
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([ 250.36922776,  411.65240858, 1151.54138476,  260.54872449,
#         245.80673161,   30.82294345,  160.82193375,  676.8423034 ,
#         266.3236301 ,  331.15266335,  102.4084379 ,  200.68429697,
#        3322.4319202 ,   60.08986943,  233.07704107,  370.33327964,
#         179.97853979,  271.6511723 ,  170.08385724])

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1 = df.head(25)

df1
# Out:
#                                     Actual    Predicted
# NAME
# Salem County, New Jersey        359.487311   250.369228
# Gloucester County, New Jersey   343.181124   411.652409
# Richmond County, New York      1689.787298  1151.541385
# Chautauqua County, New York      24.476483   260.548724
# Greene County, New York         219.702972   245.806732
# Clinton County, New York         61.355445    30.822943
# Allegany County, New York        53.140195   160.821934
# Rockland County, New York      2523.785079   676.842303
# Rensselaer County, New York     142.715566   266.323630
# Putnam County, New York         659.602848   331.152663
# Schenectady County, New York    155.851134   102.408438
# Cape May County, New Jersey     275.607875   200.684297
# Kings County, New York         1262.306464  3322.431920
# Cattaraugus County, New York     48.246324    60.089869
# Warren County, New York         182.522410   233.077041
# Orange County, New York        1563.853728   370.333280
# Albany County, New York         289.092188   179.978540
# Tolland County, Connecticut     239.280639   271.651172
# Hamilton County, New York        62.861869   170.083857

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 374.1233195522182
# Mean Squared Error: 505990.67287029827
# Root Mean Squared Error: 711.3302136633156

# %%
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Covid Case Rate (per 1000)   R-squared:                       0.880
# Model:                                    OLS   Adj. R-squared:                  0.824
# Method:                         Least Squares   F-statistic:                     15.86
# Date:                        Fri, 19 Jun 2020   Prob (F-statistic):           2.33e-19
# Time:                                03:06:14   Log-Likelihood:                -630.59
# No. Observations:                          93   AIC:                             1321.
# Df Residuals:                              63   BIC:                             1397.
# Df Model:                                  29
# Covariance Type:                    nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# const                                     -165.1799    213.730     -0.773      0.443    -592.286     261.926
# Population                                  -0.0014      0.001     -0.979      0.331      -0.004       0.001
# Households SNAP                             -0.1289      0.137     -0.937      0.352      -0.404       0.146
# Estimated Individuals SNAP                   0.0504      0.055      0.913      0.365      -0.060       0.161
# Total Citizen Educated in US                 0.0863      0.054      1.603      0.114      -0.021       0.194
# Citizen Less than High School  Education    -0.0865      0.055     -1.568      0.122      -0.197       0.024
# Citizen High School  Graduate               -0.0966      0.056     -1.733      0.088      -0.208       0.015
# Citizen Some College  Education             -0.0621      0.051     -1.217      0.228      -0.164       0.040
# Citizen College Degree                      -0.0943      0.052     -1.810      0.075      -0.198       0.010
# Citizen Graduate or Professional Degree     -0.0534      0.052     -1.029      0.307      -0.157       0.050
# Total Citizen Income                         0.0163      0.014      1.139      0.259      -0.012       0.045
# Citizen No Income                           -0.0419      0.030     -1.401      0.166      -0.102       0.018
# Citizen Income 1-9999                       -0.0622      0.030     -2.058      0.044      -0.123      -0.002
# Citizen Income 10000-14999                  -0.0151      0.049     -0.309      0.759      -0.113       0.083
# Citizen Income 15000-24999                   0.0556      0.038      1.477      0.145      -0.020       0.131
# Citizen Income 25000-34999                  -0.2052      0.053     -3.873      0.000      -0.311      -0.099
# Citizen Income 35000-49999                  -0.0498      0.033     -1.493      0.140      -0.116       0.017
# Citizen Income 50000-64999                  -0.1014      0.061     -1.655      0.103      -0.224       0.021
# Citizen Income 65000-74999                   0.1435      0.070      2.064      0.043       0.005       0.282
# Citizen Income over 75000                   -0.0613      0.028     -2.185      0.033      -0.117      -0.005
# One Race Population                          0.0418      0.021      2.004      0.049       0.000       0.084
# White Race                                   0.0422      0.022      1.963      0.054      -0.001       0.085
# Black Race                                  -0.0307      0.052     -0.591      0.557      -0.134       0.073
# Native American Race                         0.0464      0.024      1.965      0.054      -0.001       0.094
# Asian Race                                  -1.4782      0.882     -1.675      0.099      -3.242       0.285
# Pacific Islander Race                       -0.0020      0.016     -0.124      0.902      -0.034       0.030
# Other Race Alone                             0.1084      0.036      3.053      0.003       0.037       0.179
# Hispanic or Latino                          -0.0184      0.007     -2.473      0.016      -0.033      -0.004
# Total Households                             0.0051      0.017      0.299      0.766      -0.029       0.039
# Average Household Size                     192.0446     91.674      2.095      0.040       8.850     375.240
# Total Families                              -0.0106      0.019     -0.556      0.580      -0.048       0.027
# ==============================================================================
# Omnibus:                       43.228   Durbin-Watson:                   1.832
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              158.926
# Skew:                           1.478   Prob(JB):                     3.09e-35
# Kurtosis:                       8.681   Cond. No.                     1.23e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.48e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /opt/tljh/user/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %% [markdown]
# ___
# <a id = "400"> <h2> LinReg with Target Var 'Covid Death Rate' </h2> </a>

# %%
# check the average level of COVID Confirmed Cases
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(data['Covid Death Rate (per 1000)'])

# %% [markdown]
# # Build the Model

# %%
# divide the dataset into attributes and lables 
# x variable contains all the attributes/features-- took out Age bc float type
# y varaible contains labels

X = data[features]
y = data['Covid Death Rate (per 1000)']

# %%
# splait data set 
# split 80% of the data to the training set while 20% of the data to test set using below code
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2019)

# %%
# train our model
regressor = LinearRegression() 

# fit the model
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ___
# # Exploring the Output

# %%
# get the intercept and coef
intercept = regressor.intercept_

# %%
coef = regressor.coef_

# %%
# print the intercept of the model
print('The intercept of our model is {:.4}'.format(intercept))
print('-'*100)

# loop through the dict and print the coef for each variable
for cf in zip(X.columns, coef):
    print('The Coefficient for {} is {:.2}'.format(cf[0],cf[1]))
# Out:
# The intercept of our model is -5.995
# ----------------------------------------------------------------------------------------------------
# The Coefficient for Population is -2e-05
# The Coefficient for Households SNAP is -0.026
# The Coefficient for Estimated Individuals SNAP is 0.011
# The Coefficient for Total Citizen Educated in US is 0.0034
# The Coefficient for Citizen Less than High School  Education is -0.0039
# The Coefficient for Citizen High School  Graduate is -0.0041
# The Coefficient for Citizen Some College  Education is -0.004
# The Coefficient for Citizen College Degree is -0.0046
# The Coefficient for Citizen Graduate or Professional Degree is -0.0036
# The Coefficient for Total Citizen Income is 0.0019
# The Coefficient for Citizen No Income is -0.003
# The Coefficient for Citizen Income 1-9999 is -0.0028
# The Coefficient for Citizen Income 10000-14999 is -0.0011
# The Coefficient for Citizen Income 15000-24999 is -0.00034
# The Coefficient for Citizen Income 25000-34999 is -0.0061
# The Coefficient for Citizen Income 35000-49999 is 0.00077
# The Coefficient for Citizen Income 50000-64999 is -0.0062
# The Coefficient for Citizen Income 65000-74999 is 0.0046
# The Coefficient for Citizen Income over 75000 is -0.0013
# The Coefficient for One Race Population is 0.0014
# The Coefficient for White Race is 0.0018
# The Coefficient for Black Race is 0.00023
# The Coefficient for Native American Race is 0.0019
# The Coefficient for Asian Race is -0.014
# The Coefficient for Pacific Islander Race is -0.0016
# The Coefficient for Other Race Alone is -0.0019
# The Coefficient for Hispanic or Latino is -0.0013
# The Coefficient for Total Households is 0.0025
# The Coefficient for Average Household Size is 8.4
# The Coefficient for Total Families is -0.0017

# %%
# mutlivariable lin reg, reg model will show the most optimal coefficients for all attributes 
coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])  
coeff_df
# Out:
#                                           Coefficient
# Population                                  -0.000020
# Households SNAP                             -0.026415
# Estimated Individuals SNAP                   0.010713
# Total Citizen Educated in US                 0.003393
# Citizen Less than High School  Education    -0.003884
# Citizen High School  Graduate               -0.004105
# Citizen Some College  Education             -0.003957
# Citizen College Degree                      -0.004563
# Citizen Graduate or Professional Degree     -0.003575
# Total Citizen Income                         0.001886
# Citizen No Income                           -0.002993
# Citizen Income 1-9999                       -0.002833
# Citizen Income 10000-14999                  -0.001076
# Citizen Income 15000-24999                  -0.000337
# Citizen Income 25000-34999                  -0.006051
# Citizen Income 35000-49999                   0.000773
# Citizen Income 50000-64999                  -0.006222
# Citizen Income 65000-74999                   0.004576
# Citizen Income over 75000                   -0.001303
# One Race Population                          0.001354
# White Race                                   0.001783
# Black Race                                   0.000230
# Native American Race                         0.001949
# Asian Race                                  -0.014347
# Pacific Islander Race                       -0.001627
# Other Race Alone                            -0.001931
# Hispanic or Latino                          -0.001266
# Total Households                             0.002450
# Average Household Size                       8.397520
# Total Families                              -0.001744

# %% [markdown]
# # Evaluating the Model

# %%
# predicition on the test data
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([ 21.54858239,  33.12184822,  68.56777131,   2.75113176,
#         12.12040115,  -1.31667727,   7.83564963,  47.48802274,
#         15.64834717,  21.05359222,  -2.39697577,  10.35921987,
#        456.44204171,   3.60195014,  11.1841529 ,  16.1862022 ,
#         32.50969852,  22.8726399 ,  10.0101047 ])

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1 = df.head(25)

df1
# Out:
#                                    Actual   Predicted
# NAME
# Salem County, New Jersey        19.702495   21.548582
# Gloucester County, New Jersey   18.273393   33.121848
# Richmond County, New York      108.109146   68.567771
# Chautauqua County, New York      0.882102    2.751132
# Greene County, New York          9.264338   12.120401
# Clinton County, New York         2.776154   -1.316677
# Allegany County, New York        2.574266    7.835650
# Rockland County, New York       84.068312   47.488023
# Rensselaer County, New York      7.094067   15.648347
# Putnam County, New York         31.511383   21.053592
# Schenectady County, New York     6.570829   -2.396976
# Cape May County, New Jersey     20.603506   10.359220
# Kings County, New York         138.817423  456.442042
# Cattaraugus County, New York     1.593685    3.601950
# Warren County, New York         16.527919   11.184153
# Orange County, New York         48.466658   16.186202
# Albany County, New York         13.112911   32.509699
# Tolland County, Connecticut     18.724090   22.872640
# Hamilton County, New York        7.237386   10.010105

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 27.82604405574946
# Mean Squared Error: 5574.245431320701
# Root Mean Squared Error: 74.66086947873498

# %%
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     Covid Death Rate (per 1000)   R-squared:                       0.932
# Model:                                     OLS   Adj. R-squared:                  0.900
# Method:                          Least Squares   F-statistic:                     29.61
# Date:                         Fri, 19 Jun 2020   Prob (F-statistic):           8.71e-27
# Time:                                 03:05:47   Log-Likelihood:                -348.75
# No. Observations:                           93   AIC:                             757.5
# Df Residuals:                               63   BIC:                             833.5
# Df Model:                                   29
# Covariance Type:                     nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# const                                      -13.8838     10.321     -1.345      0.183     -34.508       6.740
# Population                               -2.535e-05   6.96e-05     -0.364      0.717      -0.000       0.000
# Households SNAP                             -0.0205      0.007     -3.088      0.003      -0.034      -0.007
# Estimated Individuals SNAP                   0.0083      0.003      3.121      0.003       0.003       0.014
# Total Citizen Educated in US                 0.0058      0.003      2.218      0.030       0.001       0.011
# Citizen Less than High School  Education    -0.0068      0.003     -2.560      0.013      -0.012      -0.001
# Citizen High School  Graduate               -0.0057      0.003     -2.120      0.038      -0.011      -0.000
# Citizen Some College  Education             -0.0037      0.002     -1.506      0.137      -0.009       0.001
# Citizen College Degree                      -0.0056      0.003     -2.240      0.029      -0.011      -0.001
# Citizen Graduate or Professional Degree     -0.0042      0.003     -1.661      0.102      -0.009       0.001
# Total Citizen Income                         0.0003      0.001      0.434      0.665      -0.001       0.002
# Citizen No Income                           -0.0021      0.001     -1.431      0.157      -0.005       0.001
# Citizen Income 1-9999                       -0.0025      0.001     -1.723      0.090      -0.005       0.000
# Citizen Income 10000-14999                  -0.0048      0.002     -2.044      0.045      -0.010      -0.000
# Citizen Income 15000-24999                   0.0027      0.002      1.478      0.144      -0.001       0.006
# Citizen Income 25000-34999                  -0.0103      0.003     -4.044      0.000      -0.015      -0.005
# Citizen Income 35000-49999                   0.0007      0.002      0.418      0.677      -0.003       0.004
# Citizen Income 50000-64999                  -0.0053      0.003     -1.777      0.080      -0.011       0.001
# Citizen Income 65000-74999                   0.0008      0.003      0.236      0.814      -0.006       0.008
# Citizen Income over 75000                   -0.0023      0.001     -1.719      0.091      -0.005       0.000
# One Race Population                          0.0021      0.001      2.044      0.045    4.58e-05       0.004
# White Race                                   0.0024      0.001      2.279      0.026       0.000       0.004
# Black Race                                  -0.0005      0.003     -0.180      0.857      -0.005       0.005
# Native American Race                         0.0025      0.001      2.214      0.030       0.000       0.005
# Asian Race                                  -0.0431      0.043     -1.011      0.316      -0.128       0.042
# Pacific Islander Race                        0.0003      0.001      0.370      0.713      -0.001       0.002
# Other Race Alone                             0.0020      0.002      1.192      0.238      -0.001       0.005
# Hispanic or Latino                          -0.0011      0.000     -3.076      0.003      -0.002      -0.000
# Total Households                             0.0020      0.001      2.482      0.016       0.000       0.004
# Average Household Size                      12.8437      4.427      2.901      0.005       3.998      21.690
# Total Families                              -0.0020      0.001     -2.200      0.031      -0.004      -0.000
# ==============================================================================
# Omnibus:                        4.600   Durbin-Watson:                   1.639
# Prob(Omnibus):                  0.100   Jarque-Bera (JB):                4.202
# Skew:                           0.518   Prob(JB):                        0.122
# Kurtosis:                       3.098   Cond. No.                     1.23e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.48e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /opt/tljh/user/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %% [markdown]
# ___
# <a id = "000"> <h2> Comparing Evaluations </h2> </a>

# %%
# create table in excel and convert to markdown table

# %%
# Additional notes:
# - go back and create scatter plots for each target variable and include "Take Aways"
